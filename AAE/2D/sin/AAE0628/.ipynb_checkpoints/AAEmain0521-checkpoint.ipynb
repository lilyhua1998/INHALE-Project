# %%
# Common imports
import numpy as np
import os
from backend import import_excel, export_excel

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import tensorflow as tf
from keras import Input, Model
from keras.models import Sequential, Model


import random

import sys
sys.path.append("..")

import dataset,network16

# %% [markdown]
# # Load Data

# %%
# Preprocessing

scenario= "sinus" #sinus, helix
n_instance = 1000
n_features = 2
Z=2
scales = ['-1-1','0-1']
scaled = '-1-1'
nodes=4

# %%
if scenario in ("3d", "helix"):
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    print("X_train= x,y",X_train.shape)
    print("y_train= z",y_train.shape)

    ax = plt.subplot(projection='3d')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='orange')
    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')
    plt.tight_layout()

    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='orange', label='Sample Data')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %%
#storage data
os.system('mkdir Dataset')
os.system('mkdir AAE')
os.system('mkdir AAE/Models')
os.system('mkdir AAE/Losses')
os.system('mkdir AAE/Random_test')
#export_excel(X_train, 'Dataset/X_train')
#export_excel(y_train, 'Dataset/y_train')

# print(X_train.shape,y_train.shape)
X_train = import_excel('Dataset/X_train')
y_train = import_excel('Dataset/y_train')
print('made dataset')
# Out:
# made dataset

# %% [markdown]
# # AAE

# %% [markdown]
# ### Architecture

# %%
encoder=network16.build_encoder(Z, nodes, n_features)
#print("Encoder:\n")
#encoder.summary()


decoder=network16.build_decoder(Z,nodes, n_features)
#print("Decoder:\n")
#decoder.summary()

discriminator=network16.build_discriminator(Z)
print("Discriminator:\n")
#discriminator.summary()
# Out:
# Discriminator:

# %% [markdown]
# ### Preprocessing

# %%
import AAE_Model16

GANorWGAN='WGAN'
epochs = 10001
BATCH_SIZE = 1000

# %%
aae = AAE_Model16.AAE(Z, n_features, BATCH_SIZE,GANorWGAN)

# %%
train_dataset, scaler, X_train_scaled = aae.preproc(X_train, y_train, scaled)

print("X_train",X_train.shape)
print("y_train",y_train.shape)
print("X_train_scaled",X_train_scaled.shape)
# Out:
# data shape_1 (1000, 2)
# Cycles:  1
# X_train (1000, 1)
# y_train (1000, 1)
# X_train_scaled (1000, 2)

# %% [markdown]
# ## Training

# %%
hist = aae.train(Z,BATCH_SIZE,train_dataset, epochs, scaler, scaled,X_train_scaled)
# Out:
# Epoch 1/1001
# [D valid loss: 0.057646],[D fake loss: 0.000000], [G loss(mse): 0.356469, G loss(w): 0.289340]
# /Users/lilyhua/OneDrive - Imperial College London/INHALE Code/Lily/AAE/AAE0521/AAE_Model16.py:200: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot()
# INFO:tensorflow:Assets written to: AAE/Models/encoder_2_1001/assets
# INFO:tensorflow:Assets written to: AAE/Models/decoder_2_1001/assets
# INFO:tensorflow:Assets written to: AAE/Models/discriminator_2_1001/assets
# Epoch 2/1001
# [D valid loss: 0.056530],[D fake loss: 0.000000], [G loss(mse): 0.350467, G loss(w): 0.288142]
# Epoch 3/1001
# [D valid loss: 0.055449],[D fake loss: 0.000000], [G loss(mse): 0.352207, G loss(w): 0.287072]
# Epoch 4/1001
# [D valid loss: 0.056715],[D fake loss: 0.000000], [G loss(mse): 0.353041, G loss(w): 0.289826]
# Epoch 5/1001
# [D valid loss: 0.051593],[D fake loss: 0.000000], [G loss(mse): 0.344455, G loss(w): 0.287891]
# Epoch 6/1001
# [D valid loss: 0.051892],[D fake loss: 0.000000], [G loss(mse): 0.348052, G loss(w): 0.288044]
# Epoch 7/1001
# [D valid loss: 0.050756],[D fake loss: 0.000000], [G loss(mse): 0.339210, G loss(w): 0.287467]
# Epoch 8/1001
# [D valid loss: 0.050322],[D fake loss: 0.000000], [G loss(mse): 0.340001, G loss(w): 0.286689]
# Epoch 9/1001
# [D valid loss: 0.048402],[D fake loss: 0.000000], [G loss(mse): 0.337445, G loss(w): 0.286296]
# Epoch 10/1001
# [D valid loss: 0.047054],[D fake loss: 0.000000], [G loss(mse): 0.337476, G loss(w): 0.287549]
# Epoch 11/1001
# [D valid loss: 0.046735],[D fake loss: 0.000000], [G loss(mse): 0.328635, G loss(w): 0.285805]
# Epoch 12/1001
# [D valid loss: 0.043552],[D fake loss: 0.000000], [G loss(mse): 0.336602, G loss(w): 0.287099]
# Epoch 13/1001
# [D valid loss: 0.041807],[D fake loss: 0.000000], [G loss(mse): 0.329744, G loss(w): 0.288092]
# Epoch 14/1001
# [D valid loss: 0.040927],[D fake loss: 0.000000], [G loss(mse): 0.335835, G loss(w): 0.287546]
# Epoch 15/1001
# [D valid loss: 0.038672],[D fake loss: 0.000000], [G loss(mse): 0.327512, G loss(w): 0.286371]
# Epoch 16/1001
# [D valid loss: 0.038941],[D fake loss: 0.000000], [G loss(mse): 0.328075, G loss(w): 0.285681]
# Epoch 17/1001
# [D valid loss: 0.037087],[D fake loss: 0.000000], [G loss(mse): 0.319539, G loss(w): 0.287233]
# Epoch 18/1001
# [D valid loss: 0.034276],[D fake loss: 0.000000], [G loss(mse): 0.320495, G loss(w): 0.285235]
# Epoch 19/1001
# [D valid loss: 0.034411],[D fake loss: 0.000000], [G loss(mse): 0.324667, G loss(w): 0.285868]
# Epoch 20/1001
# [D valid loss: 0.032368],[D fake loss: 0.000000], [G loss(mse): 0.319558, G loss(w): 0.286214]
# Epoch 21/1001
# [D valid loss: 0.030631],[D fake loss: 0.000000], [G loss(mse): 0.315619, G loss(w): 0.284939]
# Epoch 22/1001
# [D valid loss: 0.030275],[D fake loss: 0.000000], [G loss(mse): 0.315297, G loss(w): 0.286123]
# Epoch 23/1001
# [D valid loss: 0.027847],[D fake loss: 0.000000], [G loss(mse): 0.312891, G loss(w): 0.283766]
# Epoch 24/1001
# [D valid loss: 0.028700],[D fake loss: 0.000000], [G loss(mse): 0.312720, G loss(w): 0.285391]
# Epoch 25/1001
# [D valid loss: 0.026918],[D fake loss: 0.000000], [G loss(mse): 0.314287, G loss(w): 0.286631]
# Epoch 26/1001
# [D valid loss: 0.022439],[D fake loss: 0.000000], [G loss(mse): 0.313458, G loss(w): 0.285584]
# Epoch 27/1001
# [D valid loss: 0.025292],[D fake loss: 0.000000], [G loss(mse): 0.310472, G loss(w): 0.283715]
# Epoch 28/1001
# [D valid loss: 0.024820],[D fake loss: 0.000000], [G loss(mse): 0.303537, G loss(w): 0.285722]
# Epoch 29/1001
# [D valid loss: 0.023332],[D fake loss: 0.000000], [G loss(mse): 0.306433, G loss(w): 0.285160]
# Epoch 30/1001
# [D valid loss: 0.019516],[D fake loss: 0.000000], [G loss(mse): 0.307983, G loss(w): 0.285180]
# Epoch 31/1001
# [D valid loss: 0.018768],[D fake loss: 0.000000], [G loss(mse): 0.303746, G loss(w): 0.284644]
# Epoch 32/1001
# [D valid loss: 0.017422],[D fake loss: 0.000000], [G loss(mse): 0.297076, G loss(w): 0.285275]
# Epoch 33/1001
# [D valid loss: 0.016322],[D fake loss: 0.000000], [G loss(mse): 0.298149, G loss(w): 0.285389]
# Epoch 34/1001
# [D valid loss: 0.013515],[D fake loss: 0.000000], [G loss(mse): 0.296306, G loss(w): 0.285484]
# Epoch 35/1001
# [D valid loss: 0.013872],[D fake loss: 0.000000], [G loss(mse): 0.299146, G loss(w): 0.284197]
# Epoch 36/1001
# [D valid loss: 0.012209],[D fake loss: 0.000000], [G loss(mse): 0.297520, G loss(w): 0.284816]
# Epoch 37/1001
# [D valid loss: 0.009963],[D fake loss: 0.000000], [G loss(mse): 0.296838, G loss(w): 0.286789]
# Epoch 38/1001
# [D valid loss: 0.008206],[D fake loss: 0.000000], [G loss(mse): 0.294050, G loss(w): 0.284608]
# Epoch 39/1001
# [D valid loss: 0.008764],[D fake loss: 0.000000], [G loss(mse): 0.293432, G loss(w): 0.284633]
# Epoch 40/1001
# [D valid loss: 0.008206],[D fake loss: 0.000000], [G loss(mse): 0.288174, G loss(w): 0.284688]
# Epoch 41/1001
# [D valid loss: 0.006475],[D fake loss: 0.000000], [G loss(mse): 0.288267, G loss(w): 0.285040]
# Epoch 42/1001
# [D valid loss: 0.005678],[D fake loss: 0.000000], [G loss(mse): 0.285980, G loss(w): 0.285891]
# Epoch 43/1001
# [D valid loss: 0.004706],[D fake loss: 0.000000], [G loss(mse): 0.283700, G loss(w): 0.283721]
# Epoch 44/1001
# [D valid loss: 0.002605],[D fake loss: 0.000000], [G loss(mse): 0.280365, G loss(w): 0.283824]
# Epoch 45/1001
# [D valid loss: -0.000441],[D fake loss: 0.000000], [G loss(mse): 0.278823, G loss(w): 0.282497]
# Epoch 46/1001
# [D valid loss: -0.001095],[D fake loss: 0.000000], [G loss(mse): 0.280596, G loss(w): 0.283769]
# Epoch 47/1001
# [D valid loss: -0.002436],[D fake loss: 0.000000], [G loss(mse): 0.280454, G loss(w): 0.285869]
# Epoch 48/1001
# [D valid loss: -0.002134],[D fake loss: 0.000000], [G loss(mse): 0.280805, G loss(w): 0.285654]
# Epoch 49/1001
# [D valid loss: -0.004582],[D fake loss: 0.000000], [G loss(mse): 0.278000, G loss(w): 0.283907]
# Epoch 50/1001
# [D valid loss: -0.005532],[D fake loss: 0.000000], [G loss(mse): 0.275713, G loss(w): 0.283351]
# Epoch 51/1001
# [D valid loss: -0.006207],[D fake loss: 0.000000], [G loss(mse): 0.274423, G loss(w): 0.284722]
# Epoch 52/1001
# [D valid loss: -0.006566],[D fake loss: 0.000000], [G loss(mse): 0.276783, G loss(w): 0.284525]
# Epoch 53/1001
# [D valid loss: -0.008763],[D fake loss: 0.000000], [G loss(mse): 0.268655, G loss(w): 0.283668]
# Epoch 54/1001
# [D valid loss: -0.011086],[D fake loss: 0.000000], [G loss(mse): 0.270173, G loss(w): 0.284201]
# Epoch 55/1001
# [D valid loss: -0.011290],[D fake loss: 0.000000], [G loss(mse): 0.270642, G loss(w): 0.283515]
# Epoch 56/1001
# [D valid loss: -0.011102],[D fake loss: 0.000000], [G loss(mse): 0.267381, G loss(w): 0.283385]
# Epoch 57/1001
# [D valid loss: -0.014501],[D fake loss: 0.000000], [G loss(mse): 0.267348, G loss(w): 0.284060]
# Epoch 58/1001
# [D valid loss: -0.014298],[D fake loss: 0.000000], [G loss(mse): 0.266177, G loss(w): 0.284025]
# Epoch 59/1001
# [D valid loss: -0.015821],[D fake loss: 0.000000], [G loss(mse): 0.265427, G loss(w): 0.282948]
# Epoch 60/1001
# [D valid loss: -0.018201],[D fake loss: 0.000000], [G loss(mse): 0.264836, G loss(w): 0.284035]
# Epoch 61/1001
# [D valid loss: -0.019612],[D fake loss: 0.000000], [G loss(mse): 0.260891, G loss(w): 0.285162]
# Epoch 62/1001
# [D valid loss: -0.018906],[D fake loss: 0.000000], [G loss(mse): 0.262926, G loss(w): 0.284195]
# Epoch 63/1001
# [D valid loss: -0.021517],[D fake loss: 0.000000], [G loss(mse): 0.260641, G loss(w): 0.284256]
# Epoch 64/1001
# [D valid loss: -0.022014],[D fake loss: 0.000000], [G loss(mse): 0.257022, G loss(w): 0.283325]
# Epoch 65/1001
# [D valid loss: -0.022870],[D fake loss: 0.000000], [G loss(mse): 0.257527, G loss(w): 0.283645]
# Epoch 66/1001
# [D valid loss: -0.023346],[D fake loss: 0.000000], [G loss(mse): 0.252605, G loss(w): 0.283447]
# Epoch 67/1001
# [D valid loss: -0.025710],[D fake loss: 0.000000], [G loss(mse): 0.252677, G loss(w): 0.283137]
# Epoch 68/1001
# [D valid loss: -0.025036],[D fake loss: 0.000000], [G loss(mse): 0.250691, G loss(w): 0.283376]
# Epoch 69/1001
# [D valid loss: -0.027222],[D fake loss: 0.000000], [G loss(mse): 0.251614, G loss(w): 0.283778]
# Epoch 70/1001
# [D valid loss: -0.028955],[D fake loss: 0.000000], [G loss(mse): 0.251996, G loss(w): 0.284249]
# Epoch 71/1001
# [D valid loss: -0.029528],[D fake loss: 0.000000], [G loss(mse): 0.249617, G loss(w): 0.285327]
# Epoch 72/1001
# [D valid loss: -0.030949],[D fake loss: 0.000000], [G loss(mse): 0.249184, G loss(w): 0.284805]
# Epoch 73/1001
# [D valid loss: -0.032396],[D fake loss: 0.000000], [G loss(mse): 0.247021, G loss(w): 0.282792]
# Epoch 74/1001
# [D valid loss: -0.033431],[D fake loss: 0.000000], [G loss(mse): 0.241496, G loss(w): 0.283384]
# Epoch 75/1001
# [D valid loss: -0.035416],[D fake loss: 0.000000], [G loss(mse): 0.244553, G loss(w): 0.284352]
# Epoch 76/1001
# [D valid loss: -0.035668],[D fake loss: 0.000000], [G loss(mse): 0.243498, G loss(w): 0.283930]
# Epoch 77/1001
# [D valid loss: -0.037201],[D fake loss: 0.000000], [G loss(mse): 0.240437, G loss(w): 0.283469]
# Epoch 78/1001
# [D valid loss: -0.036914],[D fake loss: 0.000000], [G loss(mse): 0.240693, G loss(w): 0.283776]
# Epoch 79/1001
# [D valid loss: -0.039178],[D fake loss: 0.000000], [G loss(mse): 0.237384, G loss(w): 0.283115]
# Epoch 80/1001
# [D valid loss: -0.039527],[D fake loss: 0.000000], [G loss(mse): 0.237638, G loss(w): 0.282680]
# Epoch 81/1001
# [D valid loss: -0.042032],[D fake loss: 0.000000], [G loss(mse): 0.235146, G loss(w): 0.283045]
# Epoch 82/1001
# [D valid loss: -0.043525],[D fake loss: 0.000000], [G loss(mse): 0.237728, G loss(w): 0.284681]
# Epoch 83/1001
# [D valid loss: -0.044050],[D fake loss: 0.000000], [G loss(mse): 0.236312, G loss(w): 0.284056]
# Epoch 84/1001
# [D valid loss: -0.045333],[D fake loss: 0.000000], [G loss(mse): 0.232459, G loss(w): 0.282340]
# Epoch 85/1001
# [D valid loss: -0.046159],[D fake loss: 0.000000], [G loss(mse): 0.231062, G loss(w): 0.282296]
# Epoch 86/1001
# [D valid loss: -0.047677],[D fake loss: 0.000000], [G loss(mse): 0.230721, G loss(w): 0.284374]
# Epoch 87/1001
# [D valid loss: -0.047620],[D fake loss: 0.000000], [G loss(mse): 0.232302, G loss(w): 0.283803]
# Epoch 88/1001
# [D valid loss: -0.050029],[D fake loss: 0.000000], [G loss(mse): 0.228258, G loss(w): 0.283569]
# Epoch 89/1001
# [D valid loss: -0.049360],[D fake loss: 0.000000], [G loss(mse): 0.230136, G loss(w): 0.284377]
# Epoch 90/1001
# [D valid loss: -0.051820],[D fake loss: 0.000000], [G loss(mse): 0.226882, G loss(w): 0.284147]
# Epoch 91/1001
# [D valid loss: -0.053515],[D fake loss: 0.000000], [G loss(mse): 0.226046, G loss(w): 0.284594]
# Epoch 92/1001
# [D valid loss: -0.055182],[D fake loss: 0.000000], [G loss(mse): 0.224508, G loss(w): 0.283191]
# Epoch 93/1001
# [D valid loss: -0.055123],[D fake loss: 0.000000], [G loss(mse): 0.222561, G loss(w): 0.283308]
# Epoch 94/1001
# [D valid loss: -0.056002],[D fake loss: 0.000000], [G loss(mse): 0.220926, G loss(w): 0.283096]
# Epoch 95/1001
# [D valid loss: -0.057015],[D fake loss: 0.000000], [G loss(mse): 0.221854, G loss(w): 0.284122]
# Epoch 96/1001
# [D valid loss: -0.059182],[D fake loss: 0.000000], [G loss(mse): 0.221837, G loss(w): 0.284076]
# Epoch 97/1001
# [D valid loss: -0.059354],[D fake loss: 0.000000], [G loss(mse): 0.217911, G loss(w): 0.282427]
# Epoch 98/1001
# [D valid loss: -0.060706],[D fake loss: 0.000000], [G loss(mse): 0.220344, G loss(w): 0.283912]
# Epoch 99/1001
# [D valid loss: -0.061498],[D fake loss: 0.000000], [G loss(mse): 0.218292, G loss(w): 0.283779]
# Epoch 100/1001
# [D valid loss: -0.062570],[D fake loss: 0.000000], [G loss(mse): 0.213187, G loss(w): 0.283844]
# Epoch 101/1001
# [D valid loss: -0.063591],[D fake loss: 0.000000], [G loss(mse): 0.213870, G loss(w): 0.283231]
# Epoch 102/1001
# [D valid loss: -0.064802],[D fake loss: 0.000000], [G loss(mse): 0.213929, G loss(w): 0.283240]
# Epoch 103/1001
# [D valid loss: -0.066437],[D fake loss: 0.000000], [G loss(mse): 0.213208, G loss(w): 0.282883]
# Epoch 104/1001
# [D valid loss: -0.067460],[D fake loss: 0.000000], [G loss(mse): 0.211132, G loss(w): 0.282266]
# Epoch 105/1001
# [D valid loss: -0.068801],[D fake loss: 0.000000], [G loss(mse): 0.210497, G loss(w): 0.282593]
# Epoch 106/1001
# [D valid loss: -0.070091],[D fake loss: 0.000000], [G loss(mse): 0.210096, G loss(w): 0.283812]
# Epoch 107/1001
# [D valid loss: -0.070718],[D fake loss: 0.000000], [G loss(mse): 0.208251, G loss(w): 0.283281]
# Epoch 108/1001
# [D valid loss: -0.071340],[D fake loss: 0.000000], [G loss(mse): 0.208710, G loss(w): 0.283198]
# Epoch 109/1001
# [D valid loss: -0.072801],[D fake loss: 0.000000], [G loss(mse): 0.204603, G loss(w): 0.282659]
# Epoch 110/1001
# [D valid loss: -0.074479],[D fake loss: 0.000000], [G loss(mse): 0.204941, G loss(w): 0.282818]
# Epoch 111/1001
# [D valid loss: -0.074367],[D fake loss: 0.000000], [G loss(mse): 0.203854, G loss(w): 0.284203]
# Epoch 112/1001
# [D valid loss: -0.075939],[D fake loss: 0.000000], [G loss(mse): 0.202340, G loss(w): 0.283224]
# Epoch 113/1001
# [D valid loss: -0.077545],[D fake loss: 0.000000], [G loss(mse): 0.201159, G loss(w): 0.283876]
# Epoch 114/1001
# [D valid loss: -0.077668],[D fake loss: 0.000000], [G loss(mse): 0.200262, G loss(w): 0.283227]
# Epoch 115/1001
# [D valid loss: -0.078605],[D fake loss: 0.000000], [G loss(mse): 0.201087, G loss(w): 0.283362]
# Epoch 116/1001
# [D valid loss: -0.079685],[D fake loss: 0.000000], [G loss(mse): 0.198446, G loss(w): 0.283826]
# Epoch 117/1001
# [D valid loss: -0.081594],[D fake loss: 0.000000], [G loss(mse): 0.194340, G loss(w): 0.281877]
# Epoch 118/1001
# [D valid loss: -0.081925],[D fake loss: 0.000000], [G loss(mse): 0.196093, G loss(w): 0.282820]
# Epoch 119/1001
# [D valid loss: -0.082913],[D fake loss: 0.000000], [G loss(mse): 0.197904, G loss(w): 0.283318]
# Epoch 120/1001
# [D valid loss: -0.083746],[D fake loss: 0.000000], [G loss(mse): 0.194117, G loss(w): 0.282393]
# Epoch 121/1001
# [D valid loss: -0.085728],[D fake loss: 0.000000], [G loss(mse): 0.191474, G loss(w): 0.283001]
# Epoch 122/1001
# [D valid loss: -0.085737],[D fake loss: 0.000000], [G loss(mse): 0.190539, G loss(w): 0.282393]
# Epoch 123/1001
# [D valid loss: -0.088082],[D fake loss: 0.000000], [G loss(mse): 0.189629, G loss(w): 0.283098]
# Epoch 124/1001
# [D valid loss: -0.087907],[D fake loss: 0.000000], [G loss(mse): 0.190509, G loss(w): 0.282642]
# Epoch 125/1001
# [D valid loss: -0.089377],[D fake loss: 0.000000], [G loss(mse): 0.186207, G loss(w): 0.282331]
# Epoch 126/1001
# [D valid loss: -0.090382],[D fake loss: 0.000000], [G loss(mse): 0.186977, G loss(w): 0.283130]
# Epoch 127/1001
# [D valid loss: -0.091980],[D fake loss: 0.000000], [G loss(mse): 0.186910, G loss(w): 0.282585]
# Epoch 128/1001
# [D valid loss: -0.092739],[D fake loss: 0.000000], [G loss(mse): 0.186530, G loss(w): 0.283118]
# Epoch 129/1001
# [D valid loss: -0.093578],[D fake loss: 0.000000], [G loss(mse): 0.184335, G loss(w): 0.283036]
# Epoch 130/1001
# [D valid loss: -0.094612],[D fake loss: 0.000000], [G loss(mse): 0.183869, G loss(w): 0.282873]
# Epoch 131/1001
# [D valid loss: -0.095972],[D fake loss: 0.000000], [G loss(mse): 0.183978, G loss(w): 0.283238]
# Epoch 132/1001
# [D valid loss: -0.097008],[D fake loss: 0.000000], [G loss(mse): 0.181165, G loss(w): 0.282864]
# Epoch 133/1001
# [D valid loss: -0.097699],[D fake loss: 0.000000], [G loss(mse): 0.179292, G loss(w): 0.282566]
# Epoch 134/1001
# [D valid loss: -0.098667],[D fake loss: 0.000000], [G loss(mse): 0.180853, G loss(w): 0.283207]
# Epoch 135/1001
# [D valid loss: -0.099758],[D fake loss: 0.000000], [G loss(mse): 0.181043, G loss(w): 0.283845]
# Epoch 136/1001
# [D valid loss: -0.100889],[D fake loss: 0.000000], [G loss(mse): 0.178166, G loss(w): 0.283585]
# Epoch 137/1001
# [D valid loss: -0.102378],[D fake loss: 0.000000], [G loss(mse): 0.176519, G loss(w): 0.282383]
# Epoch 138/1001
# [D valid loss: -0.102372],[D fake loss: 0.000000], [G loss(mse): 0.176369, G loss(w): 0.283032]
# Epoch 139/1001
# [D valid loss: -0.104472],[D fake loss: 0.000000], [G loss(mse): 0.174470, G loss(w): 0.283035]
# Epoch 140/1001
# [D valid loss: -0.104281],[D fake loss: 0.000000], [G loss(mse): 0.173452, G loss(w): 0.282593]
# Epoch 141/1001
# [D valid loss: -0.106133],[D fake loss: 0.000000], [G loss(mse): 0.172796, G loss(w): 0.283284]
# Epoch 142/1001
# [D valid loss: -0.107052],[D fake loss: 0.000000], [G loss(mse): 0.171239, G loss(w): 0.282166]
# Epoch 143/1001
# [D valid loss: -0.107833],[D fake loss: 0.000000], [G loss(mse): 0.170429, G loss(w): 0.282519]
# Epoch 144/1001
# [D valid loss: -0.108981],[D fake loss: 0.000000], [G loss(mse): 0.170142, G loss(w): 0.283642]
# Epoch 145/1001
# [D valid loss: -0.110255],[D fake loss: 0.000000], [G loss(mse): 0.167106, G loss(w): 0.282206]
# Epoch 146/1001
# [D valid loss: -0.110791],[D fake loss: 0.000000], [G loss(mse): 0.167085, G loss(w): 0.282091]
# Epoch 147/1001
# [D valid loss: -0.111840],[D fake loss: 0.000000], [G loss(mse): 0.167938, G loss(w): 0.283148]
# Epoch 148/1001
# [D valid loss: -0.113370],[D fake loss: 0.000000], [G loss(mse): 0.165290, G loss(w): 0.281998]
# Epoch 149/1001
# [D valid loss: -0.114622],[D fake loss: 0.000000], [G loss(mse): 0.165402, G loss(w): 0.283186]
# Epoch 150/1001
# [D valid loss: -0.114928],[D fake loss: 0.000000], [G loss(mse): 0.163867, G loss(w): 0.282428]
# Epoch 151/1001
# [D valid loss: -0.115826],[D fake loss: 0.000000], [G loss(mse): 0.162779, G loss(w): 0.282796]
# Epoch 152/1001
# [D valid loss: -0.116942],[D fake loss: 0.000000], [G loss(mse): 0.160011, G loss(w): 0.281891]
# Epoch 153/1001
# [D valid loss: -0.117481],[D fake loss: 0.000000], [G loss(mse): 0.162273, G loss(w): 0.283578]
# Epoch 154/1001
# [D valid loss: -0.119538],[D fake loss: 0.000000], [G loss(mse): 0.159128, G loss(w): 0.282330]
# Epoch 155/1001
# [D valid loss: -0.119799],[D fake loss: 0.000000], [G loss(mse): 0.159405, G loss(w): 0.282578]
# Epoch 156/1001
# [D valid loss: -0.121224],[D fake loss: 0.000000], [G loss(mse): 0.157204, G loss(w): 0.282336]
# Epoch 157/1001
# [D valid loss: -0.121936],[D fake loss: 0.000000], [G loss(mse): 0.156379, G loss(w): 0.281337]
# Epoch 158/1001
# [D valid loss: -0.122490],[D fake loss: 0.000000], [G loss(mse): 0.156398, G loss(w): 0.283140]
# Epoch 159/1001
# [D valid loss: -0.124596],[D fake loss: 0.000000], [G loss(mse): 0.153973, G loss(w): 0.282742]
# Epoch 160/1001
# [D valid loss: -0.124314],[D fake loss: 0.000000], [G loss(mse): 0.152323, G loss(w): 0.282209]
# Epoch 161/1001
# [D valid loss: -0.125857],[D fake loss: 0.000000], [G loss(mse): 0.152232, G loss(w): 0.281853]
# Epoch 162/1001
# [D valid loss: -0.126871],[D fake loss: 0.000000], [G loss(mse): 0.152848, G loss(w): 0.282779]
# Epoch 163/1001
# [D valid loss: -0.127809],[D fake loss: 0.000000], [G loss(mse): 0.151817, G loss(w): 0.285138]
# Epoch 164/1001
# [D valid loss: -0.129161],[D fake loss: 0.000000], [G loss(mse): 0.149824, G loss(w): 0.283259]
# Epoch 165/1001
# [D valid loss: -0.130155],[D fake loss: 0.000000], [G loss(mse): 0.148698, G loss(w): 0.283061]
# Epoch 166/1001
# [D valid loss: -0.130729],[D fake loss: 0.000000], [G loss(mse): 0.147820, G loss(w): 0.281508]
# Epoch 167/1001
# [D valid loss: -0.131911],[D fake loss: 0.000000], [G loss(mse): 0.147284, G loss(w): 0.282352]
# Epoch 168/1001
# [D valid loss: -0.132837],[D fake loss: 0.000000], [G loss(mse): 0.147121, G loss(w): 0.282711]
# Epoch 169/1001
# [D valid loss: -0.134188],[D fake loss: 0.000000], [G loss(mse): 0.144868, G loss(w): 0.283284]
# Epoch 170/1001
# [D valid loss: -0.135435],[D fake loss: 0.000000], [G loss(mse): 0.143355, G loss(w): 0.282669]
# Epoch 171/1001
# [D valid loss: -0.135817],[D fake loss: 0.000000], [G loss(mse): 0.142573, G loss(w): 0.281873]
# Epoch 172/1001
# [D valid loss: -0.136850],[D fake loss: 0.000000], [G loss(mse): 0.140054, G loss(w): 0.282006]
# Epoch 173/1001
# [D valid loss: -0.138074],[D fake loss: 0.000000], [G loss(mse): 0.141112, G loss(w): 0.282685]
# Epoch 174/1001
# [D valid loss: -0.138810],[D fake loss: 0.000000], [G loss(mse): 0.139474, G loss(w): 0.281803]
# Epoch 175/1001
# [D valid loss: -0.139733],[D fake loss: 0.000000], [G loss(mse): 0.138233, G loss(w): 0.282260]
# Epoch 176/1001
# [D valid loss: -0.140421],[D fake loss: 0.000000], [G loss(mse): 0.137847, G loss(w): 0.282439]
# Epoch 177/1001
# [D valid loss: -0.141936],[D fake loss: 0.000000], [G loss(mse): 0.136925, G loss(w): 0.282083]
# Epoch 178/1001
# [D valid loss: -0.142634],[D fake loss: 0.000000], [G loss(mse): 0.136375, G loss(w): 0.282783]
# Epoch 179/1001
# [D valid loss: -0.142937],[D fake loss: 0.000000], [G loss(mse): 0.135775, G loss(w): 0.282498]
# Epoch 180/1001
# [D valid loss: -0.144742],[D fake loss: 0.000000], [G loss(mse): 0.134091, G loss(w): 0.282925]
# Epoch 181/1001
# [D valid loss: -0.145729],[D fake loss: 0.000000], [G loss(mse): 0.133662, G loss(w): 0.282235]
# Epoch 182/1001
# [D valid loss: -0.146622],[D fake loss: 0.000000], [G loss(mse): 0.133104, G loss(w): 0.283316]
# Epoch 183/1001
# [D valid loss: -0.147664],[D fake loss: 0.000000], [G loss(mse): 0.131136, G loss(w): 0.283039]
# Epoch 184/1001
# [D valid loss: -0.148698],[D fake loss: 0.000000], [G loss(mse): 0.132170, G loss(w): 0.282963]
# Epoch 185/1001
# [D valid loss: -0.149797],[D fake loss: 0.000000], [G loss(mse): 0.128528, G loss(w): 0.281630]
# Epoch 186/1001
# [D valid loss: -0.150650],[D fake loss: 0.000000], [G loss(mse): 0.128527, G loss(w): 0.282431]
# Epoch 187/1001
# [D valid loss: -0.151276],[D fake loss: 0.000000], [G loss(mse): 0.126629, G loss(w): 0.281233]
# Epoch 188/1001
# [D valid loss: -0.152678],[D fake loss: 0.000000], [G loss(mse): 0.126595, G loss(w): 0.281609]
# Epoch 189/1001
# [D valid loss: -0.153327],[D fake loss: 0.000000], [G loss(mse): 0.124654, G loss(w): 0.281879]
# Epoch 190/1001
# [D valid loss: -0.154445],[D fake loss: 0.000000], [G loss(mse): 0.123471, G loss(w): 0.281060]
# Epoch 191/1001
# [D valid loss: -0.155347],[D fake loss: 0.000000], [G loss(mse): 0.122760, G loss(w): 0.281347]
# Epoch 192/1001
# [D valid loss: -0.156273],[D fake loss: 0.000000], [G loss(mse): 0.121078, G loss(w): 0.280821]
# Epoch 193/1001
# [D valid loss: -0.157201],[D fake loss: 0.000000], [G loss(mse): 0.120702, G loss(w): 0.281664]
# Epoch 194/1001
# [D valid loss: -0.158010],[D fake loss: 0.000000], [G loss(mse): 0.121038, G loss(w): 0.281976]
# Epoch 195/1001
# [D valid loss: -0.159235],[D fake loss: 0.000000], [G loss(mse): 0.118795, G loss(w): 0.281038]
# Epoch 196/1001
# [D valid loss: -0.160393],[D fake loss: 0.000000], [G loss(mse): 0.119689, G loss(w): 0.283017]
# Epoch 197/1001
# [D valid loss: -0.161199],[D fake loss: 0.000000], [G loss(mse): 0.118358, G loss(w): 0.282263]
# Epoch 198/1001
# [D valid loss: -0.162165],[D fake loss: 0.000000], [G loss(mse): 0.116011, G loss(w): 0.281138]
# Epoch 199/1001
# [D valid loss: -0.162757],[D fake loss: 0.000000], [G loss(mse): 0.113657, G loss(w): 0.279669]
# Epoch 200/1001
# [D valid loss: -0.163564],[D fake loss: 0.000000], [G loss(mse): 0.114877, G loss(w): 0.281451]
# Epoch 201/1001
# [D valid loss: -0.164955],[D fake loss: 0.000000], [G loss(mse): 0.111003, G loss(w): 0.279249]
# Epoch 202/1001
# [D valid loss: -0.166001],[D fake loss: 0.000000], [G loss(mse): 0.115008, G loss(w): 0.283400]
# Epoch 203/1001
# [D valid loss: -0.166521],[D fake loss: 0.000000], [G loss(mse): 0.110845, G loss(w): 0.280164]
# Epoch 204/1001
# [D valid loss: -0.167425],[D fake loss: 0.000000], [G loss(mse): 0.111177, G loss(w): 0.282186]
# Epoch 205/1001
# [D valid loss: -0.168789],[D fake loss: 0.000000], [G loss(mse): 0.112528, G loss(w): 0.283496]
# Epoch 206/1001
# [D valid loss: -0.169908],[D fake loss: 0.000000], [G loss(mse): 0.108472, G loss(w): 0.281147]
# Epoch 207/1001
# [D valid loss: -0.170346],[D fake loss: 0.000000], [G loss(mse): 0.108636, G loss(w): 0.281733]
# Epoch 208/1001
# [D valid loss: -0.171482],[D fake loss: 0.000000], [G loss(mse): 0.107542, G loss(w): 0.281985]
# Epoch 209/1001
# [D valid loss: -0.172512],[D fake loss: 0.000000], [G loss(mse): 0.106265, G loss(w): 0.281552]
# Epoch 210/1001
# [D valid loss: -0.173073],[D fake loss: 0.000000], [G loss(mse): 0.107143, G loss(w): 0.282916]
# Epoch 211/1001
# [D valid loss: -0.174151],[D fake loss: 0.000000], [G loss(mse): 0.104079, G loss(w): 0.281799]
# Epoch 212/1001
# [D valid loss: -0.175601],[D fake loss: 0.000000], [G loss(mse): 0.102498, G loss(w): 0.280974]
# Epoch 213/1001
# [D valid loss: -0.176485],[D fake loss: 0.000000], [G loss(mse): 0.102740, G loss(w): 0.281633]
# Epoch 214/1001
# [D valid loss: -0.176948],[D fake loss: 0.000000], [G loss(mse): 0.101195, G loss(w): 0.281649]
# Epoch 215/1001
# [D valid loss: -0.178398],[D fake loss: 0.000000], [G loss(mse): 0.101671, G loss(w): 0.282469]
# Epoch 216/1001
# [D valid loss: -0.179153],[D fake loss: 0.000000], [G loss(mse): 0.099925, G loss(w): 0.282053]
# Epoch 217/1001
# [D valid loss: -0.180057],[D fake loss: 0.000000], [G loss(mse): 0.100234, G loss(w): 0.283065]
# Epoch 218/1001
# [D valid loss: -0.181240],[D fake loss: 0.000000], [G loss(mse): 0.098713, G loss(w): 0.281243]
# Epoch 219/1001
# [D valid loss: -0.181584],[D fake loss: 0.000000], [G loss(mse): 0.097153, G loss(w): 0.282084]
# Epoch 220/1001
# [D valid loss: -0.182383],[D fake loss: 0.000000], [G loss(mse): 0.095405, G loss(w): 0.280750]
# Epoch 221/1001
# [D valid loss: -0.183860],[D fake loss: 0.000000], [G loss(mse): 0.096431, G loss(w): 0.282413]
# Epoch 222/1001
# [D valid loss: -0.184930],[D fake loss: 0.000000], [G loss(mse): 0.093615, G loss(w): 0.281271]
# Epoch 223/1001
# [D valid loss: -0.185334],[D fake loss: 0.000000], [G loss(mse): 0.094543, G loss(w): 0.282804]
# Epoch 224/1001
# [D valid loss: -0.186556],[D fake loss: 0.000000], [G loss(mse): 0.093386, G loss(w): 0.282780]
# Epoch 225/1001
# [D valid loss: -0.187490],[D fake loss: 0.000000], [G loss(mse): 0.091924, G loss(w): 0.281707]
# Epoch 226/1001
# [D valid loss: -0.188243],[D fake loss: 0.000000], [G loss(mse): 0.089618, G loss(w): 0.280293]
# Epoch 227/1001
# [D valid loss: -0.189464],[D fake loss: 0.000000], [G loss(mse): 0.088395, G loss(w): 0.280760]
# Epoch 228/1001
# [D valid loss: -0.190298],[D fake loss: 0.000000], [G loss(mse): 0.089517, G loss(w): 0.281928]
# Epoch 229/1001
# [D valid loss: -0.190661],[D fake loss: 0.000000], [G loss(mse): 0.086974, G loss(w): 0.280496]
# Epoch 230/1001
# [D valid loss: -0.192076],[D fake loss: 0.000000], [G loss(mse): 0.085877, G loss(w): 0.280489]
# Epoch 231/1001
# [D valid loss: -0.193121],[D fake loss: 0.000000], [G loss(mse): 0.085603, G loss(w): 0.281131]
# Epoch 232/1001
# [D valid loss: -0.193843],[D fake loss: 0.000000], [G loss(mse): 0.083663, G loss(w): 0.280092]
# Epoch 233/1001
# [D valid loss: -0.194765],[D fake loss: 0.000000], [G loss(mse): 0.084150, G loss(w): 0.281573]
# Epoch 234/1001
# [D valid loss: -0.195796],[D fake loss: 0.000000], [G loss(mse): 0.082023, G loss(w): 0.280446]
# Epoch 235/1001
# [D valid loss: -0.196959],[D fake loss: 0.000000], [G loss(mse): 0.079624, G loss(w): 0.278606]
# Epoch 236/1001
# [D valid loss: -0.197825],[D fake loss: 0.000000], [G loss(mse): 0.079875, G loss(w): 0.279648]
# Epoch 237/1001
# [D valid loss: -0.198371],[D fake loss: 0.000000], [G loss(mse): 0.078507, G loss(w): 0.279379]
# Epoch 238/1001
# [D valid loss: -0.199473],[D fake loss: 0.000000], [G loss(mse): 0.078982, G loss(w): 0.280616]
# Epoch 239/1001
# [D valid loss: -0.200504],[D fake loss: 0.000000], [G loss(mse): 0.078059, G loss(w): 0.281068]
# Epoch 240/1001
# [D valid loss: -0.201142],[D fake loss: 0.000000], [G loss(mse): 0.077700, G loss(w): 0.281633]
# Epoch 241/1001
# [D valid loss: -0.202320],[D fake loss: 0.000000], [G loss(mse): 0.076136, G loss(w): 0.280524]
# Epoch 242/1001
# [D valid loss: -0.203322],[D fake loss: 0.000000], [G loss(mse): 0.077400, G loss(w): 0.282639]
# Epoch 243/1001
# [D valid loss: -0.204194],[D fake loss: 0.000000], [G loss(mse): 0.074096, G loss(w): 0.280419]
# Epoch 244/1001
# [D valid loss: -0.205028],[D fake loss: 0.000000], [G loss(mse): 0.072846, G loss(w): 0.280536]
# Epoch 245/1001
# [D valid loss: -0.205837],[D fake loss: 0.000000], [G loss(mse): 0.073317, G loss(w): 0.281269]
# Epoch 246/1001
# [D valid loss: -0.206853],[D fake loss: 0.000000], [G loss(mse): 0.072588, G loss(w): 0.281896]
# Epoch 247/1001
# [D valid loss: -0.207896],[D fake loss: 0.000000], [G loss(mse): 0.071313, G loss(w): 0.281054]
# Epoch 248/1001
# [D valid loss: -0.208772],[D fake loss: 0.000000], [G loss(mse): 0.069909, G loss(w): 0.280787]
# Epoch 249/1001
# [D valid loss: -0.209480],[D fake loss: 0.000000], [G loss(mse): 0.069015, G loss(w): 0.280827]
# Epoch 250/1001
# [D valid loss: -0.210413],[D fake loss: 0.000000], [G loss(mse): 0.068112, G loss(w): 0.280937]
# Epoch 251/1001
# [D valid loss: -0.211396],[D fake loss: 0.000000], [G loss(mse): 0.066250, G loss(w): 0.279621]
# Epoch 252/1001
# [D valid loss: -0.212447],[D fake loss: 0.000000], [G loss(mse): 0.065755, G loss(w): 0.279987]
# Epoch 253/1001
# [D valid loss: -0.213113],[D fake loss: 0.000000], [G loss(mse): 0.063161, G loss(w): 0.278762]
# Epoch 254/1001
# [D valid loss: -0.214264],[D fake loss: 0.000000], [G loss(mse): 0.065057, G loss(w): 0.280927]
# Epoch 255/1001
# [D valid loss: -0.214933],[D fake loss: 0.000000], [G loss(mse): 0.062071, G loss(w): 0.279461]
# Epoch 256/1001
# [D valid loss: -0.216157],[D fake loss: 0.000000], [G loss(mse): 0.061654, G loss(w): 0.280116]
# Epoch 257/1001
# [D valid loss: -0.216861],[D fake loss: 0.000000], [G loss(mse): 0.062494, G loss(w): 0.280976]
# Epoch 258/1001
# [D valid loss: -0.217714],[D fake loss: 0.000000], [G loss(mse): 0.058875, G loss(w): 0.278402]
# Epoch 259/1001
# [D valid loss: -0.218760],[D fake loss: 0.000000], [G loss(mse): 0.059935, G loss(w): 0.280706]
# Epoch 260/1001
# [D valid loss: -0.219589],[D fake loss: 0.000000], [G loss(mse): 0.059370, G loss(w): 0.281023]
# Epoch 261/1001
# [D valid loss: -0.220820],[D fake loss: 0.000000], [G loss(mse): 0.058081, G loss(w): 0.280360]
# Epoch 262/1001
# [D valid loss: -0.221400],[D fake loss: 0.000000], [G loss(mse): 0.056923, G loss(w): 0.280076]
# Epoch 263/1001
# [D valid loss: -0.222223],[D fake loss: 0.000000], [G loss(mse): 0.054772, G loss(w): 0.279035]
# Epoch 264/1001
# [D valid loss: -0.223208],[D fake loss: 0.000000], [G loss(mse): 0.054667, G loss(w): 0.279629]
# Epoch 265/1001
# [D valid loss: -0.224211],[D fake loss: 0.000000], [G loss(mse): 0.054758, G loss(w): 0.280888]
# Epoch 266/1001
# [D valid loss: -0.224997],[D fake loss: 0.000000], [G loss(mse): 0.051249, G loss(w): 0.278120]
# Epoch 267/1001
# [D valid loss: -0.226088],[D fake loss: 0.000000], [G loss(mse): 0.051608, G loss(w): 0.279439]
# Epoch 268/1001
# [D valid loss: -0.226902],[D fake loss: 0.000000], [G loss(mse): 0.051268, G loss(w): 0.280289]
# Epoch 269/1001
# [D valid loss: -0.227798],[D fake loss: 0.000000], [G loss(mse): 0.047851, G loss(w): 0.277541]
# Epoch 270/1001
# [D valid loss: -0.228633],[D fake loss: 0.000000], [G loss(mse): 0.051159, G loss(w): 0.281702]
# Epoch 271/1001
# [D valid loss: -0.229563],[D fake loss: 0.000000], [G loss(mse): 0.048430, G loss(w): 0.279691]
# Epoch 272/1001
# [D valid loss: -0.230549],[D fake loss: 0.000000], [G loss(mse): 0.044304, G loss(w): 0.276910]
# Epoch 273/1001
# [D valid loss: -0.231308],[D fake loss: 0.000000], [G loss(mse): 0.046434, G loss(w): 0.279629]
# Epoch 274/1001
# [D valid loss: -0.232350],[D fake loss: 0.000000], [G loss(mse): 0.044009, G loss(w): 0.278315]
# Epoch 275/1001
# [D valid loss: -0.233445],[D fake loss: 0.000000], [G loss(mse): 0.044869, G loss(w): 0.279920]
# Epoch 276/1001
# [D valid loss: -0.234040],[D fake loss: 0.000000], [G loss(mse): 0.044642, G loss(w): 0.280370]
# Epoch 277/1001
# [D valid loss: -0.234994],[D fake loss: 0.000000], [G loss(mse): 0.043074, G loss(w): 0.279992]
# Epoch 278/1001
# [D valid loss: -0.235977],[D fake loss: 0.000000], [G loss(mse): 0.042670, G loss(w): 0.280136]
# Epoch 279/1001
# [D valid loss: -0.236759],[D fake loss: 0.000000], [G loss(mse): 0.040373, G loss(w): 0.279096]
# Epoch 280/1001
# [D valid loss: -0.237689],[D fake loss: 0.000000], [G loss(mse): 0.039640, G loss(w): 0.279297]
# Epoch 281/1001
# [D valid loss: -0.238833],[D fake loss: 0.000000], [G loss(mse): 0.039627, G loss(w): 0.279745]
# Epoch 282/1001
# [D valid loss: -0.239325],[D fake loss: 0.000000], [G loss(mse): 0.037806, G loss(w): 0.278691]
# Epoch 283/1001
# [D valid loss: -0.240369],[D fake loss: 0.000000], [G loss(mse): 0.036285, G loss(w): 0.278089]
# Epoch 284/1001
# [D valid loss: -0.241395],[D fake loss: 0.000000], [G loss(mse): 0.034557, G loss(w): 0.277648]
# Epoch 285/1001
# [D valid loss: -0.242262],[D fake loss: 0.000000], [G loss(mse): 0.035026, G loss(w): 0.278733]
# Epoch 286/1001
# [D valid loss: -0.243190],[D fake loss: 0.000000], [G loss(mse): 0.037086, G loss(w): 0.281725]
# Epoch 287/1001
# [D valid loss: -0.244087],[D fake loss: 0.000000], [G loss(mse): 0.031871, G loss(w): 0.277353]
# Epoch 288/1001
# [D valid loss: -0.244939],[D fake loss: 0.000000], [G loss(mse): 0.030520, G loss(w): 0.276816]
# Epoch 289/1001
# [D valid loss: -0.245995],[D fake loss: 0.000000], [G loss(mse): 0.033493, G loss(w): 0.280758]
# Epoch 290/1001
# [D valid loss: -0.246819],[D fake loss: 0.000000], [G loss(mse): 0.030140, G loss(w): 0.278429]
# Epoch 291/1001
# [D valid loss: -0.247635],[D fake loss: 0.000000], [G loss(mse): 0.031502, G loss(w): 0.280603]
# Epoch 292/1001
# [D valid loss: -0.248717],[D fake loss: 0.000000], [G loss(mse): 0.029788, G loss(w): 0.279628]
# Epoch 293/1001
# [D valid loss: -0.249461],[D fake loss: 0.000000], [G loss(mse): 0.025706, G loss(w): 0.276589]
# Epoch 294/1001
# [D valid loss: -0.250306],[D fake loss: 0.000000], [G loss(mse): 0.025914, G loss(w): 0.277680]
# Epoch 295/1001
# [D valid loss: -0.251237],[D fake loss: 0.000000], [G loss(mse): 0.024454, G loss(w): 0.277204]
# Epoch 296/1001
# [D valid loss: -0.252190],[D fake loss: 0.000000], [G loss(mse): 0.023382, G loss(w): 0.276778]
# Epoch 297/1001
# [D valid loss: -0.253024],[D fake loss: 0.000000], [G loss(mse): 0.024503, G loss(w): 0.278844]
# Epoch 298/1001
# [D valid loss: -0.253794],[D fake loss: 0.000000], [G loss(mse): 0.028051, G loss(w): 0.283172]
# Epoch 299/1001
# [D valid loss: -0.254848],[D fake loss: 0.000000], [G loss(mse): 0.023440, G loss(w): 0.279364]
# Epoch 300/1001
# [D valid loss: -0.255801],[D fake loss: 0.000000], [G loss(mse): 0.022596, G loss(w): 0.279681]
# Epoch 301/1001
# [D valid loss: -0.256601],[D fake loss: 0.000000], [G loss(mse): 0.019382, G loss(w): 0.277073]
# Epoch 302/1001
# [D valid loss: -0.257553],[D fake loss: 0.000000], [G loss(mse): 0.021012, G loss(w): 0.279775]
# Epoch 303/1001
# [D valid loss: -0.258354],[D fake loss: 0.000000], [G loss(mse): 0.019274, G loss(w): 0.278755]
# Epoch 304/1001
# [D valid loss: -0.259326],[D fake loss: 0.000000], [G loss(mse): 0.016998, G loss(w): 0.277355]
# Epoch 305/1001
# [D valid loss: -0.260244],[D fake loss: 0.000000], [G loss(mse): 0.016155, G loss(w): 0.277432]
# Epoch 306/1001
# [D valid loss: -0.261052],[D fake loss: 0.000000], [G loss(mse): 0.015119, G loss(w): 0.277182]
# Epoch 307/1001
# [D valid loss: -0.262043],[D fake loss: 0.000000], [G loss(mse): 0.013682, G loss(w): 0.276831]
# Epoch 308/1001
# [D valid loss: -0.262886],[D fake loss: 0.000000], [G loss(mse): 0.014308, G loss(w): 0.278465]
# Epoch 309/1001
# [D valid loss: -0.263826],[D fake loss: 0.000000], [G loss(mse): 0.012094, G loss(w): 0.277061]
# Epoch 310/1001
# [D valid loss: -0.264693],[D fake loss: 0.000000], [G loss(mse): 0.011676, G loss(w): 0.277392]
# Epoch 311/1001
# [D valid loss: -0.265600],[D fake loss: 0.000000], [G loss(mse): 0.012518, G loss(w): 0.279123]
# Epoch 312/1001
# [D valid loss: -0.266535],[D fake loss: 0.000000], [G loss(mse): 0.008453, G loss(w): 0.276045]
# Epoch 313/1001
# [D valid loss: -0.267298],[D fake loss: 0.000000], [G loss(mse): 0.007787, G loss(w): 0.276178]
# Epoch 314/1001
# [D valid loss: -0.268280],[D fake loss: 0.000000], [G loss(mse): 0.006091, G loss(w): 0.275444]
# Epoch 315/1001
# [D valid loss: -0.269176],[D fake loss: 0.000000], [G loss(mse): 0.008809, G loss(w): 0.279031]
# Epoch 316/1001
# [D valid loss: -0.270059],[D fake loss: 0.000000], [G loss(mse): 0.007206, G loss(w): 0.278226]
# Epoch 317/1001
# [D valid loss: -0.270907],[D fake loss: 0.000000], [G loss(mse): 0.004483, G loss(w): 0.276612]
# Epoch 318/1001
# [D valid loss: -0.271887],[D fake loss: 0.000000], [G loss(mse): 0.002759, G loss(w): 0.275495]
# Epoch 319/1001
# [D valid loss: -0.272739],[D fake loss: 0.000000], [G loss(mse): 0.001493, G loss(w): 0.275063]
# Epoch 320/1001
# [D valid loss: -0.273599],[D fake loss: 0.000000], [G loss(mse): 0.000733, G loss(w): 0.275301]
# Epoch 321/1001
# [D valid loss: -0.274518],[D fake loss: 0.000000], [G loss(mse): 0.000129, G loss(w): 0.275540]
# Epoch 322/1001
# [D valid loss: -0.275397],[D fake loss: 0.000000], [G loss(mse): 0.002020, G loss(w): 0.278217]
# Epoch 323/1001
# [D valid loss: -0.276241],[D fake loss: 0.000000], [G loss(mse): -0.001453, G loss(w): 0.275780]
# Epoch 324/1001
# [D valid loss: -0.277193],[D fake loss: 0.000000], [G loss(mse): -0.002615, G loss(w): 0.275483]
# Epoch 325/1001
# [D valid loss: -0.278056],[D fake loss: 0.000000], [G loss(mse): -0.000717, G loss(w): 0.278100]
# Epoch 326/1001
# [D valid loss: -0.278952],[D fake loss: 0.000000], [G loss(mse): -0.005400, G loss(w): 0.274485]
# Epoch 327/1001
# [D valid loss: -0.279836],[D fake loss: 0.000000], [G loss(mse): -0.003208, G loss(w): 0.277493]
# Epoch 328/1001
# [D valid loss: -0.280692],[D fake loss: 0.000000], [G loss(mse): -0.005081, G loss(w): 0.276437]
# Epoch 329/1001
# [D valid loss: -0.281606],[D fake loss: 0.000000], [G loss(mse): -0.008118, G loss(w): 0.274352]
# Epoch 330/1001
# [D valid loss: -0.282553],[D fake loss: 0.000000], [G loss(mse): -0.008146, G loss(w): 0.275185]
# Epoch 331/1001
# [D valid loss: -0.283409],[D fake loss: 0.000000], [G loss(mse): -0.009008, G loss(w): 0.275186]
# Epoch 332/1001
# [D valid loss: -0.284279],[D fake loss: 0.000000], [G loss(mse): -0.011959, G loss(w): 0.273142]
# Epoch 333/1001
# [D valid loss: -0.285203],[D fake loss: 0.000000], [G loss(mse): -0.013110, G loss(w): 0.272796]
# Epoch 334/1001
# [D valid loss: -0.286049],[D fake loss: 0.000000], [G loss(mse): -0.010678, G loss(w): 0.276048]
# Epoch 335/1001
# [D valid loss: -0.286961],[D fake loss: 0.000000], [G loss(mse): -0.011108, G loss(w): 0.276585]
# Epoch 336/1001
# [D valid loss: -0.287854],[D fake loss: 0.000000], [G loss(mse): -0.013392, G loss(w): 0.275179]
# Epoch 337/1001
# [D valid loss: -0.288756],[D fake loss: 0.000000], [G loss(mse): -0.017247, G loss(w): 0.272202]
# Epoch 338/1001
# [D valid loss: -0.289649],[D fake loss: 0.000000], [G loss(mse): -0.014775, G loss(w): 0.275509]
# Epoch 339/1001
# [D valid loss: -0.290510],[D fake loss: 0.000000], [G loss(mse): -0.011446, G loss(w): 0.279729]
# Epoch 340/1001
# [D valid loss: -0.291434],[D fake loss: 0.000000], [G loss(mse): -0.013253, G loss(w): 0.278791]
# Epoch 341/1001
# [D valid loss: -0.292287],[D fake loss: 0.000000], [G loss(mse): -0.017707, G loss(w): 0.275236]
# Epoch 342/1001
# [D valid loss: -0.293194],[D fake loss: 0.000000], [G loss(mse): -0.017758, G loss(w): 0.276060]
# Epoch 343/1001
# [D valid loss: -0.294073],[D fake loss: 0.000000], [G loss(mse): -0.021694, G loss(w): 0.272984]
# Epoch 344/1001
# [D valid loss: -0.294968],[D fake loss: 0.000000], [G loss(mse): -0.020517, G loss(w): 0.275046]
# Epoch 345/1001
# [D valid loss: -0.295858],[D fake loss: 0.000000], [G loss(mse): -0.023174, G loss(w): 0.273272]
# Epoch 346/1001
# [D valid loss: -0.296755],[D fake loss: 0.000000], [G loss(mse): -0.027895, G loss(w): 0.269425]
# Epoch 347/1001
# [D valid loss: -0.297645],[D fake loss: 0.000000], [G loss(mse): -0.022756, G loss(w): 0.275429]
# Epoch 348/1001
# [D valid loss: -0.298530],[D fake loss: 0.000000], [G loss(mse): -0.026311, G loss(w): 0.272759]
# Epoch 349/1001
# [D valid loss: -0.299417],[D fake loss: 0.000000], [G loss(mse): -0.027107, G loss(w): 0.272835]
# Epoch 350/1001
# [D valid loss: -0.300308],[D fake loss: 0.000000], [G loss(mse): -0.027383, G loss(w): 0.273434]
# Epoch 351/1001
# [D valid loss: -0.301198],[D fake loss: 0.000000], [G loss(mse): -0.029668, G loss(w): 0.272023]
# Epoch 352/1001
# [D valid loss: -0.302087],[D fake loss: 0.000000], [G loss(mse): -0.024651, G loss(w): 0.277913]
# Epoch 353/1001
# [D valid loss: -0.302981],[D fake loss: 0.000000], [G loss(mse): -0.033659, G loss(w): 0.269792]
# Epoch 354/1001
# [D valid loss: -0.303864],[D fake loss: 0.000000], [G loss(mse): -0.031219, G loss(w): 0.273119]
# Epoch 355/1001
# [D valid loss: -0.304750],[D fake loss: 0.000000], [G loss(mse): -0.028568, G loss(w): 0.276653]
# Epoch 356/1001
# [D valid loss: -0.305646],[D fake loss: 0.000000], [G loss(mse): -0.031978, G loss(w): 0.274089]
# Epoch 357/1001
# [D valid loss: -0.306529],[D fake loss: 0.000000], [G loss(mse): -0.034459, G loss(w): 0.272513]
# Epoch 358/1001
# [D valid loss: -0.307433],[D fake loss: 0.000000], [G loss(mse): -0.032852, G loss(w): 0.274956]
# Epoch 359/1001
# [D valid loss: -0.308305],[D fake loss: 0.000000], [G loss(mse): -0.034205, G loss(w): 0.274489]
# Epoch 360/1001
# [D valid loss: -0.309232],[D fake loss: 0.000000], [G loss(mse): -0.033298, G loss(w): 0.276297]
# Epoch 361/1001
# [D valid loss: -0.310114],[D fake loss: 0.000000], [G loss(mse): -0.038158, G loss(w): 0.272292]
# Epoch 362/1001
# [D valid loss: -0.311006],[D fake loss: 0.000000], [G loss(mse): -0.035674, G loss(w): 0.275628]
# Epoch 363/1001
# [D valid loss: -0.311888],[D fake loss: 0.000000], [G loss(mse): -0.038338, G loss(w): 0.273897]
# Epoch 364/1001
# [D valid loss: -0.312781],[D fake loss: 0.000000], [G loss(mse): -0.041962, G loss(w): 0.271099]
# Epoch 365/1001
# [D valid loss: -0.313665],[D fake loss: 0.000000], [G loss(mse): -0.038168, G loss(w): 0.275886]
# Epoch 366/1001
# [D valid loss: -0.314547],[D fake loss: 0.000000], [G loss(mse): -0.041078, G loss(w): 0.273774]
# Epoch 367/1001
# [D valid loss: -0.315470],[D fake loss: 0.000000], [G loss(mse): -0.044794, G loss(w): 0.270931]
# Epoch 368/1001
# [D valid loss: -0.316355],[D fake loss: 0.000000], [G loss(mse): -0.046091, G loss(w): 0.270544]
# Epoch 369/1001
# [D valid loss: -0.317281],[D fake loss: 0.000000], [G loss(mse): -0.044085, G loss(w): 0.273441]
# Epoch 370/1001
# [D valid loss: -0.318172],[D fake loss: 0.000000], [G loss(mse): -0.045595, G loss(w): 0.272801]
# Epoch 371/1001
# [D valid loss: -0.319118],[D fake loss: 0.000000], [G loss(mse): -0.046524, G loss(w): 0.272717]
# Epoch 372/1001
# [D valid loss: -0.319989],[D fake loss: 0.000000], [G loss(mse): -0.047381, G loss(w): 0.272710]
# Epoch 373/1001
# [D valid loss: -0.320800],[D fake loss: 0.000000], [G loss(mse): -0.050967, G loss(w): 0.270017]
# Epoch 374/1001
# [D valid loss: -0.321733],[D fake loss: 0.000000], [G loss(mse): -0.050814, G loss(w): 0.271137]
# Epoch 375/1001
# [D valid loss: -0.322645],[D fake loss: 0.000000], [G loss(mse): -0.050586, G loss(w): 0.272153]
# Epoch 376/1001
# [D valid loss: -0.323505],[D fake loss: 0.000000], [G loss(mse): -0.051667, G loss(w): 0.271980]
# Epoch 377/1001
# [D valid loss: -0.324452],[D fake loss: 0.000000], [G loss(mse): -0.051327, G loss(w): 0.273178]
# Epoch 378/1001
# [D valid loss: -0.325224],[D fake loss: 0.000000], [G loss(mse): -0.052851, G loss(w): 0.272535]
# Epoch 379/1001
# [D valid loss: -0.326139],[D fake loss: 0.000000], [G loss(mse): -0.055447, G loss(w): 0.270844]
# Epoch 380/1001
# [D valid loss: -0.327065],[D fake loss: 0.000000], [G loss(mse): -0.056038, G loss(w): 0.271117]
# Epoch 381/1001
# [D valid loss: -0.327974],[D fake loss: 0.000000], [G loss(mse): -0.056386, G loss(w): 0.271712]
# Epoch 382/1001
# [D valid loss: -0.328947],[D fake loss: 0.000000], [G loss(mse): -0.057611, G loss(w): 0.271419]
# Epoch 383/1001
# [D valid loss: -0.329836],[D fake loss: 0.000000], [G loss(mse): -0.058663, G loss(w): 0.271246]
# Epoch 384/1001
# [D valid loss: -0.330681],[D fake loss: 0.000000], [G loss(mse): -0.057399, G loss(w): 0.273161]
# Epoch 385/1001
# [D valid loss: -0.331616],[D fake loss: 0.000000], [G loss(mse): -0.055995, G loss(w): 0.275569]
# Epoch 386/1001
# [D valid loss: -0.332588],[D fake loss: 0.000000], [G loss(mse): -0.061115, G loss(w): 0.271402]
# Epoch 387/1001
# [D valid loss: -0.333400],[D fake loss: 0.000000], [G loss(mse): -0.062801, G loss(w): 0.270558]
# Epoch 388/1001
# [D valid loss: -0.334351],[D fake loss: 0.000000], [G loss(mse): -0.061508, G loss(w): 0.272835]
# Epoch 389/1001
# [D valid loss: -0.335164],[D fake loss: 0.000000], [G loss(mse): -0.060745, G loss(w): 0.274269]
# Epoch 390/1001
# [D valid loss: -0.336155],[D fake loss: 0.000000], [G loss(mse): -0.064050, G loss(w): 0.272056]
# Epoch 391/1001
# [D valid loss: -0.336954],[D fake loss: 0.000000], [G loss(mse): -0.067144, G loss(w): 0.269669]
# Epoch 392/1001
# [D valid loss: -0.337901],[D fake loss: 0.000000], [G loss(mse): -0.065731, G loss(w): 0.271856]
# Epoch 393/1001
# [D valid loss: -0.338878],[D fake loss: 0.000000], [G loss(mse): -0.068063, G loss(w): 0.270685]
# Epoch 394/1001
# [D valid loss: -0.339652],[D fake loss: 0.000000], [G loss(mse): -0.068777, G loss(w): 0.270853]
# Epoch 395/1001
# [D valid loss: -0.340523],[D fake loss: 0.000000], [G loss(mse): -0.070754, G loss(w): 0.269718]
# Epoch 396/1001
# [D valid loss: -0.341602],[D fake loss: 0.000000], [G loss(mse): -0.074342, G loss(w): 0.267092]
# Epoch 397/1001
# [D valid loss: -0.342399],[D fake loss: 0.000000], [G loss(mse): -0.073298, G loss(w): 0.269051]
# Epoch 398/1001
# [D valid loss: -0.343406],[D fake loss: 0.000000], [G loss(mse): -0.073213, G loss(w): 0.269908]
# Epoch 399/1001
# [D valid loss: -0.344302],[D fake loss: 0.000000], [G loss(mse): -0.073654, G loss(w): 0.270503]
# Epoch 400/1001
# [D valid loss: -0.345239],[D fake loss: 0.000000], [G loss(mse): -0.075718, G loss(w): 0.269327]
# Epoch 401/1001
# [D valid loss: -0.346174],[D fake loss: 0.000000], [G loss(mse): -0.079014, G loss(w): 0.266677]
# Epoch 402/1001
# [D valid loss: -0.347092],[D fake loss: 0.000000], [G loss(mse): -0.075173, G loss(w): 0.271519]
# Epoch 403/1001
# [D valid loss: -0.347927],[D fake loss: 0.000000], [G loss(mse): -0.081395, G loss(w): 0.266721]
# Epoch 404/1001
# [D valid loss: -0.348887],[D fake loss: 0.000000], [G loss(mse): -0.079000, G loss(w): 0.269271]
# Epoch 405/1001
# [D valid loss: -0.349810],[D fake loss: 0.000000], [G loss(mse): -0.083829, G loss(w): 0.265751]
# Epoch 406/1001
# [D valid loss: -0.350675],[D fake loss: 0.000000], [G loss(mse): -0.080213, G loss(w): 0.270159]
# Epoch 407/1001
# [D valid loss: -0.351833],[D fake loss: 0.000000], [G loss(mse): -0.083487, G loss(w): 0.267590]
# Epoch 408/1001
# [D valid loss: -0.352719],[D fake loss: 0.000000], [G loss(mse): -0.083729, G loss(w): 0.268368]
# Epoch 409/1001
# [D valid loss: -0.353419],[D fake loss: 0.000000], [G loss(mse): -0.088074, G loss(w): 0.265140]
# Epoch 410/1001
# [D valid loss: -0.354571],[D fake loss: 0.000000], [G loss(mse): -0.088812, G loss(w): 0.265157]
# Epoch 411/1001
# [D valid loss: -0.355275],[D fake loss: 0.000000], [G loss(mse): -0.086389, G loss(w): 0.268728]
# Epoch 412/1001
# [D valid loss: -0.356344],[D fake loss: 0.000000], [G loss(mse): -0.092899, G loss(w): 0.263089]
# Epoch 413/1001
# [D valid loss: -0.357148],[D fake loss: 0.000000], [G loss(mse): -0.089152, G loss(w): 0.267575]
# Epoch 414/1001
# [D valid loss: -0.358144],[D fake loss: 0.000000], [G loss(mse): -0.089793, G loss(w): 0.267497]
# Epoch 415/1001
# [D valid loss: -0.359236],[D fake loss: 0.000000], [G loss(mse): -0.089601, G loss(w): 0.268824]
# Epoch 416/1001
# [D valid loss: -0.360309],[D fake loss: 0.000000], [G loss(mse): -0.090456, G loss(w): 0.269146]
# Epoch 417/1001
# [D valid loss: -0.360847],[D fake loss: 0.000000], [G loss(mse): -0.095690, G loss(w): 0.264626]
# Epoch 418/1001
# [D valid loss: -0.361954],[D fake loss: 0.000000], [G loss(mse): -0.092688, G loss(w): 0.268363]
# Epoch 419/1001
# [D valid loss: -0.363079],[D fake loss: 0.000000], [G loss(mse): -0.097866, G loss(w): 0.264606]
# Epoch 420/1001
# [D valid loss: -0.363950],[D fake loss: 0.000000], [G loss(mse): -0.100264, G loss(w): 0.262591]
# Epoch 421/1001
# [D valid loss: -0.364882],[D fake loss: 0.000000], [G loss(mse): -0.099200, G loss(w): 0.265031]
# Epoch 422/1001
# [D valid loss: -0.365853],[D fake loss: 0.000000], [G loss(mse): -0.098595, G loss(w): 0.266306]
# Epoch 423/1001
# [D valid loss: -0.366870],[D fake loss: 0.000000], [G loss(mse): -0.099984, G loss(w): 0.265671]
# Epoch 424/1001
# [D valid loss: -0.367728],[D fake loss: 0.000000], [G loss(mse): -0.105003, G loss(w): 0.261956]
# Epoch 425/1001
# [D valid loss: -0.368718],[D fake loss: 0.000000], [G loss(mse): -0.102830, G loss(w): 0.265009]
# Epoch 426/1001
# [D valid loss: -0.369696],[D fake loss: 0.000000], [G loss(mse): -0.102991, G loss(w): 0.265894]
# Epoch 427/1001
# ...
# Epoch 860/1001
# [D valid loss: -1.649323],[D fake loss: 0.000000], [G loss(mse): -3.577271, G loss(w): 0.171445]
# Epoch 861/1001
# [D valid loss: -1.659599],[D fake loss: 0.000000], [G loss(mse): -3.484180, G loss(w): 0.168289]
# Epoch 862/1001
# [D valid loss: -1.677702],[D fake loss: 0.000000], [G loss(mse): -3.602778, G loss(w): 0.169514]
# Epoch 863/1001
# [D valid loss: -1.689431],[D fake loss: 0.000000], [G loss(mse): -3.570552, G loss(w): 0.175401]
# Epoch 864/1001
# [D valid loss: -1.671883],[D fake loss: 0.000000], [G loss(mse): -3.646257, G loss(w): 0.171766]
# Epoch 865/1001
# [D valid loss: -1.679935],[D fake loss: 0.000000], [G loss(mse): -3.656094, G loss(w): 0.170091]
# Epoch 866/1001
# [D valid loss: -1.702519],[D fake loss: 0.000000], [G loss(mse): -3.814440, G loss(w): 0.175238]
# Epoch 867/1001
# [D valid loss: -1.704124],[D fake loss: 0.000000], [G loss(mse): -3.702196, G loss(w): 0.172445]
# Epoch 868/1001
# [D valid loss: -1.709547],[D fake loss: 0.000000], [G loss(mse): -3.776167, G loss(w): 0.169830]
# Epoch 869/1001
# [D valid loss: -1.712619],[D fake loss: 0.000000], [G loss(mse): -3.807206, G loss(w): 0.169306]
# Epoch 870/1001
# [D valid loss: -1.714163],[D fake loss: 0.000000], [G loss(mse): -3.775161, G loss(w): 0.180658]
# Epoch 871/1001
# [D valid loss: -1.719071],[D fake loss: 0.000000], [G loss(mse): -3.765473, G loss(w): 0.163298]
# Epoch 872/1001
# [D valid loss: -1.726506],[D fake loss: 0.000000], [G loss(mse): -3.899441, G loss(w): 0.172001]
# Epoch 873/1001
# [D valid loss: -1.734464],[D fake loss: 0.000000], [G loss(mse): -3.670051, G loss(w): 0.165029]
# Epoch 874/1001
# [D valid loss: -1.735007],[D fake loss: 0.000000], [G loss(mse): -3.791022, G loss(w): 0.168203]
# Epoch 875/1001
# [D valid loss: -1.734517],[D fake loss: 0.000000], [G loss(mse): -3.846142, G loss(w): 0.177138]
# Epoch 876/1001
# [D valid loss: -1.754471],[D fake loss: 0.000000], [G loss(mse): -3.849028, G loss(w): 0.169648]
# Epoch 877/1001
# [D valid loss: -1.752167],[D fake loss: 0.000000], [G loss(mse): -3.859371, G loss(w): 0.173179]
# Epoch 878/1001
# [D valid loss: -1.748519],[D fake loss: 0.000000], [G loss(mse): -3.983524, G loss(w): 0.171439]
# Epoch 879/1001
# [D valid loss: -1.748169],[D fake loss: 0.000000], [G loss(mse): -3.937150, G loss(w): 0.171060]
# Epoch 880/1001
# [D valid loss: -1.764491],[D fake loss: 0.000000], [G loss(mse): -3.931517, G loss(w): 0.166871]
# Epoch 881/1001
# [D valid loss: -1.764564],[D fake loss: 0.000000], [G loss(mse): -4.153053, G loss(w): 0.163887]
# Epoch 882/1001
# [D valid loss: -1.772512],[D fake loss: 0.000000], [G loss(mse): -4.043629, G loss(w): 0.166411]
# Epoch 883/1001
# [D valid loss: -1.777705],[D fake loss: 0.000000], [G loss(mse): -4.186221, G loss(w): 0.170018]
# Epoch 884/1001
# [D valid loss: -1.788843],[D fake loss: 0.000000], [G loss(mse): -4.381884, G loss(w): 0.166801]
# Epoch 885/1001
# [D valid loss: -1.791524],[D fake loss: 0.000000], [G loss(mse): -4.158956, G loss(w): 0.175493]
# Epoch 886/1001
# [D valid loss: -1.785384],[D fake loss: 0.000000], [G loss(mse): -4.335934, G loss(w): 0.173342]
# Epoch 887/1001
# [D valid loss: -1.806522],[D fake loss: 0.000000], [G loss(mse): -4.238378, G loss(w): 0.163847]
# Epoch 888/1001
# [D valid loss: -1.796416],[D fake loss: 0.000000], [G loss(mse): -4.488308, G loss(w): 0.164901]
# Epoch 889/1001
# [D valid loss: -1.805991],[D fake loss: 0.000000], [G loss(mse): -4.252086, G loss(w): 0.167993]
# Epoch 890/1001
# [D valid loss: -1.823594],[D fake loss: 0.000000], [G loss(mse): -4.509683, G loss(w): 0.165949]
# Epoch 891/1001
# [D valid loss: -1.812272],[D fake loss: 0.000000], [G loss(mse): -4.251982, G loss(w): 0.169348]
# Epoch 892/1001
# [D valid loss: -1.819084],[D fake loss: 0.000000], [G loss(mse): -4.570823, G loss(w): 0.166476]
# Epoch 893/1001
# [D valid loss: -1.836715],[D fake loss: 0.000000], [G loss(mse): -4.393949, G loss(w): 0.164724]
# Epoch 894/1001
# [D valid loss: -1.851288],[D fake loss: 0.000000], [G loss(mse): -4.592888, G loss(w): 0.166596]
# Epoch 895/1001
# [D valid loss: -1.835060],[D fake loss: 0.000000], [G loss(mse): -4.391690, G loss(w): 0.167500]
# Epoch 896/1001
# [D valid loss: -1.859107],[D fake loss: 0.000000], [G loss(mse): -4.561274, G loss(w): 0.164052]
# Epoch 897/1001
# [D valid loss: -1.855526],[D fake loss: 0.000000], [G loss(mse): -4.422353, G loss(w): 0.163819]
# Epoch 898/1001
# [D valid loss: -1.861509],[D fake loss: 0.000000], [G loss(mse): -4.590410, G loss(w): 0.169147]
# Epoch 899/1001
# [D valid loss: -1.866961],[D fake loss: 0.000000], [G loss(mse): -4.646222, G loss(w): 0.167315]
# Epoch 900/1001
# [D valid loss: -1.865666],[D fake loss: 0.000000], [G loss(mse): -4.709724, G loss(w): 0.164181]
# Epoch 901/1001
# [D valid loss: -1.863899],[D fake loss: 0.000000], [G loss(mse): -4.739712, G loss(w): 0.166977]
# Epoch 902/1001
# [D valid loss: -1.876748],[D fake loss: 0.000000], [G loss(mse): -4.744165, G loss(w): 0.166185]
# Epoch 903/1001
# [D valid loss: -1.898708],[D fake loss: 0.000000], [G loss(mse): -4.737646, G loss(w): 0.156773]
# Epoch 904/1001
# [D valid loss: -1.884419],[D fake loss: 0.000000], [G loss(mse): -4.801841, G loss(w): 0.163615]
# Epoch 905/1001
# [D valid loss: -1.890491],[D fake loss: 0.000000], [G loss(mse): -4.773525, G loss(w): 0.169183]
# Epoch 906/1001
# [D valid loss: -1.913034],[D fake loss: 0.000000], [G loss(mse): -4.906506, G loss(w): 0.160166]
# Epoch 907/1001
# [D valid loss: -1.908632],[D fake loss: 0.000000], [G loss(mse): -4.925116, G loss(w): 0.164765]
# Epoch 908/1001
# [D valid loss: -1.893050],[D fake loss: 0.000000], [G loss(mse): -5.203731, G loss(w): 0.169846]
# Epoch 909/1001
# [D valid loss: -1.906436],[D fake loss: 0.000000], [G loss(mse): -4.944423, G loss(w): 0.160292]
# Epoch 910/1001
# [D valid loss: -1.921472],[D fake loss: 0.000000], [G loss(mse): -5.166254, G loss(w): 0.160243]
# Epoch 911/1001
# [D valid loss: -1.910741],[D fake loss: 0.000000], [G loss(mse): -5.182641, G loss(w): 0.158685]
# Epoch 912/1001
# [D valid loss: -1.927473],[D fake loss: 0.000000], [G loss(mse): -5.173739, G loss(w): 0.167719]
# Epoch 913/1001
# [D valid loss: -1.927998],[D fake loss: 0.000000], [G loss(mse): -5.172767, G loss(w): 0.169832]
# Epoch 914/1001
# [D valid loss: -1.950786],[D fake loss: 0.000000], [G loss(mse): -5.263065, G loss(w): 0.165120]
# Epoch 915/1001
# [D valid loss: -1.958916],[D fake loss: 0.000000], [G loss(mse): -5.112121, G loss(w): 0.163959]
# Epoch 916/1001
# [D valid loss: -1.952342],[D fake loss: 0.000000], [G loss(mse): -5.443870, G loss(w): 0.159897]
# Epoch 917/1001
# [D valid loss: -1.961148],[D fake loss: 0.000000], [G loss(mse): -5.229243, G loss(w): 0.167472]
# Epoch 918/1001
# [D valid loss: -1.983403],[D fake loss: 0.000000], [G loss(mse): -5.444821, G loss(w): 0.164132]
# Epoch 919/1001
# [D valid loss: -1.974854],[D fake loss: 0.000000], [G loss(mse): -5.089038, G loss(w): 0.160265]
# Epoch 920/1001
# [D valid loss: -1.984632],[D fake loss: 0.000000], [G loss(mse): -5.777125, G loss(w): 0.162270]
# Epoch 921/1001
# [D valid loss: -1.986213],[D fake loss: 0.000000], [G loss(mse): -5.394747, G loss(w): 0.156319]
# Epoch 922/1001
# [D valid loss: -1.994046],[D fake loss: 0.000000], [G loss(mse): -5.359248, G loss(w): 0.159114]
# Epoch 923/1001
# [D valid loss: -2.001681],[D fake loss: 0.000000], [G loss(mse): -5.617703, G loss(w): 0.166150]
# Epoch 924/1001
# [D valid loss: -1.991151],[D fake loss: 0.000000], [G loss(mse): -5.562082, G loss(w): 0.157851]
# Epoch 925/1001
# [D valid loss: -2.012276],[D fake loss: 0.000000], [G loss(mse): -5.799238, G loss(w): 0.159427]
# Epoch 926/1001
# [D valid loss: -1.995454],[D fake loss: 0.000000], [G loss(mse): -5.670605, G loss(w): 0.159587]
# Epoch 927/1001
# [D valid loss: -2.016922],[D fake loss: 0.000000], [G loss(mse): -5.957083, G loss(w): 0.162375]
# Epoch 928/1001
# [D valid loss: -2.029251],[D fake loss: 0.000000], [G loss(mse): -5.568732, G loss(w): 0.161006]
# Epoch 929/1001
# [D valid loss: -2.004530],[D fake loss: 0.000000], [G loss(mse): -5.664043, G loss(w): 0.164549]
# Epoch 930/1001
# [D valid loss: -2.039917],[D fake loss: 0.000000], [G loss(mse): -5.827093, G loss(w): 0.158859]
# Epoch 931/1001
# [D valid loss: -2.061784],[D fake loss: 0.000000], [G loss(mse): -5.798270, G loss(w): 0.160988]
# Epoch 932/1001
# [D valid loss: -2.039936],[D fake loss: 0.000000], [G loss(mse): -6.151381, G loss(w): 0.156257]
# Epoch 933/1001
# [D valid loss: -2.063878],[D fake loss: 0.000000], [G loss(mse): -5.786367, G loss(w): 0.163330]
# Epoch 934/1001
# [D valid loss: -2.048131],[D fake loss: 0.000000], [G loss(mse): -5.877808, G loss(w): 0.159215]
# Epoch 935/1001
# [D valid loss: -2.068147],[D fake loss: 0.000000], [G loss(mse): -6.188234, G loss(w): 0.162140]
# Epoch 936/1001
# [D valid loss: -2.074841],[D fake loss: 0.000000], [G loss(mse): -6.081165, G loss(w): 0.162790]
# Epoch 937/1001
# [D valid loss: -2.066989],[D fake loss: 0.000000], [G loss(mse): -6.015144, G loss(w): 0.163500]
# Epoch 938/1001
# [D valid loss: -2.071041],[D fake loss: 0.000000], [G loss(mse): -6.119824, G loss(w): 0.158996]
# Epoch 939/1001
# [D valid loss: -2.087557],[D fake loss: 0.000000], [G loss(mse): -6.342005, G loss(w): 0.159608]
# Epoch 940/1001
# [D valid loss: -2.079388],[D fake loss: 0.000000], [G loss(mse): -6.053211, G loss(w): 0.155192]
# Epoch 941/1001
# [D valid loss: -2.108982],[D fake loss: 0.000000], [G loss(mse): -6.439295, G loss(w): 0.164255]
# Epoch 942/1001
# [D valid loss: -2.102023],[D fake loss: 0.000000], [G loss(mse): -6.321664, G loss(w): 0.162928]
# Epoch 943/1001
# [D valid loss: -2.104547],[D fake loss: 0.000000], [G loss(mse): -6.159505, G loss(w): 0.158283]
# Epoch 944/1001
# [D valid loss: -2.110088],[D fake loss: 0.000000], [G loss(mse): -6.418793, G loss(w): 0.159085]
# Epoch 945/1001
# [D valid loss: -2.107226],[D fake loss: 0.000000], [G loss(mse): -6.678435, G loss(w): 0.156597]
# Epoch 946/1001
# [D valid loss: -2.126906],[D fake loss: 0.000000], [G loss(mse): -7.037323, G loss(w): 0.159800]
# Epoch 947/1001
# [D valid loss: -2.140067],[D fake loss: 0.000000], [G loss(mse): -6.099333, G loss(w): 0.155619]
# Epoch 948/1001
# [D valid loss: -2.143026],[D fake loss: 0.000000], [G loss(mse): -6.716101, G loss(w): 0.155309]
# Epoch 949/1001
# [D valid loss: -2.160813],[D fake loss: 0.000000], [G loss(mse): -6.928205, G loss(w): 0.159629]
# Epoch 950/1001
# [D valid loss: -2.163934],[D fake loss: 0.000000], [G loss(mse): -6.791079, G loss(w): 0.165244]
# Epoch 951/1001
# [D valid loss: -2.139354],[D fake loss: 0.000000], [G loss(mse): -6.853874, G loss(w): 0.153497]
# Epoch 952/1001
# [D valid loss: -2.151905],[D fake loss: 0.000000], [G loss(mse): -7.001950, G loss(w): 0.153096]
# Epoch 953/1001
# [D valid loss: -2.164866],[D fake loss: 0.000000], [G loss(mse): -6.504938, G loss(w): 0.153303]
# Epoch 954/1001
# [D valid loss: -2.173185],[D fake loss: 0.000000], [G loss(mse): -6.722783, G loss(w): 0.154236]
# Epoch 955/1001
# [D valid loss: -2.179242],[D fake loss: 0.000000], [G loss(mse): -7.171739, G loss(w): 0.156672]
# Epoch 956/1001
# [D valid loss: -2.186117],[D fake loss: 0.000000], [G loss(mse): -6.861223, G loss(w): 0.156915]
# Epoch 957/1001
# [D valid loss: -2.177171],[D fake loss: 0.000000], [G loss(mse): -6.851061, G loss(w): 0.158244]
# Epoch 958/1001
# [D valid loss: -2.181688],[D fake loss: 0.000000], [G loss(mse): -7.271688, G loss(w): 0.152283]
# Epoch 959/1001
# [D valid loss: -2.201660],[D fake loss: 0.000000], [G loss(mse): -7.250937, G loss(w): 0.160047]
# Epoch 960/1001
# [D valid loss: -2.210928],[D fake loss: 0.000000], [G loss(mse): -7.381415, G loss(w): 0.159734]
# Epoch 961/1001
# [D valid loss: -2.203595],[D fake loss: 0.000000], [G loss(mse): -7.606248, G loss(w): 0.152204]
# Epoch 962/1001
# [D valid loss: -2.227027],[D fake loss: 0.000000], [G loss(mse): -6.963737, G loss(w): 0.152149]
# Epoch 963/1001
# [D valid loss: -2.218419],[D fake loss: 0.000000], [G loss(mse): -6.731857, G loss(w): 0.154982]
# Epoch 964/1001
# [D valid loss: -2.225033],[D fake loss: 0.000000], [G loss(mse): -7.299123, G loss(w): 0.151381]
# Epoch 965/1001
# [D valid loss: -2.209628],[D fake loss: 0.000000], [G loss(mse): -7.735451, G loss(w): 0.156528]
# Epoch 966/1001
# [D valid loss: -2.259734],[D fake loss: 0.000000], [G loss(mse): -7.653600, G loss(w): 0.155584]
# Epoch 967/1001
# [D valid loss: -2.264189],[D fake loss: 0.000000], [G loss(mse): -7.528841, G loss(w): 0.153597]
# Epoch 968/1001
# [D valid loss: -2.267169],[D fake loss: 0.000000], [G loss(mse): -7.734739, G loss(w): 0.156374]
# Epoch 969/1001
# [D valid loss: -2.260716],[D fake loss: 0.000000], [G loss(mse): -8.121991, G loss(w): 0.151606]
# Epoch 970/1001
# [D valid loss: -2.273227],[D fake loss: 0.000000], [G loss(mse): -8.056972, G loss(w): 0.152089]
# Epoch 971/1001
# [D valid loss: -2.273021],[D fake loss: 0.000000], [G loss(mse): -7.782728, G loss(w): 0.149012]
# Epoch 972/1001
# [D valid loss: -2.296849],[D fake loss: 0.000000], [G loss(mse): -8.040457, G loss(w): 0.150343]
# Epoch 973/1001
# [D valid loss: -2.277627],[D fake loss: 0.000000], [G loss(mse): -8.035738, G loss(w): 0.155906]
# Epoch 974/1001
# [D valid loss: -2.301482],[D fake loss: 0.000000], [G loss(mse): -8.258450, G loss(w): 0.156441]
# Epoch 975/1001
# [D valid loss: -2.296400],[D fake loss: 0.000000], [G loss(mse): -8.252658, G loss(w): 0.155251]
# Epoch 976/1001
# [D valid loss: -2.281983],[D fake loss: 0.000000], [G loss(mse): -8.172537, G loss(w): 0.157489]
# Epoch 977/1001
# [D valid loss: -2.308272],[D fake loss: 0.000000], [G loss(mse): -7.859023, G loss(w): 0.152785]
# Epoch 978/1001
# [D valid loss: -2.324910],[D fake loss: 0.000000], [G loss(mse): -8.297787, G loss(w): 0.156244]
# Epoch 979/1001
# [D valid loss: -2.323529],[D fake loss: 0.000000], [G loss(mse): -8.926792, G loss(w): 0.152918]
# Epoch 980/1001
# [D valid loss: -2.318377],[D fake loss: 0.000000], [G loss(mse): -8.748669, G loss(w): 0.153478]
# Epoch 981/1001
# [D valid loss: -2.341008],[D fake loss: 0.000000], [G loss(mse): -8.814750, G loss(w): 0.154705]
# Epoch 982/1001
# [D valid loss: -2.322697],[D fake loss: 0.000000], [G loss(mse): -8.593864, G loss(w): 0.148140]
# Epoch 983/1001
# [D valid loss: -2.350777],[D fake loss: 0.000000], [G loss(mse): -8.363602, G loss(w): 0.158072]
# Epoch 984/1001
# [D valid loss: -2.359519],[D fake loss: 0.000000], [G loss(mse): -8.742289, G loss(w): 0.153041]
# Epoch 985/1001
# [D valid loss: -2.358703],[D fake loss: 0.000000], [G loss(mse): -8.534678, G loss(w): 0.149215]
# Epoch 986/1001
# [D valid loss: -2.365726],[D fake loss: 0.000000], [G loss(mse): -9.243752, G loss(w): 0.145013]
# Epoch 987/1001
# [D valid loss: -2.365001],[D fake loss: 0.000000], [G loss(mse): -9.312080, G loss(w): 0.157730]
# Epoch 988/1001
# [D valid loss: -2.366026],[D fake loss: 0.000000], [G loss(mse): -8.572004, G loss(w): 0.149953]
# Epoch 989/1001
# [D valid loss: -2.399407],[D fake loss: 0.000000], [G loss(mse): -9.038274, G loss(w): 0.150197]
# Epoch 990/1001
# [D valid loss: -2.390088],[D fake loss: 0.000000], [G loss(mse): -8.970980, G loss(w): 0.153897]
# Epoch 991/1001
# [D valid loss: -2.407003],[D fake loss: 0.000000], [G loss(mse): -9.030100, G loss(w): 0.152748]
# Epoch 992/1001
# [D valid loss: -2.396841],[D fake loss: 0.000000], [G loss(mse): -9.744980, G loss(w): 0.154257]
# Epoch 993/1001
# [D valid loss: -2.414321],[D fake loss: 0.000000], [G loss(mse): -9.101886, G loss(w): 0.148178]
# Epoch 994/1001
# [D valid loss: -2.413923],[D fake loss: 0.000000], [G loss(mse): -9.456167, G loss(w): 0.151281]
# Epoch 995/1001
# [D valid loss: -2.423751],[D fake loss: 0.000000], [G loss(mse): -9.567965, G loss(w): 0.155387]
# Epoch 996/1001
# [D valid loss: -2.419109],[D fake loss: 0.000000], [G loss(mse): -9.434983, G loss(w): 0.151575]
# Epoch 997/1001
# [D valid loss: -2.438414],[D fake loss: 0.000000], [G loss(mse): -9.622231, G loss(w): 0.149342]
# Epoch 998/1001
# [D valid loss: -2.434515],[D fake loss: 0.000000], [G loss(mse): -9.617082, G loss(w): 0.149941]
# Epoch 999/1001
# [D valid loss: -2.439099],[D fake loss: 0.000000], [G loss(mse): -9.335361, G loss(w): 0.155186]
# Epoch 1000/1001
# [D valid loss: -2.449223],[D fake loss: 0.000000], [G loss(mse): -9.142762, G loss(w): 0.144767]
# Epoch 1001/1001
# [D valid loss: -2.462400],[D fake loss: 0.000000], [G loss(mse): -9.728719, G loss(w): 0.152580]

# %% [markdown]
# ### predict from the decoder

# %%
#predict the labels of the data values on the basis of the trained model.
#sampling from the latent space without prediction

latent_values = np.random.normal(loc=0, scale=1, size=([1000, Z]))
predicted_values = aae.decoder(latent_values)

predicted_values2 = aae.decoder(aae.encoder(X_train_scaled))
predicted_values3 = aae.encoder(X_train_scaled)
predicted_values4 = scaler.inverse_transform(X_train_scaled)

if scaled == '-1-1':
    predicted_values = scaler.inverse_transform(predicted_values)
    predicted_values2 = scaler.inverse_transform(predicted_values2)
    #predicted_values3 = scaler.inverse_transform(predicted_values3)
    
elif scaled =='0-1':
    predicted_values = scaler.inverse_transform(predicted_values)
    predicted_values2 = scaler.inverse_transform(predicted_values2)
    


if n_features==3:
    print("Predicted Values:",predicted_values.shape)
    print("latent_space:",Z)
    print("BATCH_SIZE:",BATCH_SIZE)
    print("epochs:",epochs)
    

    ab = plt.subplot(projection='3d')
    ab.scatter(predicted_values[:,0],predicted_values[:,1],predicted_values[:,2])
    ab.set_ylabel('Y')
    ab.set_zlabel('Z')
    ab.set_xlabel('X')
    
    
    print("X-Y 2D slices:")
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    plt.ylim(-1.5,1.5)
    plt.xlim(-1.5,1.5)
    axes[0].scatter(X_train[:,0],X_train[:,1])
    axes[0].scatter(predicted_values[:,0],predicted_values[:,1])
    axes[0].set_xlabel("X")
    axes[0].set_ylabel("Y")
    
    plt.ylim(-1.5,1.5)
    plt.xlim(-2,22)
    axes[1].scatter(X_train[:,1],y_train)
    axes[1].scatter(predicted_values[:,1],predicted_values[:,2])
    axes[1].set_xlabel("Y")
    axes[1].set_ylabel("Z")
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-2,22)
    axes[2].scatter(X_train[:,0],y_train)
    axes[2].scatter(predicted_values[:,0],predicted_values[:,2])
    axes[2].set_xlabel("X")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    
    ac=np.where(np.logical_and(X_train[:,0]>=-0.8-0.05,X_train[:,0]<=-0.8+0.05),X_train[:,1],None)
    ad=np.where(np.logical_and(predicted_values[:,0]>=-0.8-0.05,predicted_values[:,0]<=-0.8+0.05),predicted_values[:,1],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,predicted_values[:,2])
    axes[0].set_xlabel("Y(X=-0.8)")
    axes[0].set_ylabel("Y")
    
    ae=np.where(np.logical_and(X_train[:,0]>=0.0-0.05,X_train[:,0]<=0.0+0.05),X_train[:,1],None)
    af=np.where(np.logical_and(predicted_values[:,0]>=0.0-0.05,predicted_values[:,0]<=0.0+0.05),predicted_values[:,1],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,predicted_values[:,2])
    axes[1].set_xlabel("Y(X=0.0)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,0]>=0.8-0.05,X_train[:,0]<=0.8+0.05),X_train[:,1],None)
    ah=np.where(np.logical_and(predicted_values[:,0]>=0.8-0.05,predicted_values[:,0]<=0.8+0.05),predicted_values[:,1],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,predicted_values[:,2])
    axes[2].set_xlabel("Y(X=0.8)")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    
    
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    ac=np.where(np.logical_and(X_train[:,1]>=0.2-0.05,X_train[:,1]<=0.2+0.05),X_train[:,0],None)
    ad=np.where(np.logical_and(predicted_values[:,1]>=0.2-0.05,predicted_values[:,1]<=0.2+0.05),predicted_values[:,0],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,predicted_values[:,2])
    axes[0].set_xlabel("X(Y=0.2)")
    axes[0].set_ylabel("Z")
    
    ae=np.where(np.logical_and(X_train[:,1]>=0.5-0.05,X_train[:,1]<=0.5+0.05),X_train[:,0],None)
    af=np.where(np.logical_and(predicted_values[:,1]>=0.5-0.05,predicted_values[:,1]<=0.5+0.05),predicted_values[:,0],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,predicted_values[:,2])
    axes[1].set_xlabel("X(Y=0.5)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,1]>=0.8-0.05,X_train[:,1]<=0.8+0.05),X_train[:,0],None)
    ah=np.where(np.logical_and(predicted_values[:,1]>=0.8-0.05,predicted_values[:,1]<=0.8+0.05),predicted_values[:,0],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,predicted_values[:,2])
    axes[2].set_xlabel("X(Y=0.8)")
    axes[2].set_ylabel("Z")
    
    
    plt.tight_layout()
    
    
else:
    print("Predicted Values:",predicted_values.shape)
    print("Predicted Values:",predicted_values2.shape)
    #plt.scatter(X_train, y_train,c='orange') #sample
    #plt.scatter(predicted_values[:,0],predicted_values[:,1],c='red') #decoder(latent space)
    #plt.scatter(predicted_values2[:,0],predicted_values2[:,1],)#encoder/decoder
    plt.scatter(predicted_values3[:,0],predicted_values3[:,1],c='pink')#encoder(X_train_scaled)
    #plt.scatter(predicted_values4[:,0],predicted_values4[:,1],c='grey')#X_trained_scaled
    plt.scatter(latent_values[:,0],latent_values[:,1],c='grey')
    plt.ylabel('Y')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
# Out:
# Predicted Values: (1000, 2)
# Predicted Values: (1000, 2)

# %% [markdown]
# ### Applying the prediction function

# %%
# define these for desired prediction
x_input = [-4,-3,-2,-1,0,1,2,3,4]
n_points = 900
y_min = -1
y_max = 1

# produces an input of fixed x coordinates with random y values
predict1 = np.full((n_points//9, n_features), x_input[0])
predict2 = np.full((n_points//9, n_features), x_input[1])
predict3 = np.full((n_points//9, n_features), x_input[2])
predict4 = np.full((n_points//9, n_features), x_input[3])
predict5 = np.full((n_points//9, n_features), x_input[4])
predict6 = np.full((n_points//9, n_features), x_input[5])
predict7 = np.full((n_points//9, n_features), x_input[6])
predict8 = np.full((n_points//9, n_features), x_input[7])
predict9 = np.full((n_points//9, n_features), x_input[8])

predictthis = np.concatenate((predict1, predict2, predict3, predict4, predict5, predict6, predict7, predict8, predict9))
predictthis = scaler.fit_transform(predictthis)
input_test = predictthis.reshape(n_points, n_features).astype('float32')


print("input_test :",input_test.shape)
plt.scatter(input_test[:,0],input_test[:,1] ,c='grey')
plt.ylabel('Y')
plt.xlabel('X')
plt.tight_layout()
# Out:
# input_test : (900, 2)

# %%
#X_generated = aae.generator.predict(input_test)
X_generated = aae.decoder(aae.encoder.predict(input_test))
X_generated = scaler.inverse_transform(X_generated)
print("X_generated :",X_generated.shape)
# Out:
# X_generated : (900, 2)

# %%
if scenario in ("3d", "helix"):
    print("latent_space=",latent_space)
    print("Epochs=",epochs)
    print("BATCH_SIZE=",BATCH_SIZE)
    print("use_bias=",use_bias)
    
    ax = plt.subplot(projection='3d')
    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], label='Generated Data')


    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()
    
    print("X-Y 2D slices:")
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    plt.ylim(-1.5,1.5)
    plt.xlim(-1.5,1.5)
    axes[0].scatter(X_train[:,0],X_train[:,1])
    axes[0].scatter(X_generated[:,0],X_generated[:,1])
    axes[0].set_xlabel("X")
    axes[0].set_ylabel("Y")
    
    plt.ylim(-1.5,1.5)
    plt.xlim(-2,22)
    axes[1].scatter(X_train[:,1],y_train)
    axes[1].scatter(X_generated[:,1],X_generated[:,2])
    axes[1].set_xlabel("Y")
    axes[1].set_ylabel("Z")
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-2,22)
    axes[2].scatter(X_train[:,0],y_train)
    axes[2].scatter(X_generated[:,0],X_generated[:,2])
    axes[2].set_xlabel("X")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    
    ac=np.where(np.logical_and(X_train[:,0]>=-0.8-0.05,X_train[:,0]<=-0.8+0.05),X_train[:,1],None)
    ad=np.where(np.logical_and(X_generated[:,0]>=-0.8-0.05,X_generated[:,0]<=-0.8+0.05),X_generated[:,1],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("Y(X=-0.8)")
    axes[0].set_ylabel("Y")
    
    ae=np.where(np.logical_and(X_train[:,0]>=0.0-0.05,X_train[:,0]<=0.0+0.05),X_train[:,1],None)
    af=np.where(np.logical_and(X_generated[:,0]>=0.0-0.05,X_generated[:,0]<=0.0+0.05),X_generated[:,1],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("Y(X=0.0)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,0]>=0.8-0.05,X_train[:,0]<=0.8+0.05),X_train[:,1],None)
    ah=np.where(np.logical_and(X_generated[:,0]>=0.8-0.05,X_generated[:,0]<=0.8+0.05),X_generated[:,1],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("Y(X=0.8)")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    
    
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    ac=np.where(np.logical_and(X_train[:,1]>=0.2-0.05,X_train[:,1]<=0.2+0.05),X_train[:,0],None)
    ad=np.where(np.logical_and(X_generated[:,1]>=0.2-0.05,X_generated[:,1]<=0.2+0.05),X_generated[:,0],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("X(Y=0.2)")
    axes[0].set_ylabel("Z")
    
    ae=np.where(np.logical_and(X_train[:,1]>=0.5-0.05,X_train[:,1]<=0.5+0.05),X_train[:,0],None)
    af=np.where(np.logical_and(X_generated[:,1]>=0.5-0.05,X_generated[:,1]<=0.5+0.05),X_generated[:,0],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("X(Y=0.5)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,1]>=0.8-0.05,X_train[:,1]<=0.8+0.05),X_train[:,0],None)
    ah=np.where(np.logical_and(X_generated[:,1]>=0.8-0.05,X_generated[:,1]<=0.8+0.05),X_generated[:,0],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("X(Y=0.8)")
    axes[2].set_ylabel("Z")
    
    
    plt.tight_layout()
    
    
else:
    print("Generated Data:",X_generated.shape)
    plt.scatter(X_train, y_train,label="Sample Data")
    plt.scatter(X_generated[:,0],X_generated[:,1])
    plt.scatter(predicted_values2[:,0],predicted_values2[:,1])
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
# Out:
# Generated Data: (900, 2)
