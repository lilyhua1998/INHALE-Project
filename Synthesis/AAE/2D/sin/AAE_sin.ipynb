# %% [markdown]
# # Version

# %%
i = 3

# %% [markdown]
# # Import python dataset

# %%
# Common imports
import numpy as np
import os
from backend import import_excel, export_excel

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import tensorflow as tf
from keras import Input, Model
from keras.models import Sequential, Model, load_model


import random

import sys
sys.path.append("..")

import dataset,network

# %% [markdown]
# # Load Data

# %%
# Preprocessing

scenario= "sinus" #sinus, helix
#n_instance = 1000
n_instance = 1000
n_features = 2
Z = 6
nodes = 8 #4
var = 4
use_bias = 'True'
scales = ['-1-1','0-1']
scaled = '-1-1'

# %%
if scenario in ("3d", "helix"):
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    print("X_train= x,y",X_train.shape)
    print("y_train= z",y_train.shape)

    ax = plt.subplot(projection='3d')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='orange')
    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')
    plt.tight_layout()

    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='orange', label='Sample Data')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %%
#storage data
os.system('mkdir Dataset')
os.system('mkdir AAE')
os.system('mkdir AAE/Models')
os.system('mkdir AAE/Losses')
os.system('mkdir AAE/Random_test')
export_excel(X_train, 'Dataset/X_train')
export_excel(y_train, 'Dataset/y_train')

# print(X_train.shape,y_train.shape)
X_train = import_excel('Dataset/X_train')
y_train = import_excel('Dataset/y_train')
print('made dataset')
# Out:
# made dataset

# %% [markdown]
# # AAE

# %% [markdown]
# ### Architecture

# %%
encoder=network.build_encoder(Z, nodes, n_features)
decoder=network.build_decoder(Z, var, n_features)
discriminator=network.build_discriminator(Z, nodes)
discriminator.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          512         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256)          1024        dense[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 256)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 16, 16)       0           re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16)       64          reshape[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose (Conv1DTranspo (None, 16, 32)       512         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 32)       128         conv1d_transpose[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 16, 32)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_1 (Conv1DTrans (None, 16, 8)        256         re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 8)        32          conv1d_transpose_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 16, 8)        0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 6)            768         flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            768         flatten[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 6)            0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 6)            24          lambda[0][0]
# ==================================================================================================
# Total params: 4,088
# Trainable params: 3,452
# Non-trainable params: 636
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 60)                360
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 60)                240
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                1220
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 20)                80
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 20)                80
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 40
# =================================================================
# Total params: 2,440
# Trainable params: 2,240
# Non-trainable params: 200
# _________________________________________________________________
# Model: "Discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               1536
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 256)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16)            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 16, 32)            512
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 32)            128
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 16, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 16)            512
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16)            64
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 16, 16)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 256
# =================================================================
# Total params: 4,032
# Trainable params: 3,424
# Non-trainable params: 608
# _________________________________________________________________

# %% [markdown]
# ### Preprocessing

# %%
import AAE_Model

GANorWGAN='GAN' #GAN
epochs = 200 #2000
batch_size = 100

# %%
aae = AAE_Model.AAE(i, Z, n_features, batch_size, GANorWGAN, nodes, var, use_bias)
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 256)          512         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256)          1024        dense_11[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 256)          0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 16, 16)       0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16)       64          reshape_3[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_2 (Conv1DTrans (None, 16, 32)       512         batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 32)       128         conv1d_transpose_2[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 16, 32)       0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_3 (Conv1DTrans (None, 16, 8)        256         re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 8)        32          conv1d_transpose_3[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 16, 8)        0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 128)          0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 6)            768         flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 6)            768         flatten_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 6)            0           dense_12[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 6)            24          lambda_1[0][0]
# ==================================================================================================
# Total params: 4,088
# Trainable params: 3,452
# Non-trainable params: 636
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 60)                360
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 60)                240
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                1220
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 20)                80
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                420
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 20)                80
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 40
# =================================================================
# Total params: 2,440
# Trainable params: 2,240
# Non-trainable params: 200
# _________________________________________________________________

# %%
train_dataset, scaler, X_train_scaled = aae.preproc(X_train, y_train, scaled)

print("X_train",X_train.shape)
print("y_train",y_train.shape)
print("X_train_scaled",X_train_scaled.shape)
# Out:
# data shape_1 (100, 2)
# data shape_2 (100, 2)
# data shape_3 (100, 2)
# data shape_4 (100, 2)
# data shape_5 (100, 2)
# data shape_6 (100, 2)
# data shape_7 (100, 2)
# data shape_8 (100, 2)
# data shape_9 (100, 2)
# data shape_10 (100, 2)
# Cycles:  10
# X_train (1000, 1)
# y_train (1000, 1)
# X_train_scaled (1000, 2)

# %% [markdown]
# ### latent variable

# %% [markdown]
# ## Training

# %%
hist = aae.train(i, Z, batch_size, train_dataset, epochs, scaler, X_train_scaled, scaled, X_train, y_train )
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['dense_13/kernel:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['dense_13/kernel:0'] when minimizing the loss.
# 1 [D real: 1.481335, D fake: 0.392811], [Enc/Dec loss: 0.516623, Enc/Dis: 0.510134]
# 2 [D real: 1.396578, D fake: 0.386580], [Enc/Dec loss: 0.358259, Enc/Dis: 0.351778]
# 3 [D real: 1.322834, D fake: 0.406181], [Enc/Dec loss: 0.285590, Enc/Dis: 0.278871]
# 4 [D real: 1.271085, D fake: 0.425447], [Enc/Dec loss: 0.239445, Enc/Dis: 0.232564]
# 5 [D real: 1.214581, D fake: 0.447094], [Enc/Dec loss: 0.221644, Enc/Dis: 0.214720]
# 6 [D real: 1.164140, D fake: 0.468318], [Enc/Dec loss: 0.209166, Enc/Dis: 0.202202]
# 7 [D real: 1.126998, D fake: 0.486968], [Enc/Dec loss: 0.193526, Enc/Dis: 0.186533]
# 8 [D real: 1.089544, D fake: 0.513058], [Enc/Dec loss: 0.186674, Enc/Dis: 0.179727]
# 9 [D real: 1.056168, D fake: 0.529109], [Enc/Dec loss: 0.188949, Enc/Dis: 0.182036]
# 10 [D real: 1.026040, D fake: 0.545921], [Enc/Dec loss: 0.170803, Enc/Dis: 0.163945]
# 11 [D real: 0.736798, D fake: 0.711855], [Enc/Dec loss: 0.160768, Enc/Dis: 0.153939]
# 12 [D real: 0.721353, D fake: 0.722088], [Enc/Dec loss: 0.153380, Enc/Dis: 0.146596]
# 13 [D real: 0.718483, D fake: 0.724454], [Enc/Dec loss: 0.137313, Enc/Dis: 0.130558]
# 14 [D real: 0.717347, D fake: 0.724856], [Enc/Dec loss: 0.140853, Enc/Dis: 0.134075]
# 15 [D real: 0.711618, D fake: 0.724340], [Enc/Dec loss: 0.131418, Enc/Dis: 0.124578]
# 16 [D real: 0.703984, D fake: 0.728473], [Enc/Dec loss: 0.128124, Enc/Dis: 0.121273]
# 17 [D real: 0.701830, D fake: 0.727885], [Enc/Dec loss: 0.115990, Enc/Dis: 0.108970]
# 18 [D real: 0.698792, D fake: 0.724767], [Enc/Dec loss: 0.115100, Enc/Dis: 0.108144]
# 19 [D real: 0.699842, D fake: 0.730138], [Enc/Dec loss: 0.119264, Enc/Dis: 0.112156]
# 20 [D real: 0.697089, D fake: 0.730995], [Enc/Dec loss: 0.117642, Enc/Dis: 0.110381]
# 21 [D real: 0.693739, D fake: 0.741301], [Enc/Dec loss: 0.118381, Enc/Dis: 0.111058]
# 22 [D real: 0.688047, D fake: 0.736366], [Enc/Dec loss: 0.107730, Enc/Dis: 0.100391]
# 23 [D real: 0.687413, D fake: 0.729836], [Enc/Dec loss: 0.101409, Enc/Dis: 0.094108]
# 24 [D real: 0.689806, D fake: 0.728335], [Enc/Dec loss: 0.105203, Enc/Dis: 0.097926]
# 25 [D real: 0.696103, D fake: 0.725235], [Enc/Dec loss: 0.098216, Enc/Dis: 0.090768]
# 26 [D real: 0.697626, D fake: 0.718627], [Enc/Dec loss: 0.106475, Enc/Dis: 0.098878]
# 27 [D real: 0.698360, D fake: 0.716501], [Enc/Dec loss: 0.096618, Enc/Dis: 0.089105]
# 28 [D real: 0.704829, D fake: 0.713170], [Enc/Dec loss: 0.099980, Enc/Dis: 0.092544]
# 29 [D real: 0.706429, D fake: 0.710464], [Enc/Dec loss: 0.102427, Enc/Dis: 0.095060]
# 30 [D real: 0.708316, D fake: 0.708983], [Enc/Dec loss: 0.094492, Enc/Dis: 0.087073]
# 31 [D real: 0.708419, D fake: 0.712445], [Enc/Dec loss: 0.092031, Enc/Dis: 0.084446]
# 32 [D real: 0.705753, D fake: 0.711109], [Enc/Dec loss: 0.097573, Enc/Dis: 0.090280]
# 33 [D real: 0.711092, D fake: 0.708237], [Enc/Dec loss: 0.097142, Enc/Dis: 0.089642]
# 34 [D real: 0.717285, D fake: 0.708113], [Enc/Dec loss: 0.094000, Enc/Dis: 0.086436]
# 35 [D real: 0.717255, D fake: 0.702966], [Enc/Dec loss: 0.092085, Enc/Dis: 0.084792]
# 36 [D real: 0.719326, D fake: 0.701647], [Enc/Dec loss: 0.091770, Enc/Dis: 0.084347]
# 37 [D real: 0.719377, D fake: 0.702627], [Enc/Dec loss: 0.090916, Enc/Dis: 0.083914]
# 38 [D real: 0.721430, D fake: 0.702043], [Enc/Dec loss: 0.092674, Enc/Dis: 0.085331]
# 39 [D real: 0.722308, D fake: 0.701524], [Enc/Dec loss: 0.084327, Enc/Dis: 0.076941]
# 40 [D real: 0.722116, D fake: 0.702171], [Enc/Dec loss: 0.085690, Enc/Dis: 0.078871]
# 41 [D real: 0.705804, D fake: 0.693876], [Enc/Dec loss: 0.089713, Enc/Dis: 0.082113]
# 42 [D real: 0.711741, D fake: 0.709412], [Enc/Dec loss: 0.090292, Enc/Dis: 0.082466]
# 43 [D real: 0.718244, D fake: 0.716153], [Enc/Dec loss: 0.084503, Enc/Dis: 0.077314]
# 44 [D real: 0.718552, D fake: 0.716677], [Enc/Dec loss: 0.080231, Enc/Dis: 0.073227]
# 45 [D real: 0.714386, D fake: 0.713731], [Enc/Dec loss: 0.089395, Enc/Dis: 0.082448]
# 46 [D real: 0.712703, D fake: 0.710940], [Enc/Dec loss: 0.092209, Enc/Dis: 0.084983]
# 47 [D real: 0.708338, D fake: 0.708744], [Enc/Dec loss: 0.092186, Enc/Dis: 0.085213]
# 48 [D real: 0.707712, D fake: 0.705783], [Enc/Dec loss: 0.090053, Enc/Dis: 0.082562]
# 49 [D real: 0.705337, D fake: 0.704959], [Enc/Dec loss: 0.087699, Enc/Dis: 0.080162]
# 50 [D real: 0.705886, D fake: 0.704663], [Enc/Dec loss: 0.086508, Enc/Dis: 0.079551]
# 51 [D real: 0.729968, D fake: 0.707522], [Enc/Dec loss: 0.088300, Enc/Dis: 0.081010]
# 52 [D real: 0.712804, D fake: 0.707802], [Enc/Dec loss: 0.082539, Enc/Dis: 0.076193]
# 53 [D real: 0.711987, D fake: 0.700573], [Enc/Dec loss: 0.089115, Enc/Dis: 0.080633]
# 54 [D real: 0.720308, D fake: 0.703628], [Enc/Dec loss: 0.088647, Enc/Dis: 0.080815]
# 55 [D real: 0.717363, D fake: 0.699610], [Enc/Dec loss: 0.088948, Enc/Dis: 0.081967]
# 56 [D real: 0.719453, D fake: 0.704026], [Enc/Dec loss: 0.081340, Enc/Dis: 0.073648]
# 57 [D real: 0.716781, D fake: 0.702341], [Enc/Dec loss: 0.081018, Enc/Dis: 0.073696]
# 58 [D real: 0.713207, D fake: 0.700790], [Enc/Dec loss: 0.087418, Enc/Dis: 0.078817]
# 59 [D real: 0.712828, D fake: 0.699021], [Enc/Dec loss: 0.080704, Enc/Dis: 0.071801]
# 60 [D real: 0.713648, D fake: 0.699107], [Enc/Dec loss: 0.080895, Enc/Dis: 0.073162]
# 61 [D real: 0.705681, D fake: 0.708046], [Enc/Dec loss: 0.076818, Enc/Dis: 0.068455]
# 62 [D real: 0.704834, D fake: 0.713358], [Enc/Dec loss: 0.078393, Enc/Dis: 0.069785]
# 63 [D real: 0.699993, D fake: 0.702863], [Enc/Dec loss: 0.095769, Enc/Dis: 0.086296]
# 64 [D real: 0.698960, D fake: 0.700853], [Enc/Dec loss: 0.078159, Enc/Dis: 0.071372]
# 65 [D real: 0.698413, D fake: 0.701568], [Enc/Dec loss: 0.076088, Enc/Dis: 0.068269]
# 66 [D real: 0.701770, D fake: 0.705873], [Enc/Dec loss: 0.081680, Enc/Dis: 0.075019]
# 67 [D real: 0.702334, D fake: 0.702128], [Enc/Dec loss: 0.085830, Enc/Dis: 0.076588]
# 68 [D real: 0.704341, D fake: 0.701971], [Enc/Dec loss: 0.084369, Enc/Dis: 0.076703]
# 69 [D real: 0.702827, D fake: 0.699916], [Enc/Dec loss: 0.085497, Enc/Dis: 0.078363]
# 70 [D real: 0.701765, D fake: 0.701540], [Enc/Dec loss: 0.081902, Enc/Dis: 0.073642]
# 71 [D real: 0.713600, D fake: 0.685164], [Enc/Dec loss: 0.078812, Enc/Dis: 0.069303]
# 72 [D real: 0.702887, D fake: 0.681352], [Enc/Dec loss: 0.084263, Enc/Dis: 0.077547]
# 73 [D real: 0.703687, D fake: 0.687952], [Enc/Dec loss: 0.085999, Enc/Dis: 0.079218]
# 74 [D real: 0.701943, D fake: 0.690688], [Enc/Dec loss: 0.094249, Enc/Dis: 0.083171]
# 75 [D real: 0.703286, D fake: 0.690762], [Enc/Dec loss: 0.082491, Enc/Dis: 0.074214]
# 76 [D real: 0.705477, D fake: 0.693141], [Enc/Dec loss: 0.084920, Enc/Dis: 0.074399]
# 77 [D real: 0.706927, D fake: 0.694993], [Enc/Dec loss: 0.082370, Enc/Dis: 0.071428]
# 78 [D real: 0.711061, D fake: 0.692961], [Enc/Dec loss: 0.079428, Enc/Dis: 0.069663]
# 79 [D real: 0.712327, D fake: 0.694418], [Enc/Dec loss: 0.084393, Enc/Dis: 0.076043]
# 80 [D real: 0.709743, D fake: 0.695539], [Enc/Dec loss: 0.074868, Enc/Dis: 0.066103]
# 81 [D real: 0.717785, D fake: 0.713354], [Enc/Dec loss: 0.080133, Enc/Dis: 0.070862]
# 82 [D real: 0.708972, D fake: 0.716824], [Enc/Dec loss: 0.082113, Enc/Dis: 0.074540]
# 83 [D real: 0.713267, D fake: 0.708825], [Enc/Dec loss: 0.082501, Enc/Dis: 0.075322]
# 84 [D real: 0.714185, D fake: 0.703958], [Enc/Dec loss: 0.084887, Enc/Dis: 0.075039]
# 85 [D real: 0.715159, D fake: 0.696283], [Enc/Dec loss: 0.083104, Enc/Dis: 0.073885]
# 86 [D real: 0.713634, D fake: 0.699781], [Enc/Dec loss: 0.077183, Enc/Dis: 0.068202]
# 87 [D real: 0.712406, D fake: 0.699988], [Enc/Dec loss: 0.082456, Enc/Dis: 0.072177]
# 88 [D real: 0.713013, D fake: 0.700200], [Enc/Dec loss: 0.082964, Enc/Dis: 0.072291]
# 89 [D real: 0.707466, D fake: 0.700539], [Enc/Dec loss: 0.085832, Enc/Dis: 0.074628]
# 90 [D real: 0.706668, D fake: 0.700128], [Enc/Dec loss: 0.081719, Enc/Dis: 0.071892]
# 91 [D real: 0.712382, D fake: 0.688253], [Enc/Dec loss: 0.079155, Enc/Dis: 0.070284]
# 92 [D real: 0.712893, D fake: 0.693034], [Enc/Dec loss: 0.076919, Enc/Dis: 0.069642]
# 93 [D real: 0.707085, D fake: 0.690048], [Enc/Dec loss: 0.081170, Enc/Dis: 0.065825]
# 94 [D real: 0.704768, D fake: 0.696612], [Enc/Dec loss: 0.080588, Enc/Dis: 0.068942]
# 95 [D real: 0.700983, D fake: 0.694795], [Enc/Dec loss: 0.082726, Enc/Dis: 0.073422]
# 96 [D real: 0.701587, D fake: 0.695530], [Enc/Dec loss: 0.083732, Enc/Dis: 0.073452]
# 97 [D real: 0.697591, D fake: 0.695602], [Enc/Dec loss: 0.078384, Enc/Dis: 0.066855]
# 98 [D real: 0.695504, D fake: 0.692175], [Enc/Dec loss: 0.082025, Enc/Dis: 0.072600]
# 99 [D real: 0.696823, D fake: 0.692701], [Enc/Dec loss: 0.075368, Enc/Dis: 0.066544]
# 100 [D real: 0.697306, D fake: 0.693765], [Enc/Dec loss: 0.084967, Enc/Dis: 0.074483]
# 101 [D real: 0.685150, D fake: 0.722474], [Enc/Dec loss: 0.081313, Enc/Dis: 0.071669]
# 102 [D real: 0.689801, D fake: 0.722409], [Enc/Dec loss: 0.079184, Enc/Dis: 0.069602]
# 103 [D real: 0.680308, D fake: 0.706965], [Enc/Dec loss: 0.074372, Enc/Dis: 0.069552]
# 104 [D real: 0.677544, D fake: 0.700028], [Enc/Dec loss: 0.080150, Enc/Dis: 0.073929]
# 105 [D real: 0.675650, D fake: 0.700521], [Enc/Dec loss: 0.074518, Enc/Dis: 0.067224]
# 106 [D real: 0.677311, D fake: 0.698076], [Enc/Dec loss: 0.079558, Enc/Dis: 0.069302]
# 107 [D real: 0.675377, D fake: 0.694516], [Enc/Dec loss: 0.086112, Enc/Dis: 0.075504]
# 108 [D real: 0.673975, D fake: 0.695753], [Enc/Dec loss: 0.073374, Enc/Dis: 0.066852]
# 109 [D real: 0.679487, D fake: 0.696290], [Enc/Dec loss: 0.079154, Enc/Dis: 0.072670]
# 110 [D real: 0.682013, D fake: 0.694611], [Enc/Dec loss: 0.082863, Enc/Dis: 0.074030]
# 111 [D real: 0.700743, D fake: 0.690521], [Enc/Dec loss: 0.073024, Enc/Dis: 0.064422]
# 112 [D real: 0.697023, D fake: 0.672689], [Enc/Dec loss: 0.079792, Enc/Dis: 0.070504]
# 113 [D real: 0.690385, D fake: 0.669417], [Enc/Dec loss: 0.087634, Enc/Dis: 0.078333]
# 114 [D real: 0.690376, D fake: 0.675971], [Enc/Dec loss: 0.077955, Enc/Dis: 0.070088]
# 115 [D real: 0.687017, D fake: 0.675744], [Enc/Dec loss: 0.081862, Enc/Dis: 0.074004]
# 116 [D real: 0.689270, D fake: 0.678177], [Enc/Dec loss: 0.084091, Enc/Dis: 0.076665]
# 117 [D real: 0.687935, D fake: 0.678521], [Enc/Dec loss: 0.075805, Enc/Dis: 0.067504]
# 118 [D real: 0.688704, D fake: 0.678885], [Enc/Dec loss: 0.084192, Enc/Dis: 0.075724]
# 119 [D real: 0.690314, D fake: 0.681873], [Enc/Dec loss: 0.079278, Enc/Dis: 0.069256]
# 120 [D real: 0.688467, D fake: 0.684098], [Enc/Dec loss: 0.074655, Enc/Dis: 0.067003]
# 121 [D real: 0.692782, D fake: 0.702599], [Enc/Dec loss: 0.076936, Enc/Dis: 0.067265]
# 122 [D real: 0.703638, D fake: 0.681796], [Enc/Dec loss: 0.088971, Enc/Dis: 0.079389]
# 123 [D real: 0.695976, D fake: 0.683253], [Enc/Dec loss: 0.081101, Enc/Dis: 0.072803]
# 124 [D real: 0.688801, D fake: 0.686423], [Enc/Dec loss: 0.080255, Enc/Dis: 0.068594]
# 125 [D real: 0.685476, D fake: 0.688455], [Enc/Dec loss: 0.082018, Enc/Dis: 0.075624]
# 126 [D real: 0.683367, D fake: 0.687764], [Enc/Dec loss: 0.069751, Enc/Dis: 0.065555]
# 127 [D real: 0.684937, D fake: 0.685800], [Enc/Dec loss: 0.080547, Enc/Dis: 0.070181]
# 128 [D real: 0.687456, D fake: 0.682793], [Enc/Dec loss: 0.083132, Enc/Dis: 0.072327]
# 129 [D real: 0.687066, D fake: 0.682977], [Enc/Dec loss: 0.072348, Enc/Dis: 0.065218]
# 130 [D real: 0.685417, D fake: 0.684090], [Enc/Dec loss: 0.076429, Enc/Dis: 0.065896]
# 131 [D real: 0.694080, D fake: 0.722669], [Enc/Dec loss: 0.078337, Enc/Dis: 0.071447]
# 132 [D real: 0.687652, D fake: 0.695189], [Enc/Dec loss: 0.082040, Enc/Dis: 0.061224]
# 133 [D real: 0.694280, D fake: 0.698044], [Enc/Dec loss: 0.076393, Enc/Dis: 0.064185]
# 134 [D real: 0.692281, D fake: 0.692127], [Enc/Dec loss: 0.075030, Enc/Dis: 0.069024]
# 135 [D real: 0.688236, D fake: 0.689221], [Enc/Dec loss: 0.068534, Enc/Dis: 0.062768]
# 136 [D real: 0.686449, D fake: 0.697918], [Enc/Dec loss: 0.080770, Enc/Dis: 0.066090]
# 137 [D real: 0.677498, D fake: 0.692732], [Enc/Dec loss: 0.082653, Enc/Dis: 0.078029]
# 138 [D real: 0.679117, D fake: 0.691284], [Enc/Dec loss: 0.091412, Enc/Dis: 0.077064]
# 139 [D real: 0.679283, D fake: 0.693365], [Enc/Dec loss: 0.083195, Enc/Dis: 0.072694]
# 140 [D real: 0.681423, D fake: 0.687235], [Enc/Dec loss: 0.078504, Enc/Dis: 0.069433]
# 141 [D real: 0.674049, D fake: 0.692316], [Enc/Dec loss: 0.072541, Enc/Dis: 0.065874]
# 142 [D real: 0.693467, D fake: 0.682873], [Enc/Dec loss: 0.076571, Enc/Dis: 0.069604]
# 143 [D real: 0.684701, D fake: 0.675763], [Enc/Dec loss: 0.079997, Enc/Dis: 0.073832]
# 144 [D real: 0.688808, D fake: 0.673728], [Enc/Dec loss: 0.082968, Enc/Dis: 0.069492]
# 145 [D real: 0.690085, D fake: 0.670576], [Enc/Dec loss: 0.080276, Enc/Dis: 0.065970]
# 146 [D real: 0.695754, D fake: 0.669646], [Enc/Dec loss: 0.075484, Enc/Dis: 0.068835]
# 147 [D real: 0.699418, D fake: 0.667630], [Enc/Dec loss: 0.081675, Enc/Dis: 0.072971]
# 148 [D real: 0.696927, D fake: 0.670493], [Enc/Dec loss: 0.082848, Enc/Dis: 0.072122]
# 149 [D real: 0.692416, D fake: 0.674400], [Enc/Dec loss: 0.072274, Enc/Dis: 0.063330]
# 150 [D real: 0.692931, D fake: 0.677519], [Enc/Dec loss: 0.074764, Enc/Dis: 0.069259]
# 151 [D real: 0.685545, D fake: 0.711945], [Enc/Dec loss: 0.080373, Enc/Dis: 0.071954]
# 152 [D real: 0.685309, D fake: 0.714492], [Enc/Dec loss: 0.076281, Enc/Dis: 0.065878]
# 153 [D real: 0.673124, D fake: 0.694680], [Enc/Dec loss: 0.077429, Enc/Dis: 0.070112]
# 154 [D real: 0.671593, D fake: 0.696101], [Enc/Dec loss: 0.077569, Enc/Dis: 0.070971]
# 155 [D real: 0.683554, D fake: 0.696876], [Enc/Dec loss: 0.074715, Enc/Dis: 0.068235]
# 156 [D real: 0.681699, D fake: 0.695106], [Enc/Dec loss: 0.071088, Enc/Dis: 0.065273]
# 157 [D real: 0.686877, D fake: 0.691756], [Enc/Dec loss: 0.070192, Enc/Dis: 0.064120]
# 158 [D real: 0.684718, D fake: 0.687030], [Enc/Dec loss: 0.073394, Enc/Dis: 0.067213]
# 159 [D real: 0.681717, D fake: 0.685095], [Enc/Dec loss: 0.072740, Enc/Dis: 0.067827]
# 160 [D real: 0.681612, D fake: 0.681325], [Enc/Dec loss: 0.073332, Enc/Dis: 0.067866]
# 161 [D real: 0.698837, D fake: 0.696352], [Enc/Dec loss: 0.083035, Enc/Dis: 0.077869]
# 162 [D real: 0.690053, D fake: 0.689439], [Enc/Dec loss: 0.066631, Enc/Dis: 0.063036]
# 163 [D real: 0.699710, D fake: 0.685977], [Enc/Dec loss: 0.066738, Enc/Dis: 0.062422]
# 164 [D real: 0.684254, D fake: 0.686316], [Enc/Dec loss: 0.075133, Enc/Dis: 0.067750]
# 165 [D real: 0.673078, D fake: 0.686323], [Enc/Dec loss: 0.076412, Enc/Dis: 0.067554]
# 166 [D real: 0.673686, D fake: 0.682963], [Enc/Dec loss: 0.077473, Enc/Dis: 0.070163]
# 167 [D real: 0.672920, D fake: 0.681653], [Enc/Dec loss: 0.083733, Enc/Dis: 0.072172]
# 168 [D real: 0.673815, D fake: 0.678732], [Enc/Dec loss: 0.082864, Enc/Dis: 0.073984]
# 169 [D real: 0.677461, D fake: 0.679011], [Enc/Dec loss: 0.097280, Enc/Dis: 0.073511]
# 170 [D real: 0.679218, D fake: 0.677946], [Enc/Dec loss: 0.080687, Enc/Dis: 0.069663]
# 171 [D real: 0.642889, D fake: 0.685766], [Enc/Dec loss: 0.076579, Enc/Dis: 0.070067]
# 172 [D real: 0.664416, D fake: 0.691887], [Enc/Dec loss: 0.072509, Enc/Dis: 0.068987]
# 173 [D real: 0.660878, D fake: 0.699776], [Enc/Dec loss: 0.076918, Enc/Dis: 0.070211]
# 174 [D real: 0.666526, D fake: 0.691294], [Enc/Dec loss: 0.077424, Enc/Dis: 0.073739]
# 175 [D real: 0.664981, D fake: 0.679880], [Enc/Dec loss: 0.073052, Enc/Dis: 0.067924]
# 176 [D real: 0.675437, D fake: 0.682899], [Enc/Dec loss: 0.074591, Enc/Dis: 0.063745]
# 177 [D real: 0.677609, D fake: 0.682775], [Enc/Dec loss: 0.072488, Enc/Dis: 0.063436]
# 178 [D real: 0.677689, D fake: 0.678570], [Enc/Dec loss: 0.080671, Enc/Dis: 0.072877]
# 179 [D real: 0.679591, D fake: 0.681360], [Enc/Dec loss: 0.078712, Enc/Dis: 0.070780]
# 180 [D real: 0.679075, D fake: 0.681365], [Enc/Dec loss: 0.071184, Enc/Dis: 0.064602]
# 181 [D real: 0.707991, D fake: 0.648222], [Enc/Dec loss: 0.068560, Enc/Dis: 0.064485]
# 182 [D real: 0.678113, D fake: 0.679256], [Enc/Dec loss: 0.082316, Enc/Dis: 0.078459]
# 183 [D real: 0.687731, D fake: 0.669365], [Enc/Dec loss: 0.072840, Enc/Dis: 0.068297]
# 184 [D real: 0.692950, D fake: 0.666311], [Enc/Dec loss: 0.071680, Enc/Dis: 0.066379]
# 185 [D real: 0.688279, D fake: 0.668757], [Enc/Dec loss: 0.074011, Enc/Dis: 0.068573]
# 186 [D real: 0.682146, D fake: 0.677995], [Enc/Dec loss: 0.071820, Enc/Dis: 0.066653]
# 187 [D real: 0.678000, D fake: 0.681649], [Enc/Dec loss: 0.069675, Enc/Dis: 0.066783]
# 188 [D real: 0.676655, D fake: 0.685119], [Enc/Dec loss: 0.066786, Enc/Dis: 0.063568]
# 189 [D real: 0.680973, D fake: 0.684166], [Enc/Dec loss: 0.070706, Enc/Dis: 0.066926]
# 190 [D real: 0.679171, D fake: 0.677521], [Enc/Dec loss: 0.071508, Enc/Dis: 0.067236]
# 191 [D real: 0.674830, D fake: 0.697526], [Enc/Dec loss: 0.075026, Enc/Dis: 0.069915]
# 192 [D real: 0.665525, D fake: 0.671352], [Enc/Dec loss: 0.083551, Enc/Dis: 0.074503]
# 193 [D real: 0.674260, D fake: 0.668032], [Enc/Dec loss: 0.075156, Enc/Dis: 0.067929]
# 194 [D real: 0.679953, D fake: 0.659711], [Enc/Dec loss: 0.074835, Enc/Dis: 0.069319]
# 195 [D real: 0.680080, D fake: 0.669421], [Enc/Dec loss: 0.065835, Enc/Dis: 0.060458]
# 196 [D real: 0.685949, D fake: 0.668491], [Enc/Dec loss: 0.073673, Enc/Dis: 0.068358]
# 197 [D real: 0.689798, D fake: 0.673282], [Enc/Dec loss: 0.070226, Enc/Dis: 0.065450]
# 198 [D real: 0.692133, D fake: 0.671517], [Enc/Dec loss: 0.073760, Enc/Dis: 0.068139]
# 199 [D real: 0.690322, D fake: 0.676227], [Enc/Dec loss: 0.081762, Enc/Dis: 0.065894]
# 200 [D real: 0.684033, D fake: 0.677923], [Enc/Dec loss: 0.077265, Enc/Dis: 0.067102]

# %% [markdown]
# ### Plot Loss

# %%
from PIL import Image

#Discriminator Loss
Dloss = Image.open('AAE/Losses/D_loss_v'+str(i)+'_epochs'+str(epochs)+'.png')
plt.figure("D_loss",figsize=[15,10])
plt.imshow(Dloss)
#Encoder Loss
Gloss = Image.open('AAE/Losses/G_loss_v'+str(i)+'_epochs'+str(epochs)+'.png')
plt.figure("G_loss",figsize=[15,10])
plt.imshow(Gloss)

# %% [markdown]
# ## predict from the decoder

# %%
#encoder = tf.keras.models.load_model('./AAE/Models/encoder_v'+str(3)+'_'+str(500), compile=False)
#decoder = tf.keras.models.load_model('./AAE/Models/decoder_v'+str(3)+'_'+str(500), compile=False)
#discriminator = tf.keras.models.load_model('./AAE/Models/discriminator_v'+str(3)+'_'+str(1000), compile=False)


#moons=2
#enc_dis = tf.keras.models.load_model('content/'+notebookName[:-6]+str(epochs)+'.h5', compile=False).layers

# %%
latent_values = tf.random.normal([1000, 6])
predicted_values = decoder(latent_values)

predicted_values2 = decoder(encoder(X_train_scaled))
predicted_values3 = encoder(X_train_scaled)
        

predicted_values = scaler.inverse_transform(predicted_values)
predicted_values2 = scaler.inverse_transform(predicted_values2)
predicted_values4 = scaler.inverse_transform(X_train_scaled)

            
fig, axes = plt.subplots()
#plt.scatter(predicted_values[:,0],predicted_values[:,1],c='green') #decoder(latent space)
plt.scatter(predicted_values4[:,0],predicted_values4[:,1],c='r')#X_trained_scaled
plt.scatter(predicted_values[:,0],predicted_values[:,1],c='green') #decoder(latent space)
plt.ylabel('Y')
plt.xlabel('X')
plt.title('Decoder (latent space)')
    
plt.tight_layout()
plt.savefig('AAE/Result/sin_v_'+str(3)+'_epochs_'+str(500)+'.png')
plt.show()

# %%
#latent_values = tf.random.normal([1000, latent_space], mean=0.0, stddev=0.1)
        
#predict the labels of the data values on the basis of the trained model.
#predicted_values = generator.predict(latent_values)

#predicted_values[:,:]=(predicted_values[:,:])
#predicted_values2 = scaler.inverse_transform(predicted_values)


bottleneck = encoder(X_train_scaled)
     

disc_output = discriminator(bottleneck)
#disc_output = disc_output.numpy().reshape(x_num,y_num).T

x = X_train_scaled[:,0]
y = X_train_scaled[:,1]
z = disc_output
        
plt.scatter(x, y, c=z)
plt.ylabel('Y')
plt.xlabel('X')
        
plt.colorbar()
plt.tight_layout()

plt.savefig('AAE/Result/'+'moons_countour_points_v'+str(2)+'_epochs'+str(2000)+'.png')
print("save countour line")
plt.show()
# Out:
# save countour line

# %%
x_num = 100
y_num = 100
        
x = np.linspace(start=-1, stop=1, num=x_num)
y = np.linspace(start=-1, stop=1, num=y_num)

xy = np.zeros((x_num*y_num, 2))
for i in range(x_num):
    for j in range(y_num):
        xy[i*y_num+j][0] = x[i]
        xy[i*y_num+j][1] = y[j]
                
bottleneck = encoder(xy)
                
disc_output = discriminator(bottleneck)
disc_output = disc_output.numpy().reshape(x_num,y_num).T
        
fig, ax = plt.subplots()
sns.heatmap(disc_output, ax=ax)
ax.invert_yaxis()
       
plt.savefig('AAE/Result/Heatmap/'+'heatmap_sin_v'+str(i)+'_epochs'+str(epochs)+'.png')
plt.show()

# %%
epochs = epochs

# %% [raw]
# img = Image.open('AAE/Result/v'+str(i)+'_latent_space 3D_'+str(epochs)+'.png')
# plt.figure("3D",figsize=[15,10])
# plt.imshow(img)
#
# img2 = Image.open('AAE/Result/v'+str(i)+'_Latent_Space 2D_'+str(epochs)+'.png')
# plt.figure("2D",figsize=[15,10])
# plt.imshow(img2)
#
# img3 = Image.open('AAE/Result/v_'+str(i)+'_epochs_'+str(epochs)+'.png')
# plt.figure("Autoencoder",figsize=[15,10])
# plt.imshow(img3)
#
# img4 = Image.open('AAE/Result/'+'countour_line_v'+str(i)+'_epochs'+str(epochs)+'.png')
# plt.figure("countour_line",figsize=[15,10])
# plt.imshow(img4)

# %% [raw]
# latent_values = tf.random.normal([10000, Z])
# predicted_values = aae.decoder(latent_values)
#
# predicted_values2 = aae.decoder(aae.encoder(X_train_scaled))
# predicted_values3 = aae.encoder(X_train_scaled)
# #predicted_values4 = scaler.inverse_transform(X_train_scaled)
#
# if scaled == '-1-1':
#     predicted_values = scaler.inverse_transform(predicted_values)
#     predicted_values2 = scaler.inverse_transform(predicted_values2)
#
#
# elif scaled =='0-1':
#     predicted_values = scaler.inverse_transform(predicted_values)
#     predicted_values2 = scaler.inverse_transform(predicted_values2)
#
#
#
#
# if n_features==3:
#
#     ab = plt.subplot(projection='3d')
#     ab.scatter(predicted_values5[:,0],predicted_values5[:,1],predicted_values5[:,2])
#     ab.set_ylabel('Y')
#     ab.set_zlabel('Z')
#     ab.set_xlabel('X')
#
#
#     print("X-Y 2D slices:")
#     fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
#     plt.ylim(-1.5,1.5)
#     plt.xlim(-1.5,1.5)
#     axes[0].scatter(X_train[:,0],X_train[:,1])
#     axes[0].scatter(predicted_values[:,0],predicted_values[:,1])
#     axes[0].set_xlabel("X")
#     axes[0].set_ylabel("Y")
#
#     plt.ylim(-1.5,1.5)
#     plt.xlim(-2,22)
#     axes[1].scatter(X_train[:,1],y_train)
#     axes[1].scatter(predicted_values[:,1],predicted_values[:,2])
#     axes[1].set_xlabel("Y")
#     axes[1].set_ylabel("Z")
#
#     plt.xlim(-1.5,1.5)
#     plt.ylim(-2,22)
#     axes[2].scatter(X_train[:,0],y_train)
#     axes[2].scatter(predicted_values[:,0],predicted_values[:,2])
#     axes[2].set_xlabel("X")
#     axes[2].set_ylabel("Z")
#
#     plt.tight_layout()
#
#
#     fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
#
#     ac=np.where(np.logical_and(X_train[:,0]>=-0.8-0.05,X_train[:,0]<=-0.8+0.05),X_train[:,1],None)
#     ad=np.where(np.logical_and(predicted_values[:,0]>=-0.8-0.05,predicted_values[:,0]<=-0.8+0.05),predicted_values[:,1],None)
#     axes[0].scatter(ac,y_train)
#     axes[0].scatter(ad,predicted_values[:,2])
#     axes[0].set_xlabel("Y(X=-0.8)")
#     axes[0].set_ylabel("Y")
#
#     ae=np.where(np.logical_and(X_train[:,0]>=0.0-0.05,X_train[:,0]<=0.0+0.05),X_train[:,1],None)
#     af=np.where(np.logical_and(predicted_values[:,0]>=0.0-0.05,predicted_values[:,0]<=0.0+0.05),predicted_values[:,1],None)
#     axes[1].scatter(ae,y_train)
#     axes[1].scatter(af,predicted_values[:,2])
#     axes[1].set_xlabel("Y(X=0.0)")
#     axes[1].set_ylabel("Z")
#
#     ag=np.where(np.logical_and(X_train[:,0]>=0.8-0.05,X_train[:,0]<=0.8+0.05),X_train[:,1],None)
#     ah=np.where(np.logical_and(predicted_values[:,0]>=0.8-0.05,predicted_values[:,0]<=0.8+0.05),predicted_values[:,1],None)
#     axes[2].scatter(ag,y_train)
#     axes[2].scatter(ah,predicted_values[:,2])
#     axes[2].set_xlabel("Y(X=0.8)")
#     axes[2].set_ylabel("Z")
#
#     plt.tight_layout()
#
#
#
#     fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
#     ac=np.where(np.logical_and(X_train[:,1]>=0.2-0.05,X_train[:,1]<=0.2+0.05),X_train[:,0],None)
#     ad=np.where(np.logical_and(predicted_values[:,1]>=0.2-0.05,predicted_values[:,1]<=0.2+0.05),predicted_values[:,0],None)
#     axes[0].scatter(ac,y_train)
#     axes[0].scatter(ad,predicted_values[:,2])
#     axes[0].set_xlabel("X(Y=0.2)")
#     axes[0].set_ylabel("Z")
#
#     ae=np.where(np.logical_and(X_train[:,1]>=0.5-0.05,X_train[:,1]<=0.5+0.05),X_train[:,0],None)
#     af=np.where(np.logical_and(predicted_values[:,1]>=0.5-0.05,predicted_values[:,1]<=0.5+0.05),predicted_values[:,0],None)
#     axes[1].scatter(ae,y_train)
#     axes[1].scatter(af,predicted_values[:,2])
#     axes[1].set_xlabel("X(Y=0.5)")
#     axes[1].set_ylabel("Z")
#
#     ag=np.where(np.logical_and(X_train[:,1]>=0.8-0.05,X_train[:,1]<=0.8+0.05),X_train[:,0],None)
#     ah=np.where(np.logical_and(predicted_values[:,1]>=0.8-0.05,predicted_values[:,1]<=0.8+0.05),predicted_values[:,0],None)
#     axes[2].scatter(ag,y_train)
#     axes[2].scatter(ah,predicted_values[:,2])
#     axes[2].set_xlabel("X(Y=0.8)")
#     axes[2].set_ylabel("Z")
#
#
#     plt.tight_layout()
#
#
# else:
#
#     if Z>=6:
#         # set up a figure twice as wide as it is tall
#         fig = plt.figure(figsize=plt.figaspect(0.5))
#         aa = fig.add_subplot(1, 2, 1, projection='3d')
#         aa.scatter(predicted_values3[:,0],predicted_values3[:,1],predicted_values3[:,2],c='pink')
#         aa.scatter(latent_values[:,0],latent_values[:,1],latent_values[:,2],c='grey')
#         aa.set_ylabel('Y')
#         aa.set_zlabel('Z')
#         aa.set_xlabel('X')
#         aa.set_title('Latent Space 3D - 0,1,2')
#
#         ax = fig.add_subplot(1, 2, 2, projection='3d')
#         ax.scatter(predicted_values3[:,3],predicted_values3[:,4],predicted_values3[:,5],c='pink')
#         ax.scatter(latent_values[:,3],latent_values[:,4],latent_values[:,5],c='grey')
#         ax.set_ylabel('Y')
#         ax.set_zlabel('Z')
#         ax.set_xlabel('X')
#         ax.set_title('Latent Space 3D - 3,4,5')
#
#         plt.savefig('AAE/Result/v'+str(i)+'_latent_space 3D_'+str(epochs)+'.png')
#
#
#         fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10), sharey=False, sharex=False)
#         axes[0][0].scatter(predicted_values3[:,0],predicted_values3[:,1],c='pink')
#         axes[0][0].scatter(latent_values[:,0],latent_values[:,1],c='grey')
#         axes[0][0].set_xlabel("X")
#         axes[0][0].set_ylabel("Y")
#         axes[0][0].set_title("Latent Space 2D- XY")
#
#
#
#         axes[0][1].scatter(predicted_values3[:,1],predicted_values3[:,2],c='pink')
#         axes[0][1].scatter(latent_values[:,1],latent_values[:,2],c='grey')
#         axes[0][1].set_xlabel("Y")
#         axes[0][1].set_ylabel("Z")
#         axes[0][1].set_title("Latent Space 2D- YZ")
#
#
#
#         axes[0][2].scatter(predicted_values3[:,0],predicted_values3[:,2],c='pink')
#         axes[0][2].scatter(latent_values[:,0],latent_values[:,2],c='grey')
#         axes[0][2].set_xlabel("X")
#         axes[0][2].set_ylabel("Z")
#         axes[0][2].set_title("Latent Space 2D- XZ")
#
#
#         axes[1][0].scatter(predicted_values3[:,3],predicted_values3[:,4],c='pink')
#         axes[1][0].scatter(latent_values[:,3],latent_values[:,4],c='grey')
#         axes[1][0].set_xlabel("X")
#         axes[1][0].set_ylabel("Y")
#         axes[1][0].set_title("Latent Space 2D- 3,4")
#
#         axes[1][1].scatter(predicted_values3[:,4],predicted_values3[:,5],c='pink')
#         axes[1][1].scatter(latent_values[:,4],latent_values[:,5],c='grey')
#         axes[1][1].set_xlabel("Y")
#         axes[1][1].set_ylabel("Z")
#         axes[1][1].set_title("Latent Space 2D- 4,5")
#
#         axes[1][2].scatter(predicted_values3[:,3],predicted_values3[:,5],c='pink')
#         axes[1][2].scatter(latent_values[:,3],latent_values[:,5],c='grey')
#         axes[1][2].set_xlabel("X")
#         axes[1][2].set_ylabel("Z")
#         axes[1][2].set_title("Latent Space 2D- 3,5")
#
#         plt.tight_layout()
#         plt.savefig('AAE/Result/v'+str(i)+'_Latent_Space 2D_'+str(epochs)+'.png')
#
#     ############################################
#     ###############Latent Space#################
#     ############################################
#
#
#     fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5), sharey=False, sharex=False)
#     axes[0].scatter(predicted_values2[:,0],predicted_values2[:,1],)#encoder/decoder
#     #axes[0].scatter(predicted_values4[:,0],predicted_values4[:,1],c='grey')#X_trained_scaled
#     axes[0].set_ylabel('Y')
#     axes[0].set_xlabel('X')
#     axes[0].set_title('Autoencoder (X_trained_scaled)')
#
#     axes[1].scatter(predicted_values[:,0],predicted_values[:,1],c='red') #decoder(latent space)
#     #axes[1].scatter(predicted_values4[:,0],predicted_values4[:,1],c='grey')#X_trained_scaled
#     axes[1].set_ylabel('Y')
#     axes[1].set_xlabel('X')
#     axes[1].set_title('Decoder (latent space)')
#
#     plt.tight_layout()
#     plt.savefig('AAE/Result/v_'+str(i)+'_epochs_'+str(epochs)+'.png')
#
#     ############################################
#     ###############Discriminator################
#     ############################################
#
#
# print('encoder output shape',predicted_values3.shape)
# encoder_output = predicted_values3
#
# dis_predicted_values = aae.discriminator(encoder_output)
# #dis_predicted_values = scaler.inverse_transform(dis_predicted_values)
# print('discriminator shape',dis_predicted_values.shape)
#
#
#
# #import seed ()
# x = np.ndarray.tolist(predicted_values2[:, 0])
# y = np.ndarray.tolist(predicted_values2[:, 1])
# #z = np.ndarray.tolist(dis_predicted_values)
# #x = np.random.choice(x)
# #y = np.random.choice(y)
# #z = np.random.choice(z)
#
# resolution_x = 100
# resolution_y = 100
# x = np.linspace(np.min(predicted_values2[:, 0]), np.max(predicted_values2[:, 0]), resolution_x)
# #x = predicted_values2[:, 0]
# y = np.linspace(np.min(predicted_values2[:, 1]), np.max(predicted_values2[:, 1]), resolution_y)
# #y = predicted_values2[:, 1]
# x, y = np.meshgrid(x, y)
#
# z = dis_predicted_values
# z = np.array(z)
# z = z.reshape((len(x), len(y)))
#
# fig = plt.figure()
# plt.contourf(x, y, z)
# plt.colorbar()
#
# #fig, ax = plt.subplots(1,1, figsize=[10,5])
# #ax.plot(dis_predicted_values)
#
# #plt.tight_layout()
# #plt.xlabel('X')
# #plt.ylabel('Y')
# #plt.title("AAE Discriminator")
# plt.savefig('AAE/Result/'+'countour_line_v'+str(i)+'_epochs'+str(epochs)+'.png')

# %% [markdown]
# ### Applying the prediction function

# %%
i = i

# %%
# Common imports
import numpy as np
import os
from backend import import_excel, export_excel

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import tensorflow as tf
from keras import Input, Model
from keras.models import Sequential, Model, load_model


import random

import sys
sys.path.append("..")

import dataset, network

# %%
epochs = epochs

# %% [raw]
# encoder = keras.models.load_model('./AAE/Models/encoder_v'+str(i)+'_'+str(epochs))
# decoder = keras.models.load_model('./AAE/Models/decoder_v'+str(i)+'_'+str(epochs))
# discriminator = keras.models.load_model('./AAE/Models/discriminator_v'+str(i)+'_'+str(epochs))

# %%
# define these for desired prediction
x_input = [-4,-3,-2,-1,0,1,2,3,4]
n_points = 900
y_min = -1
y_max = 1

# produces an input of fixed x coordinates with random y values
predict1 = np.full((n_points//9, n_features), x_input[0])
predict2 = np.full((n_points//9, n_features), x_input[1])
predict3 = np.full((n_points//9, n_features), x_input[2])
predict4 = np.full((n_points//9, n_features), x_input[3])
predict5 = np.full((n_points//9, n_features), x_input[4])
predict6 = np.full((n_points//9, n_features), x_input[5])
predict7 = np.full((n_points//9, n_features), x_input[6])
predict8 = np.full((n_points//9, n_features), x_input[7])
predict9 = np.full((n_points//9, n_features), x_input[8])

predictthis = np.concatenate((predict1, predict2, predict3, predict4, predict5, predict6, predict7, predict8, predict9))
predictthis_scaled = scaler.transform(predictthis)
input_test = predictthis_scaled.reshape(n_points, n_features).astype('float32')


print("input_test :",input_test.shape)
plt.scatter(input_test[:,0],input_test[:,1] ,c='grey')
plt.ylabel('Y')
plt.xlabel('X')
plt.tight_layout()
# Out:
# input_test : (900, 2)

# %%
X_generated = aae.predict(input_test, scaler)
print("X_generated :",X_generated.shape)
# Out:
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# ...
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)
# input: (900, 2)

# %%
if scenario in ("3d", "helix"):
    
    ax = plt.subplot(projection='3d')
    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], label='Generated Data')


    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()
    
    print("X-Y 2D slices:")
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    plt.ylim(-1.5,1.5)
    plt.xlim(-1.5,1.5)
    axes[0].scatter(X_train[:,0],X_train[:,1])
    axes[0].scatter(X_generated[:,0],X_generated[:,1])
    axes[0].set_xlabel("X")
    axes[0].set_ylabel("Y")
    
    plt.ylim(-1.5,1.5)
    plt.xlim(-2,22)
    axes[1].scatter(X_train[:,1],y_train)
    axes[1].scatter(X_generated[:,1],X_generated[:,2])
    axes[1].set_xlabel("Y")
    axes[1].set_ylabel("Z")
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-2,22)
    axes[2].scatter(X_train[:,0],y_train)
    axes[2].scatter(X_generated[:,0],X_generated[:,2])
    axes[2].set_xlabel("X")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    
    ac=np.where(np.logical_and(X_train[:,0]>=-0.8-0.05,X_train[:,0]<=-0.8+0.05),X_train[:,1],None)
    ad=np.where(np.logical_and(X_generated[:,0]>=-0.8-0.05,X_generated[:,0]<=-0.8+0.05),X_generated[:,1],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("Y(X=-0.8)")
    axes[0].set_ylabel("Y")
    
    ae=np.where(np.logical_and(X_train[:,0]>=0.0-0.05,X_train[:,0]<=0.0+0.05),X_train[:,1],None)
    af=np.where(np.logical_and(X_generated[:,0]>=0.0-0.05,X_generated[:,0]<=0.0+0.05),X_generated[:,1],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("Y(X=0.0)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,0]>=0.8-0.05,X_train[:,0]<=0.8+0.05),X_train[:,1],None)
    ah=np.where(np.logical_and(X_generated[:,0]>=0.8-0.05,X_generated[:,0]<=0.8+0.05),X_generated[:,1],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("Y(X=0.8)")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    
    
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    ac=np.where(np.logical_and(X_train[:,1]>=0.2-0.05,X_train[:,1]<=0.2+0.05),X_train[:,0],None)
    ad=np.where(np.logical_and(X_generated[:,1]>=0.2-0.05,X_generated[:,1]<=0.2+0.05),X_generated[:,0],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("X(Y=0.2)")
    axes[0].set_ylabel("Z")
    
    ae=np.where(np.logical_and(X_train[:,1]>=0.5-0.05,X_train[:,1]<=0.5+0.05),X_train[:,0],None)
    af=np.where(np.logical_and(X_generated[:,1]>=0.5-0.05,X_generated[:,1]<=0.5+0.05),X_generated[:,0],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("X(Y=0.5)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,1]>=0.8-0.05,X_train[:,1]<=0.8+0.05),X_train[:,0],None)
    ah=np.where(np.logical_and(X_generated[:,1]>=0.8-0.05,X_generated[:,1]<=0.8+0.05),X_generated[:,0],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("X(Y=0.8)")
    axes[2].set_ylabel("Z")
    
    
    plt.tight_layout()
    
    
else:
    print("Generated Data:",X_generated.shape)
    plt.scatter(X_train, y_train) 
    plt.scatter(X_generated[:,0],X_generated[:,1])
    #plt.scatter(predicted_values4[:,0],predicted_values4[:,1],c='grey')#X_trained_scaled
    #plt.scatter(predicted_values2[:,0],predicted_values2[:,1])
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
    plt.savefig('AAE/Prediction/sin'+str(epochs)+'.png')
