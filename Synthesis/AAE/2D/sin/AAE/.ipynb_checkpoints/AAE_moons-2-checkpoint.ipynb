# %% [markdown]
# # Version

# %%
i = 2 #moons

# %% [markdown]
# # Import python dataset

# %%
# Common imports
import numpy as np
import os
from backend import import_excel, export_excel

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import tensorflow as tf
from keras import Input, Model
from keras.models import Sequential, Model, load_model


import random

import sys
sys.path.append("..")

import dataset,network

# %% [markdown]
# # Load Data

# %%
# Preprocessing

scenario= "moons" #sinus, helix
#n_instance = 1000
n_instance = 1000
n_features = 2
Z = 6 #3的倍數
nodes = 4 #4
var = 2
use_bias = 'True'
scales = ['-1-1','0-1']
scaled = '-1-1'

# %%
if scenario in ("3d", "helix"):
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    print("X_train= x,y",X_train.shape)
    print("y_train= z",y_train.shape)

    ax = plt.subplot(projection='3d')
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='orange')
    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')
    plt.tight_layout()

    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='orange', label='Sample Data')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %%
#storage data
os.system('mkdir Dataset')
os.system('mkdir AAE')
os.system('mkdir AAE/Models')
os.system('mkdir AAE/Losses')
os.system('mkdir AAE/Random_test')
export_excel(X_train, 'Dataset/X_train')
export_excel(y_train, 'Dataset/y_train')

# print(X_train.shape,y_train.shape)
X_train = import_excel('Dataset/X_train')
y_train = import_excel('Dataset/y_train')
print('made dataset')
# Out:
# made dataset

# %% [markdown]
# # AAE

# %% [markdown]
# ### Architecture

# %%
encoder=network.build_encoder(Z, nodes, n_features)
decoder=network.build_decoder(Z, var, n_features)
discriminator=network.build_discriminator(Z, nodes)
discriminator.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           128         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64)           256         dense[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 64)           0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 8, 8)         0           re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8)         32          reshape[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose (Conv1DTranspo (None, 8, 16)        128         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 16)        64          conv1d_transpose[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 8, 16)        0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_1 (Conv1DTrans (None, 8, 4)         64          re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 4)         16          conv1d_transpose_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 8, 4)         0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32)           0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 6)            192         flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            192         flatten[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 6)            0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 6)            24          lambda[0][0]
# ==================================================================================================
# Total params: 1,096
# Trainable params: 900
# Non-trainable params: 196
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                180
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 30)                120
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                310
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 10)                40
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                110
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 10)                40
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 20
# =================================================================
# Total params: 820
# Trainable params: 720
# Non-trainable params: 100
# _________________________________________________________________
# Model: "Discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                384
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 64)                0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8)              0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 8, 16)             128
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 16)             64
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 8, 16)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 8, 8)              128
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8)              32
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 8, 8)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 64
# =================================================================
# Total params: 1,056
# Trainable params: 880
# Non-trainable params: 176
# _________________________________________________________________

# %% [markdown]
# ### Preprocessing

# %%
import AAE_Model

GANorWGAN='GAN' #GAN
epochs = 2000 #2000
batch_size = 100

# %%
aae = AAE_Model.AAE(i, Z, n_features, batch_size, GANorWGAN, nodes, var, use_bias)
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 64)           128         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         dense_11[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 8, 8)         0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8)         32          reshape_3[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_2 (Conv1DTrans (None, 8, 16)        128         batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 16)        64          conv1d_transpose_2[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 8, 16)        0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_3 (Conv1DTrans (None, 8, 4)         64          re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 4)         16          conv1d_transpose_3[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 8, 4)         0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 32)           0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 6)            192         flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 6)            192         flatten_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 6)            0           dense_12[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 6)            24          lambda_1[0][0]
# ==================================================================================================
# Total params: 1,096
# Trainable params: 900
# Non-trainable params: 196
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 30)                180
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 30)                120
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                310
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 10)                40
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                110
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 10)                40
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 20
# =================================================================
# Total params: 820
# Trainable params: 720
# Non-trainable params: 100
# _________________________________________________________________

# %%
train_dataset, scaler, X_train_scaled = aae.preproc(X_train, y_train, scaled)

print("X_train",X_train.shape)
print("y_train",y_train.shape)
print("X_train_scaled",X_train_scaled.shape)
# Out:
# data shape_1 (100, 2)
# data shape_2 (100, 2)
# data shape_3 (100, 2)
# data shape_4 (100, 2)
# data shape_5 (100, 2)
# data shape_6 (100, 2)
# data shape_7 (100, 2)
# data shape_8 (100, 2)
# data shape_9 (100, 2)
# data shape_10 (100, 2)
# Cycles:  10
# X_train (1000, 1)
# y_train (1000, 1)
# X_train_scaled (1000, 2)

# %% [markdown]
# ### latent variable

# %% [markdown]
# ## Training

# %%
hist = aae.train(i, Z, batch_size, train_dataset, epochs, scaler, X_train_scaled, scaled, X_train, y_train )
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['dense_13/kernel:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['dense_13/kernel:0'] when minimizing the loss.
# 1 [D real: 1.157936, D fake: 0.473816], [Enc/Dec loss: 0.633336, Enc/Dis: 0.626868]
# 2 [D real: 1.164190, D fake: 0.470202], [Enc/Dec loss: 0.513794, Enc/Dis: 0.507378]
# 3 [D real: 1.140301, D fake: 0.475145], [Enc/Dec loss: 0.444464, Enc/Dis: 0.438033]
# 4 [D real: 1.133018, D fake: 0.483788], [Enc/Dec loss: 0.361625, Enc/Dis: 0.355145]
# 5 [D real: 1.125460, D fake: 0.489645], [Enc/Dec loss: 0.313693, Enc/Dis: 0.307222]
# 6 [D real: 1.111269, D fake: 0.491121], [Enc/Dec loss: 0.257298, Enc/Dis: 0.250802]
# 7 [D real: 1.092610, D fake: 0.495334], [Enc/Dec loss: 0.246092, Enc/Dis: 0.239595]
# 8 [D real: 1.084538, D fake: 0.494814], [Enc/Dec loss: 0.215070, Enc/Dis: 0.208538]
# 9 [D real: 1.080950, D fake: 0.496634], [Enc/Dec loss: 0.195538, Enc/Dis: 0.188977]
# 10 [D real: 1.074335, D fake: 0.500048], [Enc/Dec loss: 0.195625, Enc/Dis: 0.189060]
# 11 [D real: 0.994546, D fake: 0.552152], [Enc/Dec loss: 0.170746, Enc/Dis: 0.164163]
# 12 [D real: 0.990701, D fake: 0.551760], [Enc/Dec loss: 0.172907, Enc/Dis: 0.166252]
# 13 [D real: 0.971087, D fake: 0.555945], [Enc/Dec loss: 0.157590, Enc/Dis: 0.150944]
# 14 [D real: 0.960420, D fake: 0.556559], [Enc/Dec loss: 0.153004, Enc/Dis: 0.146297]
# 15 [D real: 0.947713, D fake: 0.565287], [Enc/Dec loss: 0.149036, Enc/Dis: 0.142298]
# 16 [D real: 0.937112, D fake: 0.569342], [Enc/Dec loss: 0.153330, Enc/Dis: 0.146561]
# 17 [D real: 0.929742, D fake: 0.568154], [Enc/Dec loss: 0.143421, Enc/Dis: 0.136667]
# 18 [D real: 0.925758, D fake: 0.572490], [Enc/Dec loss: 0.145668, Enc/Dis: 0.138783]
# 19 [D real: 0.919138, D fake: 0.575571], [Enc/Dec loss: 0.132678, Enc/Dis: 0.125670]
# 20 [D real: 0.915460, D fake: 0.583668], [Enc/Dec loss: 0.141394, Enc/Dis: 0.134317]
# 21 [D real: 0.882219, D fake: 0.583383], [Enc/Dec loss: 0.132294, Enc/Dis: 0.125047]
# 22 [D real: 0.867677, D fake: 0.604519], [Enc/Dec loss: 0.134183, Enc/Dis: 0.126965]
# 23 [D real: 0.859309, D fake: 0.610051], [Enc/Dec loss: 0.136328, Enc/Dis: 0.129030]
# 24 [D real: 0.845076, D fake: 0.616573], [Enc/Dec loss: 0.124616, Enc/Dis: 0.117229]
# 25 [D real: 0.837294, D fake: 0.614187], [Enc/Dec loss: 0.131159, Enc/Dis: 0.123764]
# 26 [D real: 0.833261, D fake: 0.615883], [Enc/Dec loss: 0.123641, Enc/Dis: 0.116152]
# 27 [D real: 0.828735, D fake: 0.615689], [Enc/Dec loss: 0.118935, Enc/Dis: 0.111398]
# 28 [D real: 0.826369, D fake: 0.619796], [Enc/Dec loss: 0.113926, Enc/Dis: 0.106340]
# 29 [D real: 0.822194, D fake: 0.622155], [Enc/Dec loss: 0.114658, Enc/Dis: 0.107159]
# 30 [D real: 0.819289, D fake: 0.623946], [Enc/Dec loss: 0.119861, Enc/Dis: 0.112312]
# 31 [D real: 0.794930, D fake: 0.660396], [Enc/Dec loss: 0.122922, Enc/Dis: 0.115244]
# 32 [D real: 0.799499, D fake: 0.650805], [Enc/Dec loss: 0.121419, Enc/Dis: 0.113767]
# 33 [D real: 0.793096, D fake: 0.657684], [Enc/Dec loss: 0.114217, Enc/Dis: 0.106371]
# 34 [D real: 0.782897, D fake: 0.650567], [Enc/Dec loss: 0.114315, Enc/Dis: 0.106414]
# 35 [D real: 0.775873, D fake: 0.651672], [Enc/Dec loss: 0.111131, Enc/Dis: 0.103217]
# 36 [D real: 0.774987, D fake: 0.652226], [Enc/Dec loss: 0.117578, Enc/Dis: 0.109736]
# 37 [D real: 0.775121, D fake: 0.653317], [Enc/Dec loss: 0.108532, Enc/Dis: 0.100447]
# 38 [D real: 0.768488, D fake: 0.652171], [Enc/Dec loss: 0.108097, Enc/Dis: 0.100182]
# 39 [D real: 0.764092, D fake: 0.652366], [Enc/Dec loss: 0.114886, Enc/Dis: 0.107194]
# 40 [D real: 0.763393, D fake: 0.653639], [Enc/Dec loss: 0.103631, Enc/Dis: 0.095789]
# 41 [D real: 0.771790, D fake: 0.676624], [Enc/Dec loss: 0.108527, Enc/Dis: 0.100707]
# 42 [D real: 0.745104, D fake: 0.686490], [Enc/Dec loss: 0.110947, Enc/Dis: 0.103091]
# 43 [D real: 0.745442, D fake: 0.681346], [Enc/Dec loss: 0.105404, Enc/Dis: 0.097457]
# 44 [D real: 0.750161, D fake: 0.679099], [Enc/Dec loss: 0.107194, Enc/Dis: 0.099515]
# 45 [D real: 0.747449, D fake: 0.680120], [Enc/Dec loss: 0.112246, Enc/Dis: 0.104543]
# 46 [D real: 0.752016, D fake: 0.685506], [Enc/Dec loss: 0.109213, Enc/Dis: 0.101285]
# 47 [D real: 0.753398, D fake: 0.682941], [Enc/Dec loss: 0.109731, Enc/Dis: 0.101833]
# 48 [D real: 0.751247, D fake: 0.680652], [Enc/Dec loss: 0.108968, Enc/Dis: 0.101223]
# 49 [D real: 0.749364, D fake: 0.683296], [Enc/Dec loss: 0.106195, Enc/Dis: 0.098260]
# 50 [D real: 0.746447, D fake: 0.682759], [Enc/Dec loss: 0.105801, Enc/Dis: 0.098147]
# 51 [D real: 0.763896, D fake: 0.685395], [Enc/Dec loss: 0.107138, Enc/Dis: 0.099240]
# 52 [D real: 0.751327, D fake: 0.700837], [Enc/Dec loss: 0.106740, Enc/Dis: 0.098879]
# 53 [D real: 0.742777, D fake: 0.695642], [Enc/Dec loss: 0.098587, Enc/Dis: 0.090468]
# 54 [D real: 0.742934, D fake: 0.697134], [Enc/Dec loss: 0.099454, Enc/Dis: 0.091107]
# 55 [D real: 0.736514, D fake: 0.691292], [Enc/Dec loss: 0.106648, Enc/Dis: 0.098405]
# 56 [D real: 0.735130, D fake: 0.693420], [Enc/Dec loss: 0.102743, Enc/Dis: 0.094319]
# 57 [D real: 0.730678, D fake: 0.694010], [Enc/Dec loss: 0.107778, Enc/Dis: 0.099634]
# 58 [D real: 0.733376, D fake: 0.691315], [Enc/Dec loss: 0.100280, Enc/Dis: 0.091646]
# 59 [D real: 0.730248, D fake: 0.690345], [Enc/Dec loss: 0.109747, Enc/Dis: 0.100829]
# 60 [D real: 0.729441, D fake: 0.692125], [Enc/Dec loss: 0.101023, Enc/Dis: 0.092468]
# 61 [D real: 0.756633, D fake: 0.690488], [Enc/Dec loss: 0.103147, Enc/Dis: 0.094446]
# 62 [D real: 0.741300, D fake: 0.684404], [Enc/Dec loss: 0.109502, Enc/Dis: 0.100600]
# 63 [D real: 0.735393, D fake: 0.686493], [Enc/Dec loss: 0.095436, Enc/Dis: 0.086953]
# 64 [D real: 0.730594, D fake: 0.690619], [Enc/Dec loss: 0.100785, Enc/Dis: 0.091541]
# 65 [D real: 0.729845, D fake: 0.685695], [Enc/Dec loss: 0.108020, Enc/Dis: 0.099550]
# 66 [D real: 0.730398, D fake: 0.689261], [Enc/Dec loss: 0.096106, Enc/Dis: 0.087051]
# 67 [D real: 0.727318, D fake: 0.693211], [Enc/Dec loss: 0.105885, Enc/Dis: 0.096042]
# 68 [D real: 0.725669, D fake: 0.694240], [Enc/Dec loss: 0.105308, Enc/Dis: 0.096144]
# 69 [D real: 0.724335, D fake: 0.692055], [Enc/Dec loss: 0.100738, Enc/Dis: 0.091366]
# 70 [D real: 0.722122, D fake: 0.691545], [Enc/Dec loss: 0.097515, Enc/Dis: 0.088650]
# 71 [D real: 0.709318, D fake: 0.700998], [Enc/Dec loss: 0.105678, Enc/Dis: 0.095743]
# 72 [D real: 0.714506, D fake: 0.698693], [Enc/Dec loss: 0.096367, Enc/Dis: 0.086432]
# 73 [D real: 0.712306, D fake: 0.699905], [Enc/Dec loss: 0.100955, Enc/Dis: 0.091206]
# 74 [D real: 0.703977, D fake: 0.696770], [Enc/Dec loss: 0.097960, Enc/Dis: 0.088464]
# 75 [D real: 0.703037, D fake: 0.692947], [Enc/Dec loss: 0.095672, Enc/Dis: 0.087373]
# 76 [D real: 0.702174, D fake: 0.689868], [Enc/Dec loss: 0.099981, Enc/Dis: 0.090944]
# 77 [D real: 0.703292, D fake: 0.693275], [Enc/Dec loss: 0.100085, Enc/Dis: 0.089238]
# 78 [D real: 0.704359, D fake: 0.690686], [Enc/Dec loss: 0.096862, Enc/Dis: 0.087255]
# 79 [D real: 0.706644, D fake: 0.690972], [Enc/Dec loss: 0.103296, Enc/Dis: 0.093277]
# 80 [D real: 0.708068, D fake: 0.689597], [Enc/Dec loss: 0.097028, Enc/Dis: 0.086706]
# 81 [D real: 0.715604, D fake: 0.706589], [Enc/Dec loss: 0.090783, Enc/Dis: 0.081623]
# 82 [D real: 0.701218, D fake: 0.711544], [Enc/Dec loss: 0.099290, Enc/Dis: 0.089907]
# 83 [D real: 0.703426, D fake: 0.709399], [Enc/Dec loss: 0.102605, Enc/Dis: 0.090725]
# 84 [D real: 0.702537, D fake: 0.703157], [Enc/Dec loss: 0.099514, Enc/Dis: 0.088506]
# 85 [D real: 0.703171, D fake: 0.699981], [Enc/Dec loss: 0.096509, Enc/Dis: 0.086283]
# 86 [D real: 0.704209, D fake: 0.696635], [Enc/Dec loss: 0.092932, Enc/Dis: 0.082789]
# 87 [D real: 0.707305, D fake: 0.696390], [Enc/Dec loss: 0.103954, Enc/Dis: 0.091491]
# 88 [D real: 0.709195, D fake: 0.698420], [Enc/Dec loss: 0.103195, Enc/Dis: 0.093096]
# 89 [D real: 0.707929, D fake: 0.699507], [Enc/Dec loss: 0.096375, Enc/Dis: 0.086757]
# 90 [D real: 0.710681, D fake: 0.700428], [Enc/Dec loss: 0.100413, Enc/Dis: 0.089128]
# 91 [D real: 0.701976, D fake: 0.690984], [Enc/Dec loss: 0.103719, Enc/Dis: 0.092881]
# 92 [D real: 0.695379, D fake: 0.695478], [Enc/Dec loss: 0.091515, Enc/Dis: 0.081976]
# 93 [D real: 0.699972, D fake: 0.701479], [Enc/Dec loss: 0.097795, Enc/Dis: 0.087803]
# 94 [D real: 0.708733, D fake: 0.701148], [Enc/Dec loss: 0.103753, Enc/Dis: 0.092375]
# 95 [D real: 0.708819, D fake: 0.698637], [Enc/Dec loss: 0.104734, Enc/Dis: 0.093142]
# 96 [D real: 0.709200, D fake: 0.697390], [Enc/Dec loss: 0.100089, Enc/Dis: 0.089071]
# 97 [D real: 0.708297, D fake: 0.702145], [Enc/Dec loss: 0.101509, Enc/Dis: 0.090419]
# 98 [D real: 0.701480, D fake: 0.704393], [Enc/Dec loss: 0.100597, Enc/Dis: 0.091595]
# 99 [D real: 0.703467, D fake: 0.703328], [Enc/Dec loss: 0.095276, Enc/Dis: 0.084263]
# 100 [D real: 0.703766, D fake: 0.702357], [Enc/Dec loss: 0.098463, Enc/Dis: 0.086138]
# 101 [D real: 0.689852, D fake: 0.673043], [Enc/Dec loss: 0.093575, Enc/Dis: 0.084420]
# 102 [D real: 0.699714, D fake: 0.699956], [Enc/Dec loss: 0.100112, Enc/Dis: 0.088038]
# 103 [D real: 0.709578, D fake: 0.702083], [Enc/Dec loss: 0.102624, Enc/Dis: 0.089502]
# 104 [D real: 0.712874, D fake: 0.697116], [Enc/Dec loss: 0.098204, Enc/Dis: 0.088070]
# 105 [D real: 0.711989, D fake: 0.697507], [Enc/Dec loss: 0.095470, Enc/Dis: 0.086027]
# 106 [D real: 0.707624, D fake: 0.702077], [Enc/Dec loss: 0.095927, Enc/Dis: 0.084263]
# 107 [D real: 0.707210, D fake: 0.704018], [Enc/Dec loss: 0.096693, Enc/Dis: 0.086330]
# 108 [D real: 0.703980, D fake: 0.705922], [Enc/Dec loss: 0.097949, Enc/Dis: 0.087924]
# 109 [D real: 0.703557, D fake: 0.704483], [Enc/Dec loss: 0.095407, Enc/Dis: 0.085879]
# 110 [D real: 0.705802, D fake: 0.702140], [Enc/Dec loss: 0.093667, Enc/Dis: 0.082069]
# 111 [D real: 0.711814, D fake: 0.690871], [Enc/Dec loss: 0.095044, Enc/Dis: 0.080757]
# 112 [D real: 0.712312, D fake: 0.701917], [Enc/Dec loss: 0.089601, Enc/Dis: 0.081044]
# 113 [D real: 0.713858, D fake: 0.705066], [Enc/Dec loss: 0.088363, Enc/Dis: 0.078418]
# 114 [D real: 0.705800, D fake: 0.703257], [Enc/Dec loss: 0.096986, Enc/Dis: 0.084504]
# 115 [D real: 0.705100, D fake: 0.703178], [Enc/Dec loss: 0.088362, Enc/Dis: 0.079972]
# 116 [D real: 0.703701, D fake: 0.697038], [Enc/Dec loss: 0.098718, Enc/Dis: 0.086048]
# 117 [D real: 0.703490, D fake: 0.698114], [Enc/Dec loss: 0.093633, Enc/Dis: 0.080356]
# 118 [D real: 0.704367, D fake: 0.698442], [Enc/Dec loss: 0.098759, Enc/Dis: 0.086309]
# 119 [D real: 0.702075, D fake: 0.696686], [Enc/Dec loss: 0.089223, Enc/Dis: 0.080318]
# 120 [D real: 0.703472, D fake: 0.695050], [Enc/Dec loss: 0.095860, Enc/Dis: 0.084262]
# 121 [D real: 0.692252, D fake: 0.688744], [Enc/Dec loss: 0.100136, Enc/Dis: 0.090289]
# 122 [D real: 0.695453, D fake: 0.684025], [Enc/Dec loss: 0.097057, Enc/Dis: 0.082880]
# 123 [D real: 0.694920, D fake: 0.690353], [Enc/Dec loss: 0.100627, Enc/Dis: 0.088744]
# 124 [D real: 0.698143, D fake: 0.691272], [Enc/Dec loss: 0.096300, Enc/Dis: 0.084888]
# 125 [D real: 0.701067, D fake: 0.694518], [Enc/Dec loss: 0.092162, Enc/Dis: 0.083763]
# 126 [D real: 0.702729, D fake: 0.693878], [Enc/Dec loss: 0.094241, Enc/Dis: 0.082675]
# 127 [D real: 0.705463, D fake: 0.691835], [Enc/Dec loss: 0.097243, Enc/Dis: 0.085871]
# 128 [D real: 0.702368, D fake: 0.690032], [Enc/Dec loss: 0.090748, Enc/Dis: 0.082257]
# 129 [D real: 0.701182, D fake: 0.687895], [Enc/Dec loss: 0.095253, Enc/Dis: 0.081265]
# 130 [D real: 0.701004, D fake: 0.689065], [Enc/Dec loss: 0.091449, Enc/Dis: 0.083880]
# 131 [D real: 0.708780, D fake: 0.720251], [Enc/Dec loss: 0.087613, Enc/Dis: 0.078824]
# 132 [D real: 0.723942, D fake: 0.718124], [Enc/Dec loss: 0.088276, Enc/Dis: 0.075824]
# 133 [D real: 0.713186, D fake: 0.709173], [Enc/Dec loss: 0.090441, Enc/Dis: 0.080753]
# 134 [D real: 0.708696, D fake: 0.700126], [Enc/Dec loss: 0.087669, Enc/Dis: 0.076187]
# 135 [D real: 0.706796, D fake: 0.701195], [Enc/Dec loss: 0.091464, Enc/Dis: 0.080020]
# 136 [D real: 0.707627, D fake: 0.696058], [Enc/Dec loss: 0.098420, Enc/Dis: 0.085857]
# 137 [D real: 0.705648, D fake: 0.696952], [Enc/Dec loss: 0.092336, Enc/Dis: 0.079985]
# 138 [D real: 0.705272, D fake: 0.697312], [Enc/Dec loss: 0.092006, Enc/Dis: 0.080558]
# 139 [D real: 0.705532, D fake: 0.697001], [Enc/Dec loss: 0.092237, Enc/Dis: 0.079817]
# 140 [D real: 0.705196, D fake: 0.698579], [Enc/Dec loss: 0.090708, Enc/Dis: 0.078870]
# 141 [D real: 0.709429, D fake: 0.707485], [Enc/Dec loss: 0.087867, Enc/Dis: 0.075291]
# 142 [D real: 0.708259, D fake: 0.702919], [Enc/Dec loss: 0.100674, Enc/Dis: 0.087470]
# 143 [D real: 0.712628, D fake: 0.694062], [Enc/Dec loss: 0.092752, Enc/Dis: 0.079906]
# 144 [D real: 0.696468, D fake: 0.693310], [Enc/Dec loss: 0.095769, Enc/Dis: 0.086648]
# 145 [D real: 0.703238, D fake: 0.686372], [Enc/Dec loss: 0.094018, Enc/Dis: 0.081309]
# 146 [D real: 0.707213, D fake: 0.691073], [Enc/Dec loss: 0.090817, Enc/Dis: 0.079782]
# 147 [D real: 0.706347, D fake: 0.693628], [Enc/Dec loss: 0.096620, Enc/Dis: 0.082148]
# 148 [D real: 0.705817, D fake: 0.696281], [Enc/Dec loss: 0.082259, Enc/Dis: 0.076532]
# 149 [D real: 0.708896, D fake: 0.699074], [Enc/Dec loss: 0.093932, Enc/Dis: 0.082857]
# 150 [D real: 0.707088, D fake: 0.699825], [Enc/Dec loss: 0.092574, Enc/Dis: 0.083812]
# 151 [D real: 0.700071, D fake: 0.683049], [Enc/Dec loss: 0.092468, Enc/Dis: 0.082752]
# 152 [D real: 0.708720, D fake: 0.694143], [Enc/Dec loss: 0.087821, Enc/Dis: 0.077748]
# 153 [D real: 0.705767, D fake: 0.697632], [Enc/Dec loss: 0.093804, Enc/Dis: 0.084669]
# 154 [D real: 0.705582, D fake: 0.701686], [Enc/Dec loss: 0.095155, Enc/Dis: 0.081640]
# 155 [D real: 0.705373, D fake: 0.693725], [Enc/Dec loss: 0.097947, Enc/Dis: 0.082683]
# 156 [D real: 0.703233, D fake: 0.692840], [Enc/Dec loss: 0.098454, Enc/Dis: 0.085886]
# 157 [D real: 0.699752, D fake: 0.692429], [Enc/Dec loss: 0.096593, Enc/Dis: 0.082350]
# 158 [D real: 0.699668, D fake: 0.691389], [Enc/Dec loss: 0.089452, Enc/Dis: 0.081148]
# 159 [D real: 0.700996, D fake: 0.692354], [Enc/Dec loss: 0.089817, Enc/Dis: 0.082104]
# 160 [D real: 0.699696, D fake: 0.692409], [Enc/Dec loss: 0.088563, Enc/Dis: 0.078194]
# 161 [D real: 0.727484, D fake: 0.710257], [Enc/Dec loss: 0.089794, Enc/Dis: 0.078287]
# 162 [D real: 0.726890, D fake: 0.699103], [Enc/Dec loss: 0.088517, Enc/Dis: 0.078428]
# 163 [D real: 0.718635, D fake: 0.698352], [Enc/Dec loss: 0.089536, Enc/Dis: 0.081043]
# 164 [D real: 0.717527, D fake: 0.699722], [Enc/Dec loss: 0.087324, Enc/Dis: 0.079967]
# 165 [D real: 0.716813, D fake: 0.705757], [Enc/Dec loss: 0.091440, Enc/Dis: 0.076909]
# 166 [D real: 0.712789, D fake: 0.699179], [Enc/Dec loss: 0.082003, Enc/Dis: 0.077434]
# 167 [D real: 0.710437, D fake: 0.696237], [Enc/Dec loss: 0.095122, Enc/Dis: 0.080654]
# 168 [D real: 0.709719, D fake: 0.693469], [Enc/Dec loss: 0.097316, Enc/Dis: 0.085750]
# 169 [D real: 0.709099, D fake: 0.692517], [Enc/Dec loss: 0.097865, Enc/Dis: 0.086852]
# 170 [D real: 0.709281, D fake: 0.693423], [Enc/Dec loss: 0.082805, Enc/Dis: 0.075477]
# 171 [D real: 0.696423, D fake: 0.675440], [Enc/Dec loss: 0.089339, Enc/Dis: 0.078473]
# 172 [D real: 0.701997, D fake: 0.688411], [Enc/Dec loss: 0.094361, Enc/Dis: 0.082324]
# 173 [D real: 0.697115, D fake: 0.686988], [Enc/Dec loss: 0.090509, Enc/Dis: 0.079026]
# 174 [D real: 0.691989, D fake: 0.689432], [Enc/Dec loss: 0.087420, Enc/Dis: 0.082233]
# 175 [D real: 0.691042, D fake: 0.687851], [Enc/Dec loss: 0.098010, Enc/Dis: 0.088224]
# 176 [D real: 0.692417, D fake: 0.687623], [Enc/Dec loss: 0.093478, Enc/Dis: 0.082907]
# 177 [D real: 0.691325, D fake: 0.686552], [Enc/Dec loss: 0.092662, Enc/Dis: 0.085999]
# 178 [D real: 0.690532, D fake: 0.687250], [Enc/Dec loss: 0.090224, Enc/Dis: 0.080118]
# 179 [D real: 0.691639, D fake: 0.687314], [Enc/Dec loss: 0.091398, Enc/Dis: 0.079852]
# 180 [D real: 0.690644, D fake: 0.689330], [Enc/Dec loss: 0.089517, Enc/Dis: 0.076956]
# 181 [D real: 0.670766, D fake: 0.678261], [Enc/Dec loss: 0.094267, Enc/Dis: 0.082333]
# 182 [D real: 0.683362, D fake: 0.677987], [Enc/Dec loss: 0.089047, Enc/Dis: 0.081382]
# 183 [D real: 0.684665, D fake: 0.671906], [Enc/Dec loss: 0.086155, Enc/Dis: 0.081777]
# 184 [D real: 0.681828, D fake: 0.675230], [Enc/Dec loss: 0.085573, Enc/Dis: 0.078790]
# 185 [D real: 0.690168, D fake: 0.678944], [Enc/Dec loss: 0.082613, Enc/Dis: 0.073920]
# 186 [D real: 0.689523, D fake: 0.677701], [Enc/Dec loss: 0.091840, Enc/Dis: 0.080876]
# 187 [D real: 0.692376, D fake: 0.678077], [Enc/Dec loss: 0.091816, Enc/Dis: 0.082777]
# 188 [D real: 0.691466, D fake: 0.676816], [Enc/Dec loss: 0.103681, Enc/Dis: 0.081460]
# 189 [D real: 0.691172, D fake: 0.677677], [Enc/Dec loss: 0.094159, Enc/Dis: 0.081589]
# 190 [D real: 0.691083, D fake: 0.677228], [Enc/Dec loss: 0.083301, Enc/Dis: 0.076589]
# 191 [D real: 0.714350, D fake: 0.684864], [Enc/Dec loss: 0.089718, Enc/Dis: 0.075792]
# 192 [D real: 0.716289, D fake: 0.676029], [Enc/Dec loss: 0.088216, Enc/Dis: 0.081682]
# 193 [D real: 0.713968, D fake: 0.683967], [Enc/Dec loss: 0.085704, Enc/Dis: 0.076025]
# 194 [D real: 0.712284, D fake: 0.679576], [Enc/Dec loss: 0.088234, Enc/Dis: 0.078378]
# 195 [D real: 0.712652, D fake: 0.680884], [Enc/Dec loss: 0.088149, Enc/Dis: 0.080126]
# 196 [D real: 0.710301, D fake: 0.680681], [Enc/Dec loss: 0.099238, Enc/Dis: 0.088787]
# 197 [D real: 0.705954, D fake: 0.682405], [Enc/Dec loss: 0.086514, Enc/Dis: 0.080137]
# 198 [D real: 0.705858, D fake: 0.679200], [Enc/Dec loss: 0.088989, Enc/Dis: 0.081540]
# 199 [D real: 0.706552, D fake: 0.683494], [Enc/Dec loss: 0.084924, Enc/Dis: 0.080705]
# 200 [D real: 0.704170, D fake: 0.683983], [Enc/Dec loss: 0.091142, Enc/Dis: 0.084006]
# 201 [D real: 0.691570, D fake: 0.675585], [Enc/Dec loss: 0.096221, Enc/Dis: 0.081899]
# 202 [D real: 0.701192, D fake: 0.676678], [Enc/Dec loss: 0.099667, Enc/Dis: 0.091396]
# 203 [D real: 0.698899, D fake: 0.680504], [Enc/Dec loss: 0.087991, Enc/Dis: 0.078498]
# 204 [D real: 0.705180, D fake: 0.673006], [Enc/Dec loss: 0.090538, Enc/Dis: 0.081919]
# 205 [D real: 0.702069, D fake: 0.673399], [Enc/Dec loss: 0.086522, Enc/Dis: 0.078954]
# 206 [D real: 0.698699, D fake: 0.672692], [Enc/Dec loss: 0.095566, Enc/Dis: 0.082984]
# 207 [D real: 0.696947, D fake: 0.670433], [Enc/Dec loss: 0.085563, Enc/Dis: 0.076911]
# 208 [D real: 0.696962, D fake: 0.673509], [Enc/Dec loss: 0.089028, Enc/Dis: 0.080791]
# 209 [D real: 0.697243, D fake: 0.673114], [Enc/Dec loss: 0.085403, Enc/Dis: 0.075661]
# 210 [D real: 0.695923, D fake: 0.672238], [Enc/Dec loss: 0.099964, Enc/Dis: 0.076495]
# 211 [D real: 0.715775, D fake: 0.673863], [Enc/Dec loss: 0.087768, Enc/Dis: 0.078937]
# 212 [D real: 0.711980, D fake: 0.673617], [Enc/Dec loss: 0.088182, Enc/Dis: 0.072471]
# 213 [D real: 0.699880, D fake: 0.666303], [Enc/Dec loss: 0.093131, Enc/Dis: 0.085297]
# 214 [D real: 0.694766, D fake: 0.670133], [Enc/Dec loss: 0.103076, Enc/Dis: 0.084750]
# 215 [D real: 0.698478, D fake: 0.668740], [Enc/Dec loss: 0.094468, Enc/Dis: 0.086589]
# 216 [D real: 0.701945, D fake: 0.673932], [Enc/Dec loss: 0.088063, Enc/Dis: 0.082721]
# 217 [D real: 0.700881, D fake: 0.673625], [Enc/Dec loss: 0.085868, Enc/Dis: 0.080193]
# 218 [D real: 0.699806, D fake: 0.671963], [Enc/Dec loss: 0.087336, Enc/Dis: 0.081472]
# 219 [D real: 0.698159, D fake: 0.671508], [Enc/Dec loss: 0.084787, Enc/Dis: 0.079185]
# 220 [D real: 0.696204, D fake: 0.671467], [Enc/Dec loss: 0.088610, Enc/Dis: 0.079394]
# 221 [D real: 0.693730, D fake: 0.661792], [Enc/Dec loss: 0.087856, Enc/Dis: 0.077459]
# 222 [D real: 0.702923, D fake: 0.662952], [Enc/Dec loss: 0.090489, Enc/Dis: 0.081801]
# 223 [D real: 0.694677, D fake: 0.665962], [Enc/Dec loss: 0.090184, Enc/Dis: 0.083169]
# 224 [D real: 0.703330, D fake: 0.665444], [Enc/Dec loss: 0.084535, Enc/Dis: 0.078773]
# 225 [D real: 0.703194, D fake: 0.666446], [Enc/Dec loss: 0.085282, Enc/Dis: 0.074957]
# 226 [D real: 0.705573, D fake: 0.665128], [Enc/Dec loss: 0.088516, Enc/Dis: 0.078869]
# 227 [D real: 0.704954, D fake: 0.663720], [Enc/Dec loss: 0.089528, Enc/Dis: 0.078499]
# 228 [D real: 0.706014, D fake: 0.667452], [Enc/Dec loss: 0.091181, Enc/Dis: 0.076513]
# 229 [D real: 0.703550, D fake: 0.665543], [Enc/Dec loss: 0.087118, Enc/Dis: 0.074757]
# 230 [D real: 0.701651, D fake: 0.662767], [Enc/Dec loss: 0.084578, Enc/Dis: 0.074391]
# 231 [D real: 0.693739, D fake: 0.676302], [Enc/Dec loss: 0.088150, Enc/Dis: 0.077794]
# 232 [D real: 0.682503, D fake: 0.668057], [Enc/Dec loss: 0.090802, Enc/Dis: 0.083124]
# 233 [D real: 0.681338, D fake: 0.671390], [Enc/Dec loss: 0.085816, Enc/Dis: 0.076881]
# 234 [D real: 0.691512, D fake: 0.667860], [Enc/Dec loss: 0.088412, Enc/Dis: 0.079576]
# 235 [D real: 0.689924, D fake: 0.667318], [Enc/Dec loss: 0.078926, Enc/Dis: 0.072197]
# 236 [D real: 0.692454, D fake: 0.666631], [Enc/Dec loss: 0.084264, Enc/Dis: 0.076026]
# 237 [D real: 0.694641, D fake: 0.666070], [Enc/Dec loss: 0.084318, Enc/Dis: 0.077099]
# 238 [D real: 0.696378, D fake: 0.666511], [Enc/Dec loss: 0.085291, Enc/Dis: 0.079320]
# 239 [D real: 0.698208, D fake: 0.662747], [Enc/Dec loss: 0.081491, Enc/Dis: 0.075795]
# 240 [D real: 0.699962, D fake: 0.660139], [Enc/Dec loss: 0.083786, Enc/Dis: 0.077592]
# 241 [D real: 0.722395, D fake: 0.667945], [Enc/Dec loss: 0.086791, Enc/Dis: 0.078271]
# 242 [D real: 0.722383, D fake: 0.653250], [Enc/Dec loss: 0.085705, Enc/Dis: 0.078352]
# 243 [D real: 0.724168, D fake: 0.653146], [Enc/Dec loss: 0.084301, Enc/Dis: 0.077701]
# 244 [D real: 0.715281, D fake: 0.642179], [Enc/Dec loss: 0.087599, Enc/Dis: 0.079260]
# 245 [D real: 0.711477, D fake: 0.640786], [Enc/Dec loss: 0.089408, Enc/Dis: 0.081012]
# 246 [D real: 0.710152, D fake: 0.645918], [Enc/Dec loss: 0.086556, Enc/Dis: 0.079243]
# 247 [D real: 0.708046, D fake: 0.650315], [Enc/Dec loss: 0.086258, Enc/Dis: 0.079488]
# 248 [D real: 0.703438, D fake: 0.654111], [Enc/Dec loss: 0.084442, Enc/Dis: 0.076752]
# 249 [D real: 0.700333, D fake: 0.653127], [Enc/Dec loss: 0.084240, Enc/Dis: 0.075012]
# 250 [D real: 0.701811, D fake: 0.652323], [Enc/Dec loss: 0.083832, Enc/Dis: 0.074887]
# 251 [D real: 0.671340, D fake: 0.659400], [Enc/Dec loss: 0.087558, Enc/Dis: 0.081682]
# 252 [D real: 0.668489, D fake: 0.656895], [Enc/Dec loss: 0.084335, Enc/Dis: 0.078384]
# 253 [D real: 0.671847, D fake: 0.657062], [Enc/Dec loss: 0.095313, Enc/Dis: 0.076260]
# 254 [D real: 0.675702, D fake: 0.655028], [Enc/Dec loss: 0.086553, Enc/Dis: 0.074338]
# 255 [D real: 0.679947, D fake: 0.650544], [Enc/Dec loss: 0.081396, Enc/Dis: 0.076017]
# 256 [D real: 0.678429, D fake: 0.643605], [Enc/Dec loss: 0.089933, Enc/Dis: 0.082235]
# 257 [D real: 0.678153, D fake: 0.641459], [Enc/Dec loss: 0.079120, Enc/Dis: 0.071063]
# 258 [D real: 0.677773, D fake: 0.644982], [Enc/Dec loss: 0.087805, Enc/Dis: 0.077849]
# 259 [D real: 0.676946, D fake: 0.643099], [Enc/Dec loss: 0.086545, Enc/Dis: 0.076301]
# 260 [D real: 0.676704, D fake: 0.643765], [Enc/Dec loss: 0.091249, Enc/Dis: 0.080129]
# 261 [D real: 0.693348, D fake: 0.672201], [Enc/Dec loss: 0.087467, Enc/Dis: 0.080076]
# 262 [D real: 0.706429, D fake: 0.660801], [Enc/Dec loss: 0.095220, Enc/Dis: 0.079463]
# 263 [D real: 0.697440, D fake: 0.655204], [Enc/Dec loss: 0.084306, Enc/Dis: 0.074386]
# 264 [D real: 0.697470, D fake: 0.649228], [Enc/Dec loss: 0.078490, Enc/Dis: 0.075459]
# 265 [D real: 0.693926, D fake: 0.651933], [Enc/Dec loss: 0.078499, Enc/Dis: 0.072736]
# 266 [D real: 0.689792, D fake: 0.651564], [Enc/Dec loss: 0.084538, Enc/Dis: 0.078539]
# 267 [D real: 0.688852, D fake: 0.652141], [Enc/Dec loss: 0.079257, Enc/Dis: 0.069994]
# 268 [D real: 0.684139, D fake: 0.655567], [Enc/Dec loss: 0.089177, Enc/Dis: 0.081330]
# 269 [D real: 0.685729, D fake: 0.655303], [Enc/Dec loss: 0.084876, Enc/Dis: 0.078434]
# 270 [D real: 0.684383, D fake: 0.654272], [Enc/Dec loss: 0.087604, Enc/Dis: 0.080757]
# 271 [D real: 0.681646, D fake: 0.650542], [Enc/Dec loss: 0.088526, Enc/Dis: 0.081153]
# 272 [D real: 0.702143, D fake: 0.646439], [Enc/Dec loss: 0.085042, Enc/Dis: 0.077162]
# 273 [D real: 0.688358, D fake: 0.638623], [Enc/Dec loss: 0.084140, Enc/Dis: 0.075580]
# 274 [D real: 0.687579, D fake: 0.633164], [Enc/Dec loss: 0.092650, Enc/Dis: 0.084431]
# 275 [D real: 0.684331, D fake: 0.627951], [Enc/Dec loss: 0.083363, Enc/Dis: 0.074689]
# 276 [D real: 0.678367, D fake: 0.644614], [Enc/Dec loss: 0.084370, Enc/Dis: 0.074798]
# 277 [D real: 0.675324, D fake: 0.649456], [Enc/Dec loss: 0.087255, Enc/Dis: 0.075979]
# 278 [D real: 0.675053, D fake: 0.649690], [Enc/Dec loss: 0.084744, Enc/Dis: 0.076069]
# 279 [D real: 0.682881, D fake: 0.650107], [Enc/Dec loss: 0.078450, Enc/Dis: 0.072701]
# 280 [D real: 0.685145, D fake: 0.649405], [Enc/Dec loss: 0.087212, Enc/Dis: 0.079079]
# 281 [D real: 0.720007, D fake: 0.635529], [Enc/Dec loss: 0.081527, Enc/Dis: 0.072495]
# 282 [D real: 0.681465, D fake: 0.657307], [Enc/Dec loss: 0.089129, Enc/Dis: 0.083643]
# 283 [D real: 0.670246, D fake: 0.651784], [Enc/Dec loss: 0.087414, Enc/Dis: 0.081041]
# 284 [D real: 0.670166, D fake: 0.653180], [Enc/Dec loss: 0.082668, Enc/Dis: 0.073559]
# 285 [D real: 0.674687, D fake: 0.646676], [Enc/Dec loss: 0.082520, Enc/Dis: 0.074353]
# 286 [D real: 0.674056, D fake: 0.641226], [Enc/Dec loss: 0.082699, Enc/Dis: 0.076777]
# 287 [D real: 0.676176, D fake: 0.645735], [Enc/Dec loss: 0.081256, Enc/Dis: 0.076073]
# 288 [D real: 0.677808, D fake: 0.640694], [Enc/Dec loss: 0.083420, Enc/Dis: 0.076822]
# 289 [D real: 0.674901, D fake: 0.641031], [Enc/Dec loss: 0.081290, Enc/Dis: 0.077202]
# 290 [D real: 0.673426, D fake: 0.637660], [Enc/Dec loss: 0.082807, Enc/Dis: 0.077632]
# 291 [D real: 0.666409, D fake: 0.637432], [Enc/Dec loss: 0.075513, Enc/Dis: 0.070911]
# 292 [D real: 0.681407, D fake: 0.623334], [Enc/Dec loss: 0.076799, Enc/Dis: 0.071802]
# 293 [D real: 0.684739, D fake: 0.641570], [Enc/Dec loss: 0.076272, Enc/Dis: 0.070580]
# 294 [D real: 0.670839, D fake: 0.649040], [Enc/Dec loss: 0.083500, Enc/Dis: 0.078392]
# 295 [D real: 0.668382, D fake: 0.643325], [Enc/Dec loss: 0.076757, Enc/Dis: 0.071651]
# 296 [D real: 0.662417, D fake: 0.643120], [Enc/Dec loss: 0.084459, Enc/Dis: 0.078934]
# 297 [D real: 0.661453, D fake: 0.640858], [Enc/Dec loss: 0.078254, Enc/Dis: 0.072303]
# 298 [D real: 0.653626, D fake: 0.639761], [Enc/Dec loss: 0.080833, Enc/Dis: 0.074164]
# 299 [D real: 0.649644, D fake: 0.638080], [Enc/Dec loss: 0.085687, Enc/Dis: 0.078486]
# 300 [D real: 0.649598, D fake: 0.635476], [Enc/Dec loss: 0.081766, Enc/Dis: 0.077247]
# 301 [D real: 0.647111, D fake: 0.634157], [Enc/Dec loss: 0.086138, Enc/Dis: 0.082429]
# 302 [D real: 0.630222, D fake: 0.626017], [Enc/Dec loss: 0.083761, Enc/Dis: 0.074584]
# 303 [D real: 0.631831, D fake: 0.626927], [Enc/Dec loss: 0.084477, Enc/Dis: 0.068157]
# 304 [D real: 0.636757, D fake: 0.632291], [Enc/Dec loss: 0.095680, Enc/Dis: 0.085024]
# 305 [D real: 0.639100, D fake: 0.642529], [Enc/Dec loss: 0.078253, Enc/Dis: 0.075270]
# 306 [D real: 0.639082, D fake: 0.639585], [Enc/Dec loss: 0.082096, Enc/Dis: 0.078505]
# 307 [D real: 0.645730, D fake: 0.642261], [Enc/Dec loss: 0.078490, Enc/Dis: 0.074622]
# 308 [D real: 0.650737, D fake: 0.638229], [Enc/Dec loss: 0.094738, Enc/Dis: 0.082607]
# 309 [D real: 0.649887, D fake: 0.635939], [Enc/Dec loss: 0.093959, Enc/Dis: 0.077989]
# 310 [D real: 0.646239, D fake: 0.635059], [Enc/Dec loss: 0.091222, Enc/Dis: 0.082830]
# 311 [D real: 0.645283, D fake: 0.627497], [Enc/Dec loss: 0.086130, Enc/Dis: 0.079510]
# 312 [D real: 0.647760, D fake: 0.620636], [Enc/Dec loss: 0.082278, Enc/Dis: 0.075129]
# 313 [D real: 0.649347, D fake: 0.602594], [Enc/Dec loss: 0.084656, Enc/Dis: 0.076665]
# 314 [D real: 0.648385, D fake: 0.602707], [Enc/Dec loss: 0.086529, Enc/Dis: 0.079434]
# 315 [D real: 0.654597, D fake: 0.607850], [Enc/Dec loss: 0.083837, Enc/Dis: 0.077003]
# 316 [D real: 0.651768, D fake: 0.610875], [Enc/Dec loss: 0.084631, Enc/Dis: 0.078595]
# 317 [D real: 0.653220, D fake: 0.608262], [Enc/Dec loss: 0.084106, Enc/Dis: 0.078379]
# 318 [D real: 0.655822, D fake: 0.607680], [Enc/Dec loss: 0.085851, Enc/Dis: 0.078558]
# 319 [D real: 0.653356, D fake: 0.606171], [Enc/Dec loss: 0.088015, Enc/Dis: 0.082424]
# 320 [D real: 0.649967, D fake: 0.610224], [Enc/Dec loss: 0.073078, Enc/Dis: 0.067785]
# 321 [D real: 0.614167, D fake: 0.627459], [Enc/Dec loss: 0.078850, Enc/Dis: 0.073985]
# 322 [D real: 0.641198, D fake: 0.606402], [Enc/Dec loss: 0.085008, Enc/Dis: 0.080912]
# 323 [D real: 0.632441, D fake: 0.608056], [Enc/Dec loss: 0.082675, Enc/Dis: 0.078837]
# 324 [D real: 0.641523, D fake: 0.602928], [Enc/Dec loss: 0.086608, Enc/Dis: 0.082521]
# 325 [D real: 0.638561, D fake: 0.600631], [Enc/Dec loss: 0.075709, Enc/Dis: 0.071292]
# 326 [D real: 0.641705, D fake: 0.605131], [Enc/Dec loss: 0.075710, Enc/Dis: 0.073956]
# 327 [D real: 0.635983, D fake: 0.599651], [Enc/Dec loss: 0.085998, Enc/Dis: 0.079424]
# 328 [D real: 0.638104, D fake: 0.599026], [Enc/Dec loss: 0.086368, Enc/Dis: 0.075928]
# 329 [D real: 0.635106, D fake: 0.601248], [Enc/Dec loss: 0.082629, Enc/Dis: 0.073980]
# 330 [D real: 0.639968, D fake: 0.599739], [Enc/Dec loss: 0.080849, Enc/Dis: 0.074340]
# 331 [D real: 0.612233, D fake: 0.581888], [Enc/Dec loss: 0.087512, Enc/Dis: 0.081078]
# 332 [D real: 0.639535, D fake: 0.574321], [Enc/Dec loss: 0.085541, Enc/Dis: 0.079108]
# 333 [D real: 0.630675, D fake: 0.594874], [Enc/Dec loss: 0.071449, Enc/Dis: 0.064531]
# 334 [D real: 0.641478, D fake: 0.598694], [Enc/Dec loss: 0.082177, Enc/Dis: 0.073956]
# 335 [D real: 0.641500, D fake: 0.593731], [Enc/Dec loss: 0.091778, Enc/Dis: 0.080996]
# 336 [D real: 0.640005, D fake: 0.588062], [Enc/Dec loss: 0.080547, Enc/Dis: 0.071569]
# 337 [D real: 0.646576, D fake: 0.589375], [Enc/Dec loss: 0.077939, Enc/Dis: 0.072277]
# 338 [D real: 0.641882, D fake: 0.595371], [Enc/Dec loss: 0.083136, Enc/Dis: 0.078611]
# 339 [D real: 0.637231, D fake: 0.594029], [Enc/Dec loss: 0.088425, Enc/Dis: 0.084160]
# 340 [D real: 0.631314, D fake: 0.595485], [Enc/Dec loss: 0.086626, Enc/Dis: 0.069864]
# 341 [D real: 0.630209, D fake: 0.610824], [Enc/Dec loss: 0.084553, Enc/Dis: 0.075459]
# 342 [D real: 0.624004, D fake: 0.588449], [Enc/Dec loss: 0.081042, Enc/Dis: 0.075677]
# 343 [D real: 0.623943, D fake: 0.582947], [Enc/Dec loss: 0.082574, Enc/Dis: 0.077237]
# 344 [D real: 0.607991, D fake: 0.574550], [Enc/Dec loss: 0.081252, Enc/Dis: 0.075486]
# 345 [D real: 0.613724, D fake: 0.588540], [Enc/Dec loss: 0.084490, Enc/Dis: 0.078113]
# 346 [D real: 0.620088, D fake: 0.584649], [Enc/Dec loss: 0.082837, Enc/Dis: 0.075928]
# 347 [D real: 0.626123, D fake: 0.587189], [Enc/Dec loss: 0.079551, Enc/Dis: 0.072613]
# 348 [D real: 0.627647, D fake: 0.586174], [Enc/Dec loss: 0.085580, Enc/Dis: 0.078594]
# 349 [D real: 0.630700, D fake: 0.586870], [Enc/Dec loss: 0.086376, Enc/Dis: 0.078804]
# 350 [D real: 0.623560, D fake: 0.590240], [Enc/Dec loss: 0.084057, Enc/Dis: 0.079116]
# 351 [D real: 0.637286, D fake: 0.568402], [Enc/Dec loss: 0.073207, Enc/Dis: 0.068551]
# 352 [D real: 0.600874, D fake: 0.575365], [Enc/Dec loss: 0.085310, Enc/Dis: 0.079378]
# 353 [D real: 0.621904, D fake: 0.570994], [Enc/Dec loss: 0.078165, Enc/Dis: 0.067509]
# 354 [D real: 0.612110, D fake: 0.578863], [Enc/Dec loss: 0.090112, Enc/Dis: 0.078220]
# 355 [D real: 0.633107, D fake: 0.593784], [Enc/Dec loss: 0.085177, Enc/Dis: 0.077204]
# 356 [D real: 0.632655, D fake: 0.597194], [Enc/Dec loss: 0.088552, Enc/Dis: 0.080070]
# 357 [D real: 0.627778, D fake: 0.592689], [Enc/Dec loss: 0.082040, Enc/Dis: 0.070319]
# 358 [D real: 0.626927, D fake: 0.593221], [Enc/Dec loss: 0.080782, Enc/Dis: 0.079258]
# 359 [D real: 0.619620, D fake: 0.595696], [Enc/Dec loss: 0.083687, Enc/Dis: 0.076160]
# 360 [D real: 0.616337, D fake: 0.597245], [Enc/Dec loss: 0.082158, Enc/Dis: 0.077755]
# 361 [D real: 0.591954, D fake: 0.607385], [Enc/Dec loss: 0.086372, Enc/Dis: 0.072680]
# 362 [D real: 0.615482, D fake: 0.575231], [Enc/Dec loss: 0.081634, Enc/Dis: 0.072725]
# 363 [D real: 0.603354, D fake: 0.578419], [Enc/Dec loss: 0.087756, Enc/Dis: 0.082482]
# 364 [D real: 0.615058, D fake: 0.582897], [Enc/Dec loss: 0.078199, Enc/Dis: 0.074807]
# 365 [D real: 0.617685, D fake: 0.587091], [Enc/Dec loss: 0.083101, Enc/Dis: 0.078605]
# 366 [D real: 0.608438, D fake: 0.596162], [Enc/Dec loss: 0.084436, Enc/Dis: 0.078224]
# 367 [D real: 0.608342, D fake: 0.599897], [Enc/Dec loss: 0.078353, Enc/Dis: 0.074998]
# 368 [D real: 0.605925, D fake: 0.593374], [Enc/Dec loss: 0.079527, Enc/Dis: 0.076441]
# 369 [D real: 0.605336, D fake: 0.588797], [Enc/Dec loss: 0.080207, Enc/Dis: 0.076088]
# 370 [D real: 0.614358, D fake: 0.589628], [Enc/Dec loss: 0.080173, Enc/Dis: 0.074970]
# 371 [D real: 0.600125, D fake: 0.565562], [Enc/Dec loss: 0.086442, Enc/Dis: 0.081249]
# 372 [D real: 0.607323, D fake: 0.573539], [Enc/Dec loss: 0.083891, Enc/Dis: 0.077853]
# 373 [D real: 0.630963, D fake: 0.571267], [Enc/Dec loss: 0.073620, Enc/Dis: 0.069360]
# 374 [D real: 0.623900, D fake: 0.576612], [Enc/Dec loss: 0.082846, Enc/Dis: 0.080194]
# 375 [D real: 0.628421, D fake: 0.578416], [Enc/Dec loss: 0.080036, Enc/Dis: 0.077061]
# 376 [D real: 0.623372, D fake: 0.574343], [Enc/Dec loss: 0.078055, Enc/Dis: 0.074448]
# 377 [D real: 0.625994, D fake: 0.577663], [Enc/Dec loss: 0.077353, Enc/Dis: 0.073674]
# 378 [D real: 0.618257, D fake: 0.583684], [Enc/Dec loss: 0.074667, Enc/Dis: 0.070690]
# 379 [D real: 0.615495, D fake: 0.579206], [Enc/Dec loss: 0.079943, Enc/Dis: 0.075589]
# 380 [D real: 0.617993, D fake: 0.577755], [Enc/Dec loss: 0.078457, Enc/Dis: 0.073173]
# 381 [D real: 0.551481, D fake: 0.601550], [Enc/Dec loss: 0.077554, Enc/Dis: 0.071918]
# 382 [D real: 0.560424, D fake: 0.578790], [Enc/Dec loss: 0.087298, Enc/Dis: 0.081745]
# 383 [D real: 0.551630, D fake: 0.587155], [Enc/Dec loss: 0.077579, Enc/Dis: 0.072263]
# 384 [D real: 0.561838, D fake: 0.584087], [Enc/Dec loss: 0.085806, Enc/Dis: 0.081222]
# 385 [D real: 0.580878, D fake: 0.586512], [Enc/Dec loss: 0.075335, Enc/Dis: 0.072019]
# 386 [D real: 0.582499, D fake: 0.592532], [Enc/Dec loss: 0.076386, Enc/Dis: 0.071802]
# 387 [D real: 0.585073, D fake: 0.588961], [Enc/Dec loss: 0.089715, Enc/Dis: 0.077385]
# 388 [D real: 0.585850, D fake: 0.593543], [Enc/Dec loss: 0.087699, Enc/Dis: 0.073954]
# 389 [D real: 0.586685, D fake: 0.593732], [Enc/Dec loss: 0.082492, Enc/Dis: 0.073549]
# 390 [D real: 0.585216, D fake: 0.589385], [Enc/Dec loss: 0.082064, Enc/Dis: 0.076366]
# 391 [D real: 0.565906, D fake: 0.557048], [Enc/Dec loss: 0.077026, Enc/Dis: 0.070924]
# 392 [D real: 0.580825, D fake: 0.566130], [Enc/Dec loss: 0.077461, Enc/Dis: 0.070852]
# 393 [D real: 0.608436, D fake: 0.579591], [Enc/Dec loss: 0.083781, Enc/Dis: 0.077482]
# 394 [D real: 0.593105, D fake: 0.576801], [Enc/Dec loss: 0.081872, Enc/Dis: 0.076205]
# 395 [D real: 0.602839, D fake: 0.568170], [Enc/Dec loss: 0.081677, Enc/Dis: 0.075628]
# 396 [D real: 0.594486, D fake: 0.575427], [Enc/Dec loss: 0.072301, Enc/Dis: 0.067322]
# 397 [D real: 0.590814, D fake: 0.586472], [Enc/Dec loss: 0.081769, Enc/Dis: 0.075477]
# 398 [D real: 0.590362, D fake: 0.586227], [Enc/Dec loss: 0.091266, Enc/Dis: 0.085886]
# 399 [D real: 0.592728, D fake: 0.588596], [Enc/Dec loss: 0.080382, Enc/Dis: 0.075350]
# 400 [D real: 0.592057, D fake: 0.588232], [Enc/Dec loss: 0.077092, Enc/Dis: 0.072326]
# 401 [D real: 0.557892, D fake: 0.543322], [Enc/Dec loss: 0.078509, Enc/Dis: 0.074385]
# 402 [D real: 0.611728, D fake: 0.534717], [Enc/Dec loss: 0.078067, Enc/Dis: 0.074226]
# 403 [D real: 0.601740, D fake: 0.537368], [Enc/Dec loss: 0.076430, Enc/Dis: 0.072306]
# 404 [D real: 0.579357, D fake: 0.542820], [Enc/Dec loss: 0.076575, Enc/Dis: 0.072205]
# 405 [D real: 0.586103, D fake: 0.546445], [Enc/Dec loss: 0.074933, Enc/Dis: 0.070445]
# 406 [D real: 0.597167, D fake: 0.549105], [Enc/Dec loss: 0.081056, Enc/Dis: 0.077493]
# 407 [D real: 0.609178, D fake: 0.552630], [Enc/Dec loss: 0.077560, Enc/Dis: 0.074171]
# 408 [D real: 0.607768, D fake: 0.554602], [Enc/Dec loss: 0.078260, Enc/Dis: 0.074018]
# 409 [D real: 0.608156, D fake: 0.558879], [Enc/Dec loss: 0.082983, Enc/Dis: 0.077905]
# 410 [D real: 0.602099, D fake: 0.560531], [Enc/Dec loss: 0.079004, Enc/Dis: 0.074688]
# 411 [D real: 0.580140, D fake: 0.578760], [Enc/Dec loss: 0.077547, Enc/Dis: 0.070857]
# 412 [D real: 0.550604, D fake: 0.609894], [Enc/Dec loss: 0.089057, Enc/Dis: 0.080740]
# 413 [D real: 0.561278, D fake: 0.612020], [Enc/Dec loss: 0.085292, Enc/Dis: 0.078685]
# 414 [D real: 0.556756, D fake: 0.587617], [Enc/Dec loss: 0.077519, Enc/Dis: 0.071148]
# 415 [D real: 0.558739, D fake: 0.577396], [Enc/Dec loss: 0.078109, Enc/Dis: 0.073636]
# 416 [D real: 0.556735, D fake: 0.583464], [Enc/Dec loss: 0.081429, Enc/Dis: 0.076654]
# 417 [D real: 0.545557, D fake: 0.578763], [Enc/Dec loss: 0.078829, Enc/Dis: 0.074201]
# 418 [D real: 0.548558, D fake: 0.578719], [Enc/Dec loss: 0.080147, Enc/Dis: 0.076572]
# 419 [D real: 0.547938, D fake: 0.572383], [Enc/Dec loss: 0.087650, Enc/Dis: 0.078270]
# 420 [D real: 0.554392, D fake: 0.568960], [Enc/Dec loss: 0.079813, Enc/Dis: 0.072924]
# 421 [D real: 0.585733, D fake: 0.583849], [Enc/Dec loss: 0.081974, Enc/Dis: 0.074335]
# 422 [D real: 0.620296, D fake: 0.572890], [Enc/Dec loss: 0.089686, Enc/Dis: 0.082272]
# 423 [D real: 0.602632, D fake: 0.558972], [Enc/Dec loss: 0.076154, Enc/Dis: 0.071900]
# 424 [D real: 0.593752, D fake: 0.542477], [Enc/Dec loss: 0.073188, Enc/Dis: 0.071661]
# 425 [D real: 0.579071, D fake: 0.530634], [Enc/Dec loss: 0.083300, Enc/Dis: 0.080738]
# 426 [D real: 0.587688, D fake: 0.529437], [Enc/Dec loss: 0.077419, Enc/Dis: 0.071926]
# 427 [D real: 0.576592, D fake: 0.529050], [Enc/Dec loss: 0.080629, Enc/Dis: 0.074898]
# 428 [D real: 0.581107, D fake: 0.530577], [Enc/Dec loss: 0.086401, Enc/Dis: 0.080506]
# 429 [D real: 0.580233, D fake: 0.528943], [Enc/Dec loss: 0.082794, Enc/Dis: 0.076837]
# 430 [D real: 0.578408, D fake: 0.531178], [Enc/Dec loss: 0.084434, Enc/Dis: 0.078362]
# 431 [D real: 0.544379, D fake: 0.539217], [Enc/Dec loss: 0.077022, Enc/Dis: 0.073964]
# 432 [D real: 0.537948, D fake: 0.531449], [Enc/Dec loss: 0.100701, Enc/Dis: 0.078496]
# 433 [D real: 0.555245, D fake: 0.526592], [Enc/Dec loss: 0.092804, Enc/Dis: 0.068506]
# 434 [D real: 0.545455, D fake: 0.536009], [Enc/Dec loss: 0.081134, Enc/Dis: 0.067740]
# 435 [D real: 0.552712, D fake: 0.540806], [Enc/Dec loss: 0.081662, Enc/Dis: 0.073459]
# 436 [D real: 0.551606, D fake: 0.544904], [Enc/Dec loss: 0.083949, Enc/Dis: 0.077284]
# 437 [D real: 0.548642, D fake: 0.540843], [Enc/Dec loss: 0.081295, Enc/Dis: 0.077489]
# 438 [D real: 0.546337, D fake: 0.533628], [Enc/Dec loss: 0.079960, Enc/Dis: 0.077850]
# 439 [D real: 0.554469, D fake: 0.533027], [Enc/Dec loss: 0.087722, Enc/Dis: 0.074721]
# 440 [D real: 0.547388, D fake: 0.530930], [Enc/Dec loss: 0.099858, Enc/Dis: 0.086219]
# 441 [D real: 0.492054, D fake: 0.550338], [Enc/Dec loss: 0.075407, Enc/Dis: 0.070879]
# 442 [D real: 0.549174, D fake: 0.534376], [Enc/Dec loss: 0.084818, Enc/Dis: 0.078035]
# 443 [D real: 0.572221, D fake: 0.529839], [Enc/Dec loss: 0.082695, Enc/Dis: 0.075650]
# 444 [D real: 0.556011, D fake: 0.530090], [Enc/Dec loss: 0.082111, Enc/Dis: 0.075948]
# 445 [D real: 0.536486, D fake: 0.547596], [Enc/Dec loss: 0.077761, Enc/Dis: 0.072616]
# 446 [D real: 0.523524, D fake: 0.541331], [Enc/Dec loss: 0.077064, Enc/Dis: 0.072431]
# 447 [D real: 0.522777, D fake: 0.543796], [Enc/Dec loss: 0.084721, Enc/Dis: 0.080056]
# 448 [D real: 0.518900, D fake: 0.541394], [Enc/Dec loss: 0.076048, Enc/Dis: 0.070964]
# 449 [D real: 0.519627, D fake: 0.534389], [Enc/Dec loss: 0.079094, Enc/Dis: 0.074280]
# 450 [D real: 0.520867, D fake: 0.536556], [Enc/Dec loss: 0.080743, Enc/Dis: 0.075938]
# 451 [D real: 0.604355, D fake: 0.534770], [Enc/Dec loss: 0.080351, Enc/Dis: 0.075699]
# 452 [D real: 0.588512, D fake: 0.540623], [Enc/Dec loss: 0.075425, Enc/Dis: 0.071015]
# 453 [D real: 0.576991, D fake: 0.528978], [Enc/Dec loss: 0.080785, Enc/Dis: 0.076438]
# 454 [D real: 0.546451, D fake: 0.529313], [Enc/Dec loss: 0.077318, Enc/Dis: 0.073057]
# 455 [D real: 0.535473, D fake: 0.527891], [Enc/Dec loss: 0.073422, Enc/Dis: 0.070383]
# 456 [D real: 0.527102, D fake: 0.519868], [Enc/Dec loss: 0.075293, Enc/Dis: 0.072674]
# 457 [D real: 0.516598, D fake: 0.525010], [Enc/Dec loss: 0.076653, Enc/Dis: 0.073163]
# 458 [D real: 0.511966, D fake: 0.532557], [Enc/Dec loss: 0.081253, Enc/Dis: 0.077405]
# 459 [D real: 0.520475, D fake: 0.527043], [Enc/Dec loss: 0.075298, Enc/Dis: 0.071247]
# 460 [D real: 0.528205, D fake: 0.519474], [Enc/Dec loss: 0.084375, Enc/Dis: 0.076312]
# 461 [D real: 0.574792, D fake: 0.487602], [Enc/Dec loss: 0.100936, Enc/Dis: 0.076387]
# 462 [D real: 0.499697, D fake: 0.512565], [Enc/Dec loss: 0.091881, Enc/Dis: 0.077307]
# 463 [D real: 0.513630, D fake: 0.531531], [Enc/Dec loss: 0.079814, Enc/Dis: 0.070678]
# 464 [D real: 0.513508, D fake: 0.512226], [Enc/Dec loss: 0.085971, Enc/Dis: 0.078218]
# 465 [D real: 0.514414, D fake: 0.508329], [Enc/Dec loss: 0.086401, Enc/Dis: 0.079554]
# 466 [D real: 0.505347, D fake: 0.501884], [Enc/Dec loss: 0.076488, Enc/Dis: 0.069714]
# 467 [D real: 0.505070, D fake: 0.494383], [Enc/Dec loss: 0.079958, Enc/Dis: 0.073777]
# 468 [D real: 0.502881, D fake: 0.494865], [Enc/Dec loss: 0.090816, Enc/Dis: 0.077717]
# 469 [D real: 0.503066, D fake: 0.489165], [Enc/Dec loss: 0.085505, Enc/Dis: 0.075058]
# 470 [D real: 0.501174, D fake: 0.491535], [Enc/Dec loss: 0.072946, Enc/Dis: 0.069054]
# 471 [D real: 0.545296, D fake: 0.516688], [Enc/Dec loss: 0.075087, Enc/Dis: 0.073725]
# 472 [D real: 0.526960, D fake: 0.514092], [Enc/Dec loss: 0.081194, Enc/Dis: 0.079487]
# 473 [D real: 0.539934, D fake: 0.508475], [Enc/Dec loss: 0.084653, Enc/Dis: 0.082582]
# 474 [D real: 0.550386, D fake: 0.506600], [Enc/Dec loss: 0.075666, Enc/Dis: 0.073157]
# 475 [D real: 0.549296, D fake: 0.517201], [Enc/Dec loss: 0.083745, Enc/Dis: 0.081114]
# 476 [D real: 0.519974, D fake: 0.523056], [Enc/Dec loss: 0.079034, Enc/Dis: 0.076658]
# 477 [D real: 0.527292, D fake: 0.518906], [Enc/Dec loss: 0.073269, Enc/Dis: 0.070574]
# 478 [D real: 0.524744, D fake: 0.514272], [Enc/Dec loss: 0.076087, Enc/Dis: 0.073407]
# 479 [D real: 0.519393, D fake: 0.505486], [Enc/Dec loss: 0.074488, Enc/Dis: 0.071548]
# 480 [D real: 0.514125, D fake: 0.511344], [Enc/Dec loss: 0.076650, Enc/Dis: 0.072984]
# 481 [D real: 0.464887, D fake: 0.471895], [Enc/Dec loss: 0.075136, Enc/Dis: 0.073278]
# 482 [D real: 0.453601, D fake: 0.560065], [Enc/Dec loss: 0.078588, Enc/Dis: 0.076846]
# 483 [D real: 0.484338, D fake: 0.531678], [Enc/Dec loss: 0.082901, Enc/Dis: 0.080521]
# 484 [D real: 0.474151, D fake: 0.532517], [Enc/Dec loss: 0.076789, Enc/Dis: 0.073956]
# 485 [D real: 0.479437, D fake: 0.506374], [Enc/Dec loss: 0.072856, Enc/Dis: 0.069692]
# 486 [D real: 0.477983, D fake: 0.494349], [Enc/Dec loss: 0.076403, Enc/Dis: 0.073370]
# 487 [D real: 0.492140, D fake: 0.494814], [Enc/Dec loss: 0.072101, Enc/Dis: 0.069437]
# 488 [D real: 0.488710, D fake: 0.492554], [Enc/Dec loss: 0.077790, Enc/Dis: 0.074724]
# 489 [D real: 0.491888, D fake: 0.490430], [Enc/Dec loss: 0.075641, Enc/Dis: 0.072472]
# 490 [D real: 0.491615, D fake: 0.491986], [Enc/Dec loss: 0.081106, Enc/Dis: 0.078595]
# 491 [D real: 0.391315, D fake: 0.465261], [Enc/Dec loss: 0.076574, Enc/Dis: 0.074179]
# 492 [D real: 0.479394, D fake: 0.494358], [Enc/Dec loss: 0.075637, Enc/Dis: 0.073266]
# 493 [D real: 0.475238, D fake: 0.496800], [Enc/Dec loss: 0.071989, Enc/Dis: 0.069538]
# 494 [D real: 0.473153, D fake: 0.478848], [Enc/Dec loss: 0.088221, Enc/Dis: 0.085638]
# 495 [D real: 0.474561, D fake: 0.488614], [Enc/Dec loss: 0.081369, Enc/Dis: 0.078742]
# 496 [D real: 0.466234, D fake: 0.475503], [Enc/Dec loss: 0.081419, Enc/Dis: 0.078611]
# 497 [D real: 0.462822, D fake: 0.476436], [Enc/Dec loss: 0.079806, Enc/Dis: 0.076783]
# 498 [D real: 0.474292, D fake: 0.480938], [Enc/Dec loss: 0.078209, Enc/Dis: 0.074807]
# 499 [D real: 0.471221, D fake: 0.491287], [Enc/Dec loss: 0.077164, Enc/Dis: 0.073722]
# 500 [D real: 0.469042, D fake: 0.484675], [Enc/Dec loss: 0.072756, Enc/Dis: 0.069457]
# INFO:tensorflow:Assets written to: ./AAE/Models/encoder_v2_500/assets
# INFO:tensorflow:Assets written to: ./AAE/Models/decoder_v2_500/assets
# INFO:tensorflow:Assets written to: ./AAE/Models/discriminator_v2_500/assets
# save model
# D_Loss:
# G_Loss:
# 501 [D real: 0.497417, D fake: 0.457207], [Enc/Dec loss: 0.072696, Enc/Dis: 0.068205]
# 502 [D real: 0.529305, D fake: 0.446108], [Enc/Dec loss: 0.077848, Enc/Dis: 0.073631]
# 503 [D real: 0.512297, D fake: 0.450308], [Enc/Dec loss: 0.084147, Enc/Dis: 0.079925]
# 504 [D real: 0.491071, D fake: 0.464285], [Enc/Dec loss: 0.098255, Enc/Dis: 0.074279]
# 505 [D real: 0.473272, D fake: 0.470494], [Enc/Dec loss: 0.074768, Enc/Dis: 0.074194]
# 506 [D real: 0.460198, D fake: 0.475982], [Enc/Dec loss: 0.081054, Enc/Dis: 0.078765]
# 507 [D real: 0.455026, D fake: 0.471044], [Enc/Dec loss: 0.074100, Enc/Dis: 0.070602]
# 508 [D real: 0.447889, D fake: 0.468907], [Enc/Dec loss: 0.081525, Enc/Dis: 0.076866]
# 509 [D real: 0.443653, D fake: 0.469281], [Enc/Dec loss: 0.076861, Enc/Dis: 0.071077]
# 510 [D real: 0.445317, D fake: 0.464483], [Enc/Dec loss: 0.081646, Enc/Dis: 0.075851]
# 511 [D real: 0.451970, D fake: 0.483749], [Enc/Dec loss: 0.080915, Enc/Dis: 0.075766]
# 512 [D real: 0.460401, D fake: 0.457039], [Enc/Dec loss: 0.080999, Enc/Dis: 0.076275]
# 513 [D real: 0.483064, D fake: 0.436149], [Enc/Dec loss: 0.082970, Enc/Dis: 0.078024]
# 514 [D real: 0.480414, D fake: 0.470097], [Enc/Dec loss: 0.071503, Enc/Dis: 0.067287]
# 515 [D real: 0.464315, D fake: 0.453229], [Enc/Dec loss: 0.080249, Enc/Dis: 0.076666]
# 516 [D real: 0.475926, D fake: 0.466201], [Enc/Dec loss: 0.082163, Enc/Dis: 0.078625]
# 517 [D real: 0.481109, D fake: 0.465253], [Enc/Dec loss: 0.079937, Enc/Dis: 0.076317]
# 518 [D real: 0.474386, D fake: 0.463065], [Enc/Dec loss: 0.074757, Enc/Dis: 0.071147]
# 519 [D real: 0.462919, D fake: 0.464355], [Enc/Dec loss: 0.081681, Enc/Dis: 0.077416]
# 520 [D real: 0.456653, D fake: 0.466671], [Enc/Dec loss: 0.076797, Enc/Dis: 0.072769]
# 521 [D real: 0.457408, D fake: 0.487917], [Enc/Dec loss: 0.074586, Enc/Dis: 0.070451]
# 522 [D real: 0.482384, D fake: 0.442568], [Enc/Dec loss: 0.079904, Enc/Dis: 0.075219]
# 523 [D real: 0.465937, D fake: 0.453053], [Enc/Dec loss: 0.078117, Enc/Dis: 0.073725]
# 524 [D real: 0.453121, D fake: 0.485785], [Enc/Dec loss: 0.077191, Enc/Dis: 0.072834]
# 525 [D real: 0.450937, D fake: 0.465270], [Enc/Dec loss: 0.080502, Enc/Dis: 0.075695]
# 526 [D real: 0.472175, D fake: 0.467442], [Enc/Dec loss: 0.076235, Enc/Dis: 0.071380]
# 527 [D real: 0.461708, D fake: 0.453236], [Enc/Dec loss: 0.076916, Enc/Dis: 0.072817]
# 528 [D real: 0.458648, D fake: 0.449158], [Enc/Dec loss: 0.079807, Enc/Dis: 0.076233]
# 529 [D real: 0.449080, D fake: 0.443650], [Enc/Dec loss: 0.077508, Enc/Dis: 0.073995]
# 530 [D real: 0.440514, D fake: 0.446304], [Enc/Dec loss: 0.079905, Enc/Dis: 0.075626]
# 531 [D real: 0.470381, D fake: 0.517308], [Enc/Dec loss: 0.075352, Enc/Dis: 0.071110]
# 532 [D real: 0.464575, D fake: 0.499754], [Enc/Dec loss: 0.081544, Enc/Dis: 0.077109]
# 533 [D real: 0.443493, D fake: 0.495710], [Enc/Dec loss: 0.079955, Enc/Dis: 0.075692]
# 534 [D real: 0.418601, D fake: 0.488814], [Enc/Dec loss: 0.081633, Enc/Dis: 0.077404]
# 535 [D real: 0.435402, D fake: 0.481933], [Enc/Dec loss: 0.078344, Enc/Dis: 0.074341]
# 536 [D real: 0.447911, D fake: 0.482705], [Enc/Dec loss: 0.076395, Enc/Dis: 0.072748]
# 537 [D real: 0.456518, D fake: 0.470166], [Enc/Dec loss: 0.077984, Enc/Dis: 0.074674]
# 538 [D real: 0.451592, D fake: 0.455794], [Enc/Dec loss: 0.087929, Enc/Dis: 0.084869]
# 539 [D real: 0.446667, D fake: 0.445939], [Enc/Dec loss: 0.082356, Enc/Dis: 0.078538]
# 540 [D real: 0.446582, D fake: 0.447019], [Enc/Dec loss: 0.077836, Enc/Dis: 0.074019]
# 541 [D real: 0.436025, D fake: 0.406049], [Enc/Dec loss: 0.081032, Enc/Dis: 0.079057]
# 542 [D real: 0.517270, D fake: 0.384262], [Enc/Dec loss: 0.095369, Enc/Dis: 0.079445]
# 543 [D real: 0.475245, D fake: 0.397771], [Enc/Dec loss: 0.079955, Enc/Dis: 0.070303]
# 544 [D real: 0.473057, D fake: 0.420099], [Enc/Dec loss: 0.082247, Enc/Dis: 0.074661]
# 545 [D real: 0.463450, D fake: 0.425436], [Enc/Dec loss: 0.086938, Enc/Dis: 0.078987]
# 546 [D real: 0.457982, D fake: 0.427411], [Enc/Dec loss: 0.074469, Enc/Dis: 0.070449]
# 547 [D real: 0.444679, D fake: 0.432072], [Enc/Dec loss: 0.075222, Enc/Dis: 0.073467]
# 548 [D real: 0.430914, D fake: 0.442102], [Enc/Dec loss: 0.075898, Enc/Dis: 0.074685]
# 549 [D real: 0.422020, D fake: 0.437293], [Enc/Dec loss: 0.075213, Enc/Dis: 0.073869]
# 550 [D real: 0.416960, D fake: 0.436390], [Enc/Dec loss: 0.072176, Enc/Dis: 0.070632]
# 551 [D real: 0.392527, D fake: 0.438777], [Enc/Dec loss: 0.072249, Enc/Dis: 0.070660]
# 552 [D real: 0.423644, D fake: 0.409048], [Enc/Dec loss: 0.082769, Enc/Dis: 0.080631]
# 553 [D real: 0.412704, D fake: 0.403539], [Enc/Dec loss: 0.076983, Enc/Dis: 0.073821]
# 554 [D real: 0.434252, D fake: 0.413198], [Enc/Dec loss: 0.083333, Enc/Dis: 0.080487]
# ...
# 1820 [D real: 0.012389, D fake: 0.012641], [Enc/Dec loss: 0.072667, Enc/Dis: 0.071643]
# 1821 [D real: 0.007228, D fake: 0.010236], [Enc/Dec loss: 0.073529, Enc/Dis: 0.072729]
# 1822 [D real: 0.005705, D fake: 0.010286], [Enc/Dec loss: 0.068766, Enc/Dis: 0.067845]
# 1823 [D real: 0.006521, D fake: 0.009648], [Enc/Dec loss: 0.069216, Enc/Dis: 0.068355]
# 1824 [D real: 0.016819, D fake: 0.008698], [Enc/Dec loss: 0.075238, Enc/Dis: 0.074364]
# 1825 [D real: 0.014043, D fake: 0.009413], [Enc/Dec loss: 0.072088, Enc/Dis: 0.071412]
# 1826 [D real: 0.012111, D fake: 0.010032], [Enc/Dec loss: 0.074740, Enc/Dis: 0.074138]
# 1827 [D real: 0.010863, D fake: 0.009762], [Enc/Dec loss: 0.078247, Enc/Dis: 0.077635]
# 1828 [D real: 0.010004, D fake: 0.015142], [Enc/Dec loss: 0.074163, Enc/Dis: 0.073483]
# 1829 [D real: 0.009317, D fake: 0.016587], [Enc/Dec loss: 0.076449, Enc/Dis: 0.075769]
# 1830 [D real: 0.008869, D fake: 0.015516], [Enc/Dec loss: 0.077803, Enc/Dis: 0.077098]
# 1831 [D real: 0.014700, D fake: 0.003820], [Enc/Dec loss: 0.070450, Enc/Dis: 0.069745]
# 1832 [D real: 0.008360, D fake: 0.010851], [Enc/Dec loss: 0.073731, Enc/Dis: 0.072916]
# 1833 [D real: 0.007688, D fake: 0.010602], [Enc/Dec loss: 0.076314, Enc/Dis: 0.075608]
# 1834 [D real: 0.008410, D fake: 0.012157], [Enc/Dec loss: 0.078668, Enc/Dis: 0.077993]
# 1835 [D real: 0.008214, D fake: 0.012186], [Enc/Dec loss: 0.071589, Enc/Dis: 0.070799]
# 1836 [D real: 0.008024, D fake: 0.013005], [Enc/Dec loss: 0.069018, Enc/Dis: 0.068310]
# 1837 [D real: 0.010247, D fake: 0.012926], [Enc/Dec loss: 0.071449, Enc/Dis: 0.070575]
# 1838 [D real: 0.009430, D fake: 0.011784], [Enc/Dec loss: 0.075526, Enc/Dis: 0.075017]
# 1839 [D real: 0.008905, D fake: 0.011200], [Enc/Dec loss: 0.070289, Enc/Dis: 0.069660]
# 1840 [D real: 0.008912, D fake: 0.010403], [Enc/Dec loss: 0.078940, Enc/Dis: 0.078409]
# 1841 [D real: 0.010664, D fake: 0.019616], [Enc/Dec loss: 0.074088, Enc/Dis: 0.073485]
# 1842 [D real: 0.006818, D fake: 0.011673], [Enc/Dec loss: 0.076936, Enc/Dis: 0.076290]
# 1843 [D real: 0.007201, D fake: 0.009802], [Enc/Dec loss: 0.071203, Enc/Dis: 0.070739]
# 1844 [D real: 0.006427, D fake: 0.012614], [Enc/Dec loss: 0.074449, Enc/Dis: 0.074062]
# 1845 [D real: 0.006716, D fake: 0.011568], [Enc/Dec loss: 0.072763, Enc/Dis: 0.072329]
# 1846 [D real: 0.006335, D fake: 0.010476], [Enc/Dec loss: 0.068960, Enc/Dis: 0.068651]
# 1847 [D real: 0.005889, D fake: 0.011395], [Enc/Dec loss: 0.071251, Enc/Dis: 0.070858]
# 1848 [D real: 0.006314, D fake: 0.010256], [Enc/Dec loss: 0.079215, Enc/Dis: 0.078828]
# 1849 [D real: 0.005884, D fake: 0.012233], [Enc/Dec loss: 0.069623, Enc/Dis: 0.069236]
# 1850 [D real: 0.006118, D fake: 0.011378], [Enc/Dec loss: 0.073122, Enc/Dis: 0.072668]
# 1851 [D real: 0.005796, D fake: 0.007225], [Enc/Dec loss: 0.073422, Enc/Dis: 0.072998]
# 1852 [D real: 0.004512, D fake: 0.005349], [Enc/Dec loss: 0.069697, Enc/Dis: 0.069219]
# 1853 [D real: 0.007229, D fake: 0.005510], [Enc/Dec loss: 0.071558, Enc/Dis: 0.071201]
# 1854 [D real: 0.007075, D fake: 0.006396], [Enc/Dec loss: 0.073486, Enc/Dis: 0.073114]
# 1855 [D real: 0.009025, D fake: 0.006107], [Enc/Dec loss: 0.081698, Enc/Dis: 0.081461]
# 1856 [D real: 0.011130, D fake: 0.006671], [Enc/Dec loss: 0.069143, Enc/Dis: 0.068979]
# 1857 [D real: 0.010700, D fake: 0.006103], [Enc/Dec loss: 0.070630, Enc/Dis: 0.070415]
# 1858 [D real: 0.010885, D fake: 0.006309], [Enc/Dec loss: 0.072838, Enc/Dis: 0.072567]
# 1859 [D real: 0.009909, D fake: 0.005953], [Enc/Dec loss: 0.076847, Enc/Dis: 0.076604]
# 1860 [D real: 0.013580, D fake: 0.008587], [Enc/Dec loss: 0.074561, Enc/Dis: 0.074565]
# 1861 [D real: 0.015089, D fake: 0.005609], [Enc/Dec loss: 0.084856, Enc/Dis: 0.084666]
# 1862 [D real: 0.195501, D fake: 0.007751], [Enc/Dec loss: 0.069112, Enc/Dis: 0.065883]
# 1863 [D real: 0.131304, D fake: 0.018866], [Enc/Dec loss: 0.075247, Enc/Dis: 0.070812]
# 1864 [D real: 0.099223, D fake: 0.024009], [Enc/Dec loss: 0.080290, Enc/Dis: 0.075474]
# 1865 [D real: 0.080500, D fake: 0.063187], [Enc/Dec loss: 0.079234, Enc/Dis: 0.074972]
# 1866 [D real: 0.067697, D fake: 0.058248], [Enc/Dec loss: 0.074158, Enc/Dis: 0.070864]
# 1867 [D real: 0.062505, D fake: 0.065347], [Enc/Dec loss: 0.081767, Enc/Dis: 0.078344]
# 1868 [D real: 0.055830, D fake: 0.080286], [Enc/Dec loss: 0.071458, Enc/Dis: 0.069005]
# 1869 [D real: 0.050093, D fake: 0.075765], [Enc/Dec loss: 0.075778, Enc/Dis: 0.075109]
# 1870 [D real: 0.045566, D fake: 0.071920], [Enc/Dec loss: 0.069039, Enc/Dis: 0.068653]
# 1871 [D real: 0.030058, D fake: 0.014352], [Enc/Dec loss: 0.071236, Enc/Dis: 0.070948]
# 1872 [D real: 0.033997, D fake: 0.009865], [Enc/Dec loss: 0.070949, Enc/Dis: 0.070741]
# 1873 [D real: 0.032936, D fake: 0.009732], [Enc/Dec loss: 0.072345, Enc/Dis: 0.072147]
# 1874 [D real: 0.027350, D fake: 0.007950], [Enc/Dec loss: 0.069738, Enc/Dis: 0.069550]
# 1875 [D real: 0.026338, D fake: 0.006999], [Enc/Dec loss: 0.071521, Enc/Dis: 0.071300]
# 1876 [D real: 0.025029, D fake: 0.006471], [Enc/Dec loss: 0.076614, Enc/Dis: 0.076375]
# 1877 [D real: 0.023114, D fake: 0.006047], [Enc/Dec loss: 0.070023, Enc/Dis: 0.069605]
# 1878 [D real: 0.023027, D fake: 0.006011], [Enc/Dec loss: 0.073749, Enc/Dis: 0.073276]
# 1879 [D real: 0.024245, D fake: 0.005703], [Enc/Dec loss: 0.076137, Enc/Dis: 0.075719]
# 1880 [D real: 0.023226, D fake: 0.005942], [Enc/Dec loss: 0.072917, Enc/Dis: 0.072531]
# 1881 [D real: 0.039349, D fake: 0.005524], [Enc/Dec loss: 0.072508, Enc/Dis: 0.072039]
# 1882 [D real: 0.027368, D fake: 0.007567], [Enc/Dec loss: 0.070840, Enc/Dis: 0.070332]
# 1883 [D real: 0.020008, D fake: 0.008856], [Enc/Dec loss: 0.072014, Enc/Dis: 0.071555]
# 1884 [D real: 0.018328, D fake: 0.007630], [Enc/Dec loss: 0.077335, Enc/Dis: 0.076943]
# 1885 [D real: 0.015438, D fake: 0.007036], [Enc/Dec loss: 0.068414, Enc/Dis: 0.068057]
# 1886 [D real: 0.016427, D fake: 0.007326], [Enc/Dec loss: 0.077533, Enc/Dis: 0.077138]
# 1887 [D real: 0.021261, D fake: 0.007749], [Enc/Dec loss: 0.075018, Enc/Dis: 0.074478]
# 1888 [D real: 0.018828, D fake: 0.007189], [Enc/Dec loss: 0.076579, Enc/Dis: 0.076093]
# 1889 [D real: 0.017070, D fake: 0.006796], [Enc/Dec loss: 0.073995, Enc/Dis: 0.073580]
# 1890 [D real: 0.016421, D fake: 0.006574], [Enc/Dec loss: 0.068210, Enc/Dis: 0.067796]
# 1891 [D real: 0.008234, D fake: 0.003763], [Enc/Dec loss: 0.078273, Enc/Dis: 0.077888]
# 1892 [D real: 0.013459, D fake: 0.003416], [Enc/Dec loss: 0.075555, Enc/Dis: 0.075197]
# 1893 [D real: 0.010354, D fake: 0.003726], [Enc/Dec loss: 0.075718, Enc/Dis: 0.075392]
# 1894 [D real: 0.008156, D fake: 0.005130], [Enc/Dec loss: 0.076016, Enc/Dis: 0.075722]
# 1895 [D real: 0.007559, D fake: 0.005227], [Enc/Dec loss: 0.069084, Enc/Dis: 0.068817]
# 1896 [D real: 0.024105, D fake: 0.006222], [Enc/Dec loss: 0.104724, Enc/Dis: 0.073375]
# 1897 [D real: 0.021388, D fake: 0.007431], [Enc/Dec loss: 0.088307, Enc/Dis: 0.070194]
# 1898 [D real: 0.018938, D fake: 0.008546], [Enc/Dec loss: 0.081954, Enc/Dis: 0.072090]
# 1899 [D real: 0.016967, D fake: 0.035689], [Enc/Dec loss: 0.104782, Enc/Dis: 0.072116]
# 1900 [D real: 0.015511, D fake: 0.032906], [Enc/Dec loss: 0.081009, Enc/Dis: 0.080291]
# 1901 [D real: 0.003866, D fake: 0.004466], [Enc/Dec loss: 0.074174, Enc/Dis: 0.073710]
# 1902 [D real: 0.009901, D fake: 0.006659], [Enc/Dec loss: 0.071842, Enc/Dis: 0.071449]
# 1903 [D real: 0.008656, D fake: 0.007246], [Enc/Dec loss: 0.072913, Enc/Dis: 0.072618]
# 1904 [D real: 0.007912, D fake: 0.007928], [Enc/Dec loss: 0.072734, Enc/Dis: 0.072440]
# 1905 [D real: 0.007265, D fake: 0.009530], [Enc/Dec loss: 0.072896, Enc/Dis: 0.072736]
# 1906 [D real: 0.009134, D fake: 0.008711], [Enc/Dec loss: 0.073344, Enc/Dis: 0.073271]
# 1907 [D real: 0.008425, D fake: 0.008192], [Enc/Dec loss: 0.066266, Enc/Dis: 0.066184]
# 1908 [D real: 0.053382, D fake: 0.010065], [Enc/Dec loss: 0.077348, Enc/Dis: 0.077254]
# 1909 [D real: 0.048544, D fake: 0.010289], [Enc/Dec loss: 0.074310, Enc/Dis: 0.074279]
# 1910 [D real: 0.044299, D fake: 0.011672], [Enc/Dec loss: 0.073150, Enc/Dis: 0.073092]
# 1911 [D real: 0.002680, D fake: 0.017559], [Enc/Dec loss: 0.073194, Enc/Dis: 0.073170]
# 1912 [D real: 0.003924, D fake: 0.016253], [Enc/Dec loss: 0.070290, Enc/Dis: 0.070258]
# 1913 [D real: 0.002875, D fake: 0.033612], [Enc/Dec loss: 0.082111, Enc/Dis: 0.082062]
# 1914 [D real: 0.003061, D fake: 0.069306], [Enc/Dec loss: 0.073042, Enc/Dis: 0.072931]
# 1915 [D real: 0.003154, D fake: 0.066948], [Enc/Dec loss: 0.069491, Enc/Dis: 0.069369]
# 1916 [D real: 0.003048, D fake: 0.056289], [Enc/Dec loss: 0.070519, Enc/Dis: 0.070448]
# 1917 [D real: 0.003043, D fake: 0.051188], [Enc/Dec loss: 0.066638, Enc/Dis: 0.066464]
# 1918 [D real: 0.011984, D fake: 0.049322], [Enc/Dec loss: 0.071130, Enc/Dis: 0.071005]
# 1919 [D real: 0.012571, D fake: 0.048453], [Enc/Dec loss: 0.074535, Enc/Dis: 0.074431]
# 1920 [D real: 0.011897, D fake: 0.045124], [Enc/Dec loss: 0.069077, Enc/Dis: 0.068973]
# 1921 [D real: 0.004791, D fake: 0.008521], [Enc/Dec loss: 0.069886, Enc/Dis: 0.069802]
# 1922 [D real: 0.016691, D fake: 0.012303], [Enc/Dec loss: 0.076903, Enc/Dis: 0.076838]
# 1923 [D real: 0.013519, D fake: 0.011695], [Enc/Dec loss: 0.070208, Enc/Dis: 0.070118]
# 1924 [D real: 0.015386, D fake: 0.010013], [Enc/Dec loss: 0.073222, Enc/Dis: 0.073112]
# 1925 [D real: 0.018293, D fake: 0.008553], [Enc/Dec loss: 0.071041, Enc/Dis: 0.070905]
# 1926 [D real: 0.016038, D fake: 0.007339], [Enc/Dec loss: 0.075504, Enc/Dis: 0.075401]
# 1927 [D real: 0.021442, D fake: 0.006563], [Enc/Dec loss: 0.075794, Enc/Dis: 0.075727]
# 1928 [D real: 0.020482, D fake: 0.006328], [Enc/Dec loss: 0.078205, Enc/Dis: 0.078143]
# 1929 [D real: 0.018813, D fake: 0.005943], [Enc/Dec loss: 0.079424, Enc/Dis: 0.079310]
# 1930 [D real: 0.017500, D fake: 0.005809], [Enc/Dec loss: 0.071312, Enc/Dis: 0.071271]
# 1931 [D real: 0.002037, D fake: 0.023808], [Enc/Dec loss: 0.073741, Enc/Dis: 0.073683]
# 1932 [D real: 0.003731, D fake: 0.014776], [Enc/Dec loss: 0.065019, Enc/Dis: 0.064970]
# 1933 [D real: 0.005648, D fake: 0.018849], [Enc/Dec loss: 0.071194, Enc/Dis: 0.071101]
# 1934 [D real: 0.008429, D fake: 0.015660], [Enc/Dec loss: 0.066575, Enc/Dis: 0.066489]
# 1935 [D real: 0.009389, D fake: 0.013552], [Enc/Dec loss: 0.071866, Enc/Dis: 0.071722]
# 1936 [D real: 0.010302, D fake: 0.011839], [Enc/Dec loss: 0.082237, Enc/Dis: 0.082118]
# 1937 [D real: 0.009897, D fake: 0.010605], [Enc/Dec loss: 0.084449, Enc/Dis: 0.084319]
# 1938 [D real: 0.009004, D fake: 0.011834], [Enc/Dec loss: 0.071224, Enc/Dis: 0.071143]
# 1939 [D real: 0.010656, D fake: 0.010920], [Enc/Dec loss: 0.072194, Enc/Dis: 0.072032]
# 1940 [D real: 0.009887, D fake: 0.010313], [Enc/Dec loss: 0.072282, Enc/Dis: 0.072111]
# 1941 [D real: 0.002914, D fake: 0.006365], [Enc/Dec loss: 0.076125, Enc/Dis: 0.075954]
# 1942 [D real: 0.004393, D fake: 0.006419], [Enc/Dec loss: 0.067292, Enc/Dis: 0.067148]
# 1943 [D real: 0.036523, D fake: 0.009155], [Enc/Dec loss: 0.067438, Enc/Dis: 0.067229]
# 1944 [D real: 0.027774, D fake: 0.027076], [Enc/Dec loss: 0.068880, Enc/Dis: 0.068722]
# 1945 [D real: 0.023455, D fake: 0.023166], [Enc/Dec loss: 0.086235, Enc/Dis: 0.086147]
# 1946 [D real: 0.020075, D fake: 0.023973], [Enc/Dec loss: 0.075094, Enc/Dis: 0.075043]
# 1947 [D real: 0.017396, D fake: 0.021306], [Enc/Dec loss: 0.070117, Enc/Dis: 0.069943]
# 1948 [D real: 0.015777, D fake: 0.020540], [Enc/Dec loss: 0.072294, Enc/Dis: 0.072176]
# 1949 [D real: 0.014237, D fake: 0.021401], [Enc/Dec loss: 0.072144, Enc/Dis: 0.072034]
# 1950 [D real: 0.012967, D fake: 0.019792], [Enc/Dec loss: 0.075258, Enc/Dis: 0.075140]
# 1951 [D real: 0.001764, D fake: 0.010505], [Enc/Dec loss: 0.071492, Enc/Dis: 0.071316]
# 1952 [D real: 0.002705, D fake: 0.010212], [Enc/Dec loss: 0.074124, Enc/Dis: 0.073996]
# 1953 [D real: 0.003264, D fake: 0.016925], [Enc/Dec loss: 0.074679, Enc/Dis: 0.074584]
# 1954 [D real: 0.003365, D fake: 0.014334], [Enc/Dec loss: 0.063485, Enc/Dis: 0.063383]
# 1955 [D real: 0.003187, D fake: 0.012519], [Enc/Dec loss: 0.075435, Enc/Dis: 0.075275]
# 1956 [D real: 0.003264, D fake: 0.010702], [Enc/Dec loss: 0.074689, Enc/Dis: 0.074541]
# 1957 [D real: 0.005572, D fake: 0.009798], [Enc/Dec loss: 0.076440, Enc/Dis: 0.076273]
# 1958 [D real: 0.006290, D fake: 0.009047], [Enc/Dec loss: 0.073065, Enc/Dis: 0.072963]
# 1959 [D real: 0.006002, D fake: 0.008649], [Enc/Dec loss: 0.071259, Enc/Dis: 0.071169]
# 1960 [D real: 0.008705, D fake: 0.008073], [Enc/Dec loss: 0.075171, Enc/Dis: 0.075036]
# 1961 [D real: 0.013424, D fake: 0.002721], [Enc/Dec loss: 0.073109, Enc/Dis: 0.072946]
# 1962 [D real: 0.008601, D fake: 0.006169], [Enc/Dec loss: 0.071309, Enc/Dis: 0.071222]
# 1963 [D real: 0.006436, D fake: 0.005663], [Enc/Dec loss: 0.074344, Enc/Dis: 0.074221]
# 1964 [D real: 0.015766, D fake: 0.004923], [Enc/Dec loss: 0.081298, Enc/Dis: 0.081228]
# 1965 [D real: 0.048704, D fake: 0.004545], [Enc/Dec loss: 0.077640, Enc/Dis: 0.077550]
# 1966 [D real: 0.040813, D fake: 0.004333], [Enc/Dec loss: 0.072463, Enc/Dis: 0.072309]
# 1967 [D real: 0.035232, D fake: 0.016111], [Enc/Dec loss: 0.077765, Enc/Dis: 0.077531]
# 1968 [D real: 0.031092, D fake: 0.015258], [Enc/Dec loss: 0.078372, Enc/Dis: 0.078173]
# 1969 [D real: 0.027893, D fake: 0.015587], [Enc/Dec loss: 0.071455, Enc/Dis: 0.071279]
# 1970 [D real: 0.025240, D fake: 0.016829], [Enc/Dec loss: 0.076927, Enc/Dis: 0.076616]
# 1971 [D real: 0.001993, D fake: 0.312465], [Enc/Dec loss: 0.070496, Enc/Dis: 0.070261]
# 1972 [D real: 0.002584, D fake: 0.165744], [Enc/Dec loss: 0.080518, Enc/Dis: 0.080286]
# 1973 [D real: 0.002697, D fake: 0.112375], [Enc/Dec loss: 0.068758, Enc/Dis: 0.068527]
# 1974 [D real: 0.010323, D fake: 0.085740], [Enc/Dec loss: 0.072928, Enc/Dis: 0.072498]
# 1975 [D real: 0.021194, D fake: 0.069075], [Enc/Dec loss: 0.076832, Enc/Dis: 0.076552]
# 1976 [D real: 0.019082, D fake: 0.058744], [Enc/Dec loss: 0.071851, Enc/Dis: 0.071585]
# 1977 [D real: 0.164343, D fake: 0.051454], [Enc/Dec loss: 0.077053, Enc/Dis: 0.076822]
# 1978 [D real: 0.146557, D fake: 0.049850], [Enc/Dec loss: 0.074767, Enc/Dis: 0.074481]
# 1979 [D real: 0.130650, D fake: 0.051296], [Enc/Dec loss: 0.070526, Enc/Dis: 0.070235]
# 1980 [D real: 0.117781, D fake: 0.070377], [Enc/Dec loss: 0.068953, Enc/Dis: 0.068724]
# 1981 [D real: 0.003518, D fake: 0.046479], [Enc/Dec loss: 0.074013, Enc/Dis: 0.073800]
# 1982 [D real: 0.005951, D fake: 0.052234], [Enc/Dec loss: 0.071018, Enc/Dis: 0.070788]
# 1983 [D real: 0.006032, D fake: 0.069899], [Enc/Dec loss: 0.077877, Enc/Dis: 0.077678]
# 1984 [D real: 0.005059, D fake: 0.054917], [Enc/Dec loss: 0.069371, Enc/Dis: 0.069023]
# 1985 [D real: 0.006264, D fake: 0.046956], [Enc/Dec loss: 0.075050, Enc/Dis: 0.074866]
# 1986 [D real: 0.005554, D fake: 0.041165], [Enc/Dec loss: 0.073723, Enc/Dis: 0.073493]
# 1987 [D real: 0.007819, D fake: 0.038611], [Enc/Dec loss: 0.073587, Enc/Dis: 0.073283]
# 1988 [D real: 0.009851, D fake: 0.035803], [Enc/Dec loss: 0.071999, Enc/Dis: 0.071871]
# 1989 [D real: 0.016645, D fake: 0.034100], [Enc/Dec loss: 0.077878, Enc/Dis: 0.077782]
# 1990 [D real: 0.015610, D fake: 0.031877], [Enc/Dec loss: 0.068955, Enc/Dis: 0.068845]
# 1991 [D real: 0.003327, D fake: 0.007048], [Enc/Dec loss: 0.071771, Enc/Dis: 0.071707]
# 1992 [D real: 0.036304, D fake: 0.004906], [Enc/Dec loss: 0.077854, Enc/Dis: 0.077775]
# 1993 [D real: 0.029380, D fake: 0.003790], [Enc/Dec loss: 0.076831, Enc/Dis: 0.076774]
# 1994 [D real: 0.022901, D fake: 0.008629], [Enc/Dec loss: 0.067283, Enc/Dis: 0.067175]
# 1995 [D real: 0.019515, D fake: 0.007831], [Enc/Dec loss: 0.069797, Enc/Dis: 0.069711]
# 1996 [D real: 0.017084, D fake: 0.007562], [Enc/Dec loss: 0.073159, Enc/Dis: 0.073025]
# 1997 [D real: 0.015132, D fake: 0.007708], [Enc/Dec loss: 0.067527, Enc/Dis: 0.067408]
# 1998 [D real: 0.013499, D fake: 0.050814], [Enc/Dec loss: 0.071706, Enc/Dis: 0.071632]
# 1999 [D real: 0.013284, D fake: 0.045577], [Enc/Dec loss: 0.079361, Enc/Dis: 0.079252]
# 2000 [D real: 0.018777, D fake: 0.041146], [Enc/Dec loss: 0.080167, Enc/Dis: 0.080102]
# INFO:tensorflow:Assets written to: ./AAE/Models/encoder_v2_2000/assets
# INFO:tensorflow:Assets written to: ./AAE/Models/decoder_v2_2000/assets
# INFO:tensorflow:Assets written to: ./AAE/Models/discriminator_v2_2000/assets
# save model
# D_Loss:
# G_Loss:

# %% [markdown]
# ### Plot Loss

# %%
from PIL import Image

#Discriminator Loss
Dloss = Image.open('AAE/Losses/D_loss_v'+str(i)+'_epochs'+str(epochs)+'.png')
plt.figure("D_loss",figsize=[15,10])
plt.imshow(Dloss)
#Encoder Loss
Gloss = Image.open('AAE/Losses/G_loss_v'+str(i)+'_epochs'+str(epochs)+'.png')
plt.figure("G_loss",figsize=[15,10])
plt.imshow(Gloss)

# %%
latent_values = tf.random.normal([1000, Z])
predicted_values = decoder(latent_values)

predicted_values2 = decoder(self.encoder(X_train_scaled))
predicted_values3 = encoder(X_train_scaled)
        
if scaled == '-1-1':
    predicted_values = scaler.inverse_transform(predicted_values)
    predicted_values2 = scaler.inverse_transform(predicted_values2)
    predicted_values4 = scaler.inverse_transform(X_train_scaled)

            
    fig, axes = plt.subplots(figsize=(15,10))
    plt.scatter(predicted_values[:,0],predicted_values[:,1],c='green') #decoder(latent space)
    plt.scatter(X_train, y_train,c='r')#X_trained_scaled
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.title('Decoder (latent space)')
    
    plt.tight_layout()
    plt.savefig('AAE/Result/cooooool_v_'+str(i)+'_epochs_'+str(epoch+1)+'.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f8673be77505> in <module>
#       2 predicted_values = decoder(latent_values)
#       3
# ----> 4 predicted_values2 = decoder(self.encoder(X_train_scaled))
#       5 predicted_values3 = encoder(X_train_scaled)
#       6
#
# NameError: name 'self' is not defined

# %% [markdown]
# ## predict from the decoder

# %%
epochs = epochs

# %% [raw]
# img = Image.open('AAE/Result/v'+str(i)+'_latent_space 3D_'+str(epochs)+'.png')
# plt.figure("3D",figsize=[15,10])
# plt.imshow(img)
#
# img2 = Image.open('AAE/Result/v'+str(i)+'_Latent_Space 2D_'+str(epochs)+'.png')
# plt.figure("2D",figsize=[15,10])
# plt.imshow(img2)
#
# img3 = Image.open('AAE/Result/v_'+str(i)+'_epochs_'+str(epochs)+'.png')
# plt.figure("Autoencoder",figsize=[15,10])
# plt.imshow(img3)
#
# img4 = Image.open('AAE/Result/'+'countour_line_v'+str(i)+'_epochs'+str(epochs)+'.png')
# plt.figure("countour_line",figsize=[15,10])
# plt.imshow(img4)

# %% [raw]
# latent_values = tf.random.normal([10000, Z])
# predicted_values = aae.decoder(latent_values)
#
# predicted_values2 = aae.decoder(aae.encoder(X_train_scaled))
# predicted_values3 = aae.encoder(X_train_scaled)
# #predicted_values4 = scaler.inverse_transform(X_train_scaled)
#
# if scaled == '-1-1':
#     predicted_values = scaler.inverse_transform(predicted_values)
#     predicted_values2 = scaler.inverse_transform(predicted_values2)
#
#
# elif scaled =='0-1':
#     predicted_values = scaler.inverse_transform(predicted_values)
#     predicted_values2 = scaler.inverse_transform(predicted_values2)
#
#
#
#
# if n_features==3:
#
#     ab = plt.subplot(projection='3d')
#     ab.scatter(predicted_values5[:,0],predicted_values5[:,1],predicted_values5[:,2])
#     ab.set_ylabel('Y')
#     ab.set_zlabel('Z')
#     ab.set_xlabel('X')
#
#
#     print("X-Y 2D slices:")
#     fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
#     plt.ylim(-1.5,1.5)
#     plt.xlim(-1.5,1.5)
#     axes[0].scatter(X_train[:,0],X_train[:,1])
#     axes[0].scatter(predicted_values[:,0],predicted_values[:,1])
#     axes[0].set_xlabel("X")
#     axes[0].set_ylabel("Y")
#
#     plt.ylim(-1.5,1.5)
#     plt.xlim(-2,22)
#     axes[1].scatter(X_train[:,1],y_train)
#     axes[1].scatter(predicted_values[:,1],predicted_values[:,2])
#     axes[1].set_xlabel("Y")
#     axes[1].set_ylabel("Z")
#
#     plt.xlim(-1.5,1.5)
#     plt.ylim(-2,22)
#     axes[2].scatter(X_train[:,0],y_train)
#     axes[2].scatter(predicted_values[:,0],predicted_values[:,2])
#     axes[2].set_xlabel("X")
#     axes[2].set_ylabel("Z")
#
#     plt.tight_layout()
#
#
#     fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
#
#     ac=np.where(np.logical_and(X_train[:,0]>=-0.8-0.05,X_train[:,0]<=-0.8+0.05),X_train[:,1],None)
#     ad=np.where(np.logical_and(predicted_values[:,0]>=-0.8-0.05,predicted_values[:,0]<=-0.8+0.05),predicted_values[:,1],None)
#     axes[0].scatter(ac,y_train)
#     axes[0].scatter(ad,predicted_values[:,2])
#     axes[0].set_xlabel("Y(X=-0.8)")
#     axes[0].set_ylabel("Y")
#
#     ae=np.where(np.logical_and(X_train[:,0]>=0.0-0.05,X_train[:,0]<=0.0+0.05),X_train[:,1],None)
#     af=np.where(np.logical_and(predicted_values[:,0]>=0.0-0.05,predicted_values[:,0]<=0.0+0.05),predicted_values[:,1],None)
#     axes[1].scatter(ae,y_train)
#     axes[1].scatter(af,predicted_values[:,2])
#     axes[1].set_xlabel("Y(X=0.0)")
#     axes[1].set_ylabel("Z")
#
#     ag=np.where(np.logical_and(X_train[:,0]>=0.8-0.05,X_train[:,0]<=0.8+0.05),X_train[:,1],None)
#     ah=np.where(np.logical_and(predicted_values[:,0]>=0.8-0.05,predicted_values[:,0]<=0.8+0.05),predicted_values[:,1],None)
#     axes[2].scatter(ag,y_train)
#     axes[2].scatter(ah,predicted_values[:,2])
#     axes[2].set_xlabel("Y(X=0.8)")
#     axes[2].set_ylabel("Z")
#
#     plt.tight_layout()
#
#
#
#     fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
#     ac=np.where(np.logical_and(X_train[:,1]>=0.2-0.05,X_train[:,1]<=0.2+0.05),X_train[:,0],None)
#     ad=np.where(np.logical_and(predicted_values[:,1]>=0.2-0.05,predicted_values[:,1]<=0.2+0.05),predicted_values[:,0],None)
#     axes[0].scatter(ac,y_train)
#     axes[0].scatter(ad,predicted_values[:,2])
#     axes[0].set_xlabel("X(Y=0.2)")
#     axes[0].set_ylabel("Z")
#
#     ae=np.where(np.logical_and(X_train[:,1]>=0.5-0.05,X_train[:,1]<=0.5+0.05),X_train[:,0],None)
#     af=np.where(np.logical_and(predicted_values[:,1]>=0.5-0.05,predicted_values[:,1]<=0.5+0.05),predicted_values[:,0],None)
#     axes[1].scatter(ae,y_train)
#     axes[1].scatter(af,predicted_values[:,2])
#     axes[1].set_xlabel("X(Y=0.5)")
#     axes[1].set_ylabel("Z")
#
#     ag=np.where(np.logical_and(X_train[:,1]>=0.8-0.05,X_train[:,1]<=0.8+0.05),X_train[:,0],None)
#     ah=np.where(np.logical_and(predicted_values[:,1]>=0.8-0.05,predicted_values[:,1]<=0.8+0.05),predicted_values[:,0],None)
#     axes[2].scatter(ag,y_train)
#     axes[2].scatter(ah,predicted_values[:,2])
#     axes[2].set_xlabel("X(Y=0.8)")
#     axes[2].set_ylabel("Z")
#
#
#     plt.tight_layout()
#
#
# else:
#
#     if Z>=6:
#         # set up a figure twice as wide as it is tall
#         fig = plt.figure(figsize=plt.figaspect(0.5))
#         aa = fig.add_subplot(1, 2, 1, projection='3d')
#         aa.scatter(predicted_values3[:,0],predicted_values3[:,1],predicted_values3[:,2],c='pink')
#         aa.scatter(latent_values[:,0],latent_values[:,1],latent_values[:,2],c='grey')
#         aa.set_ylabel('Y')
#         aa.set_zlabel('Z')
#         aa.set_xlabel('X')
#         aa.set_title('Latent Space 3D - 0,1,2')
#
#         ax = fig.add_subplot(1, 2, 2, projection='3d')
#         ax.scatter(predicted_values3[:,3],predicted_values3[:,4],predicted_values3[:,5],c='pink')
#         ax.scatter(latent_values[:,3],latent_values[:,4],latent_values[:,5],c='grey')
#         ax.set_ylabel('Y')
#         ax.set_zlabel('Z')
#         ax.set_xlabel('X')
#         ax.set_title('Latent Space 3D - 3,4,5')
#
#         plt.savefig('AAE/Result/v'+str(i)+'_latent_space 3D_'+str(epochs)+'.png')
#
#
#         fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10), sharey=False, sharex=False)
#         axes[0][0].scatter(predicted_values3[:,0],predicted_values3[:,1],c='pink')
#         axes[0][0].scatter(latent_values[:,0],latent_values[:,1],c='grey')
#         axes[0][0].set_xlabel("X")
#         axes[0][0].set_ylabel("Y")
#         axes[0][0].set_title("Latent Space 2D- XY")
#
#
#
#         axes[0][1].scatter(predicted_values3[:,1],predicted_values3[:,2],c='pink')
#         axes[0][1].scatter(latent_values[:,1],latent_values[:,2],c='grey')
#         axes[0][1].set_xlabel("Y")
#         axes[0][1].set_ylabel("Z")
#         axes[0][1].set_title("Latent Space 2D- YZ")
#
#
#
#         axes[0][2].scatter(predicted_values3[:,0],predicted_values3[:,2],c='pink')
#         axes[0][2].scatter(latent_values[:,0],latent_values[:,2],c='grey')
#         axes[0][2].set_xlabel("X")
#         axes[0][2].set_ylabel("Z")
#         axes[0][2].set_title("Latent Space 2D- XZ")
#
#
#         axes[1][0].scatter(predicted_values3[:,3],predicted_values3[:,4],c='pink')
#         axes[1][0].scatter(latent_values[:,3],latent_values[:,4],c='grey')
#         axes[1][0].set_xlabel("X")
#         axes[1][0].set_ylabel("Y")
#         axes[1][0].set_title("Latent Space 2D- 3,4")
#
#         axes[1][1].scatter(predicted_values3[:,4],predicted_values3[:,5],c='pink')
#         axes[1][1].scatter(latent_values[:,4],latent_values[:,5],c='grey')
#         axes[1][1].set_xlabel("Y")
#         axes[1][1].set_ylabel("Z")
#         axes[1][1].set_title("Latent Space 2D- 4,5")
#
#         axes[1][2].scatter(predicted_values3[:,3],predicted_values3[:,5],c='pink')
#         axes[1][2].scatter(latent_values[:,3],latent_values[:,5],c='grey')
#         axes[1][2].set_xlabel("X")
#         axes[1][2].set_ylabel("Z")
#         axes[1][2].set_title("Latent Space 2D- 3,5")
#
#         plt.tight_layout()
#         plt.savefig('AAE/Result/v'+str(i)+'_Latent_Space 2D_'+str(epochs)+'.png')
#
#     ############################################
#     ###############Latent Space#################
#     ############################################
#
#
#     fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5), sharey=False, sharex=False)
#     axes[0].scatter(predicted_values2[:,0],predicted_values2[:,1],)#encoder/decoder
#     #axes[0].scatter(predicted_values4[:,0],predicted_values4[:,1],c='grey')#X_trained_scaled
#     axes[0].set_ylabel('Y')
#     axes[0].set_xlabel('X')
#     axes[0].set_title('Autoencoder (X_trained_scaled)')
#
#     axes[1].scatter(predicted_values[:,0],predicted_values[:,1],c='red') #decoder(latent space)
#     #axes[1].scatter(predicted_values4[:,0],predicted_values4[:,1],c='grey')#X_trained_scaled
#     axes[1].set_ylabel('Y')
#     axes[1].set_xlabel('X')
#     axes[1].set_title('Decoder (latent space)')
#
#     plt.tight_layout()
#     plt.savefig('AAE/Result/v_'+str(i)+'_epochs_'+str(epochs)+'.png')
#
#     ############################################
#     ###############Discriminator################
#     ############################################
#
#
# print('encoder output shape',predicted_values3.shape)
# encoder_output = predicted_values3
#
# dis_predicted_values = aae.discriminator(encoder_output)
# #dis_predicted_values = scaler.inverse_transform(dis_predicted_values)
# print('discriminator shape',dis_predicted_values.shape)
#
#
#
# #import seed ()
# x = np.ndarray.tolist(predicted_values2[:, 0])
# y = np.ndarray.tolist(predicted_values2[:, 1])
# #z = np.ndarray.tolist(dis_predicted_values)
# #x = np.random.choice(x)
# #y = np.random.choice(y)
# #z = np.random.choice(z)
#
# resolution_x = 100
# resolution_y = 100
# x = np.linspace(np.min(predicted_values2[:, 0]), np.max(predicted_values2[:, 0]), resolution_x)
# #x = predicted_values2[:, 0]
# y = np.linspace(np.min(predicted_values2[:, 1]), np.max(predicted_values2[:, 1]), resolution_y)
# #y = predicted_values2[:, 1]
# x, y = np.meshgrid(x, y)
#
# z = dis_predicted_values
# z = np.array(z)
# z = z.reshape((len(x), len(y)))
#
# fig = plt.figure()
# plt.contourf(x, y, z)
# plt.colorbar()
#
# #fig, ax = plt.subplots(1,1, figsize=[10,5])
# #ax.plot(dis_predicted_values)
#
# #plt.tight_layout()
# #plt.xlabel('X')
# #plt.ylabel('Y')
# #plt.title("AAE Discriminator")
# plt.savefig('AAE/Result/'+'countour_line_v'+str(i)+'_epochs'+str(epochs)+'.png')

# %% [markdown]
# ### Applying the prediction function

# %%
i = i

# %%
# Common imports
import numpy as np
import os
from backend import import_excel, export_excel

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import tensorflow as tf
from keras import Input, Model
from keras.models import Sequential, Model, load_model


import random

import sys
sys.path.append("..")

import dataset, network

# %%
epochs = epochs

# %%
encoder = keras.models.load_model('./AAE/Models/encoder_v'+str(i)+'_'+str(epochs))
decoder = keras.models.load_model('./AAE/Models/decoder_v'+str(i)+'_'+str(epochs))
discriminator = keras.models.load_model('./AAE/Models/discriminator_v'+str(i)+'_'+str(epochs))

# %%
# define these for desired prediction
x_input = [-1.0,-0.5,0,0.5,1.0,1.5,2.0]
n_points = 700
y_min = -1
y_max = 1

# produces an input of fixed x coordinates with random y values
predict1 = np.full((n_points//7, n_features), x_input[0])
predict2 = np.full((n_points//7, n_features), x_input[1])
predict3 = np.full((n_points//7, n_features), x_input[2])
predict4 = np.full((n_points//7, n_features), x_input[3])
predict5 = np.full((n_points//7, n_features), x_input[4])
predict6 = np.full((n_points//7, n_features), x_input[5])
predict7 = np.full((n_points//7, n_features), x_input[6])

predictthis = np.concatenate((predict1, predict2, predict3, predict4, predict5, predict6, predict7))
predictthis = scaler.transform(predictthis)
input_test = predictthis.reshape(n_points, n_features).astype('float32')


print("input_test :",input_test.shape)
plt.scatter(input_test[:,0],input_test[:,1] ,c='grey')
plt.ylabel('Y')
plt.xlabel('X')
plt.tight_layout()
# Out:
# input_test : (700, 2)

# %%
X_generated = aae.predict(input_test, scaler)
print("X_generated :",X_generated.shape)
# Out:
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)
# input: (700, 2)

# %%
if scenario in ("3d", "helix"):
    
    ax = plt.subplot(projection='3d')
    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], label='Generated Data')


    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()
    
    print("X-Y 2D slices:")
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    plt.ylim(-1.5,1.5)
    plt.xlim(-1.5,1.5)
    axes[0].scatter(X_train[:,0],X_train[:,1])
    axes[0].scatter(X_generated[:,0],X_generated[:,1])
    axes[0].set_xlabel("X")
    axes[0].set_ylabel("Y")
    
    plt.ylim(-1.5,1.5)
    plt.xlim(-2,22)
    axes[1].scatter(X_train[:,1],y_train)
    axes[1].scatter(X_generated[:,1],X_generated[:,2])
    axes[1].set_xlabel("Y")
    axes[1].set_ylabel("Z")
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-2,22)
    axes[2].scatter(X_train[:,0],y_train)
    axes[2].scatter(X_generated[:,0],X_generated[:,2])
    axes[2].set_xlabel("X")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    
    ac=np.where(np.logical_and(X_train[:,0]>=-0.8-0.05,X_train[:,0]<=-0.8+0.05),X_train[:,1],None)
    ad=np.where(np.logical_and(X_generated[:,0]>=-0.8-0.05,X_generated[:,0]<=-0.8+0.05),X_generated[:,1],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("Y(X=-0.8)")
    axes[0].set_ylabel("Y")
    
    ae=np.where(np.logical_and(X_train[:,0]>=0.0-0.05,X_train[:,0]<=0.0+0.05),X_train[:,1],None)
    af=np.where(np.logical_and(X_generated[:,0]>=0.0-0.05,X_generated[:,0]<=0.0+0.05),X_generated[:,1],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("Y(X=0.0)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,0]>=0.8-0.05,X_train[:,0]<=0.8+0.05),X_train[:,1],None)
    ah=np.where(np.logical_and(X_generated[:,0]>=0.8-0.05,X_generated[:,0]<=0.8+0.05),X_generated[:,1],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("Y(X=0.8)")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    
    
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    ac=np.where(np.logical_and(X_train[:,1]>=0.2-0.05,X_train[:,1]<=0.2+0.05),X_train[:,0],None)
    ad=np.where(np.logical_and(X_generated[:,1]>=0.2-0.05,X_generated[:,1]<=0.2+0.05),X_generated[:,0],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("X(Y=0.2)")
    axes[0].set_ylabel("Z")
    
    ae=np.where(np.logical_and(X_train[:,1]>=0.5-0.05,X_train[:,1]<=0.5+0.05),X_train[:,0],None)
    af=np.where(np.logical_and(X_generated[:,1]>=0.5-0.05,X_generated[:,1]<=0.5+0.05),X_generated[:,0],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("X(Y=0.5)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,1]>=0.8-0.05,X_train[:,1]<=0.8+0.05),X_train[:,0],None)
    ah=np.where(np.logical_and(X_generated[:,1]>=0.8-0.05,X_generated[:,1]<=0.8+0.05),X_generated[:,0],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("X(Y=0.8)")
    axes[2].set_ylabel("Z")
    
    
    plt.tight_layout()
    
    
else:
    print("Generated Data:",X_generated.shape)
    plt.scatter(X_train, y_train) 
    plt.scatter(X_generated[:,0],X_generated[:,1])
    #plt.scatter(predicted_values4[:,0],predicted_values4[:,1],c='grey')#X_trained_scaled
    #plt.scatter(predicted_values2[:,0],predicted_values2[:,1])
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
    plt.savefig('AAE/Prediction/moons'+str(epochs)+'.png')
