# %%
k = 8031

# %%
# Common imports
import numpy as np
import os
from backend import import_excel, export_excel

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# style.use('bmh')
from mpl_toolkits.mplot3d import Axes3D
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import seaborn as sns

import tensorflow as tf
import keras
import random

import sys
sys.path.append("..")
from sklearn.preprocessing import *
from sklearn.preprocessing import MinMaxScaler
import dataset, network_2D, WGAN_Model_2D

# %% [markdown]
# # Load data

# %%
# Preprocessing
vars = np.zeros((6,864))
j = 0
for i in range(6):
    for i2 in range(4):
        for i3 in range(3):
            for i4 in range(2):
                for i5 in range(3):
                    for i6 in range(2):
                        vars[0,j]=i+2
                        vars[1,j]=i2
                        vars[2,j]=i3
                        vars[3,j]=i4
                        vars[4,j]=i5
                        vars[5,j]=i6
                        j = j +1
j=0
print(vars[:,j])

scenario= "moons" #sinus, helix
n_instance = 1000
n_features = 2
n_var =int(vars[0,j])
latent_space =100 #12
batchs = [10,100,1000]
BATCH_SIZE = 100 #100, 32
scales = ['-1-1','0-1']
scaled = '-1-1'
epochs = 8000 #4000
bias = [True,False]
use_bias = False
# Out:
# [2. 0. 0. 0. 0. 0.]

# %%
if scenario in ("3d", "helix"):
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    print("X_train= x,y",X_train.shape)
    print("y_train= z",y_train.shape)

    ax = plt.subplot(projection='3d')
    plt.xlim([-1.5,1.5])
    plt.ylim([-1.5,1.5])
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c='orange')
    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')
    plt.tight_layout()

    
else:
    X_train, y_train, X_test, y_test, X_valid, y_valid = dataset.get_dataset(n_instance, scenario)
    plt.scatter(X_train,y_train, c='orange', label='Sample Data')
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()

# %%
os.system('mkdir Dataset')
os.system('mkdir GANS')
os.system('mkdir GANS/Models')
os.system('mkdir GANS/Losses')
os.system('mkdir GANS/Random_test')
export_excel(X_train, 'Dataset/X_train')
export_excel(y_train, 'Dataset/y_train')

# print(X_train.shape,y_train.shape)
X_train = import_excel('Dataset/X_train')
y_train = import_excel('Dataset/y_train')

print('made dataset')
# Out:
# made dataset

# %% [markdown]
# # WGAN

# %% [markdown]
# ### Architecture

# %%
generator=network_2D.build_generator(latent_space, n_var, n_features,use_bias)
generator.summary()

discriminator=network_2D.build_critic(n_var, use_bias, n_features)
discriminator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                180
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30)                120
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                310
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10)                40
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 10)                40
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 20
# =================================================================
# Total params: 820
# Trainable params: 720
# Non-trainable params: 100
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 20)                40
# _________________________________________________________________
# re_lu (ReLU)                 (None, 20)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 60)                1260
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 60)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                1220
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 20)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 20)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 2,541
# Trainable params: 2,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
wgan = WGAN_Model_2D.WGAN(k, n_features,latent_space,BATCH_SIZE,n_var,use_bias)
wgan.wgan.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_2 (Sequential)    (None, 2)                 820
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 1)                 2541
# =================================================================
# Total params: 3,361
# Trainable params: 3,261
# Non-trainable params: 100
# _________________________________________________________________

# %% [markdown]
# ### Preprocessing

# %%
train_dataset, scaler, X_train_scaled = wgan.preproc(X_train, y_train, scaled)

print("X_train",X_train.shape)
print("y_train",y_train.shape)
print("X_train_scaled",X_train_scaled.shape)
# Out:
# data shape_1 (100, 2)
# data shape_2 (100, 2)
# data shape_3 (100, 2)
# data shape_4 (100, 2)
# data shape_5 (100, 2)
# data shape_6 (100, 2)
# data shape_7 (100, 2)
# data shape_8 (100, 2)
# data shape_9 (100, 2)
# data shape_10 (100, 2)
# Cycles:  10
# X_train (1000, 1)
# y_train (1000, 1)
# X_train_scaled (1000, 2)

# %%
for data in train_dataset:
    print('train_dataset',data.shape)
# Out:
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)
# train_dataset (100, 2)

# %% [markdown]
# ## Training

# %%
hist = wgan.train(train_dataset, epochs, scaler, scaled, X_train, y_train)
# Out:
# Epoch 1/8000
# critic: 0.425717 - generator: -0.019065 - 14s
# Epoch 2/8000
# critic: 0.030764 - generator: -0.007035 - 1s
# Epoch 3/8000
# critic: 0.039952 - generator: 0.002369 - 1s
# Epoch 4/8000
# critic: 0.029673 - generator: 0.008540 - 1s
# Epoch 5/8000
# critic: 0.024203 - generator: 0.010267 - 1s
# Epoch 6/8000
# critic: 0.013861 - generator: 0.009788 - 1s
# Epoch 7/8000
# critic: 0.011358 - generator: 0.011666 - 1s
# Epoch 8/8000
# critic: 0.005479 - generator: 0.009964 - 1s
# Epoch 9/8000
# critic: 0.005117 - generator: 0.009338 - 1s
# Epoch 10/8000
# critic: 0.012479 - generator: 0.007206 - 1s
# Epoch 11/8000
# critic: 0.013926 - generator: 0.005220 - 1s
# Epoch 12/8000
# critic: 0.001947 - generator: -0.001104 - 1s
# Epoch 13/8000
# critic: 0.013428 - generator: -0.012539 - 1s
# Epoch 14/8000
# critic: 0.009467 - generator: -0.018621 - 1s
# Epoch 15/8000
# critic: 0.004027 - generator: -0.020133 - 1s
# Epoch 16/8000
# critic: 0.004146 - generator: -0.025639 - 1s
# Epoch 17/8000
# critic: -0.000468 - generator: -0.029700 - 1s
# Epoch 18/8000
# critic: 0.005412 - generator: -0.031754 - 1s
# Epoch 19/8000
# critic: 0.003121 - generator: -0.030567 - 1s
# Epoch 20/8000
# critic: 0.002533 - generator: -0.031196 - 1s
# Epoch 21/8000
# critic: 0.009511 - generator: -0.030212 - 1s
# Epoch 22/8000
# critic: 0.001127 - generator: -0.029584 - 1s
# Epoch 23/8000
# critic: 0.011898 - generator: -0.028929 - 1s
# Epoch 24/8000
# critic: 0.005610 - generator: -0.025988 - 1s
# Epoch 25/8000
# critic: 0.010692 - generator: -0.022152 - 1s
# Epoch 26/8000
# critic: 0.007310 - generator: -0.018281 - 1s
# Epoch 27/8000
# critic: 0.013955 - generator: -0.011790 - 1s
# Epoch 28/8000
# critic: 0.004080 - generator: -0.007465 - 1s
# Epoch 29/8000
# critic: 0.012019 - generator: -0.005851 - 1s
# Epoch 30/8000
# critic: 0.001336 - generator: -0.001069 - 1s
# Epoch 31/8000
# critic: 0.003259 - generator: 0.000597 - 1s
# Epoch 32/8000
# critic: 0.002852 - generator: 0.000761 - 1s
# Epoch 33/8000
# critic: 0.000932 - generator: 0.003127 - 1s
# Epoch 34/8000
# critic: 0.008110 - generator: 0.001873 - 1s
# Epoch 35/8000
# critic: 0.003076 - generator: 0.003760 - 1s
# Epoch 36/8000
# critic: -0.000765 - generator: 0.005784 - 1s
# Epoch 37/8000
# critic: 0.001910 - generator: 0.005143 - 1s
# Epoch 38/8000
# critic: 0.001473 - generator: 0.001650 - 1s
# Epoch 39/8000
# critic: -0.000076 - generator: 0.000177 - 1s
# Epoch 40/8000
# critic: -0.000288 - generator: -0.002265 - 1s
# Epoch 41/8000
# critic: 0.003654 - generator: -0.001516 - 1s
# Epoch 42/8000
# critic: 0.002308 - generator: -0.002464 - 1s
# Epoch 43/8000
# critic: 0.005478 - generator: -0.004350 - 1s
# Epoch 44/8000
# critic: 0.009469 - generator: -0.006952 - 1s
# Epoch 45/8000
# critic: 0.005341 - generator: -0.008649 - 1s
# Epoch 46/8000
# critic: 0.002620 - generator: -0.008186 - 1s
# Epoch 47/8000
# critic: 0.002845 - generator: -0.010560 - 1s
# Epoch 48/8000
# critic: 0.002759 - generator: -0.010888 - 1s
# Epoch 49/8000
# critic: -0.001783 - generator: -0.013043 - 1s
# Epoch 50/8000
# critic: 0.005430 - generator: -0.015929 - 1s
# Epoch 51/8000
# critic: 0.006103 - generator: -0.013145 - 1s
# Epoch 52/8000
# critic: 0.006130 - generator: -0.012749 - 1s
# Epoch 53/8000
# critic: 0.008101 - generator: -0.011696 - 1s
# Epoch 54/8000
# critic: 0.003087 - generator: -0.014261 - 1s
# Epoch 55/8000
# critic: 0.005187 - generator: -0.014803 - 1s
# Epoch 56/8000
# critic: 0.002924 - generator: -0.015061 - 1s
# Epoch 57/8000
# critic: 0.004160 - generator: -0.015219 - 1s
# Epoch 58/8000
# critic: 0.004262 - generator: -0.016588 - 1s
# Epoch 59/8000
# critic: 0.004050 - generator: -0.019231 - 1s
# Epoch 60/8000
# critic: 0.007303 - generator: -0.020229 - 1s
# Epoch 61/8000
# critic: 0.001617 - generator: -0.019980 - 1s
# Epoch 62/8000
# critic: 0.004017 - generator: -0.021135 - 1s
# Epoch 63/8000
# critic: 0.001509 - generator: -0.023061 - 1s
# Epoch 64/8000
# critic: 0.005243 - generator: -0.023636 - 1s
# Epoch 65/8000
# critic: 0.005739 - generator: -0.024097 - 1s
# Epoch 66/8000
# critic: 0.003892 - generator: -0.024821 - 1s
# Epoch 67/8000
# critic: 0.004727 - generator: -0.029213 - 1s
# Epoch 68/8000
# critic: 0.002751 - generator: -0.027124 - 1s
# Epoch 69/8000
# critic: 0.005339 - generator: -0.027333 - 1s
# Epoch 70/8000
# critic: 0.001634 - generator: -0.029132 - 1s
# Epoch 71/8000
# critic: 0.003172 - generator: -0.032297 - 1s
# Epoch 72/8000
# critic: 0.005888 - generator: -0.031833 - 1s
# Epoch 73/8000
# critic: 0.001462 - generator: -0.027998 - 1s
# Epoch 74/8000
# critic: 0.006336 - generator: -0.025781 - 1s
# Epoch 75/8000
# critic: 0.009159 - generator: -0.023491 - 1s
# Epoch 76/8000
# critic: 0.006230 - generator: -0.023975 - 1s
# Epoch 77/8000
# critic: 0.007583 - generator: -0.026476 - 1s
# Epoch 78/8000
# critic: 0.004257 - generator: -0.026578 - 1s
# Epoch 79/8000
# critic: 0.004959 - generator: -0.030110 - 1s
# Epoch 80/8000
# critic: 0.005738 - generator: -0.026468 - 1s
# Epoch 81/8000
# critic: 0.001893 - generator: -0.026171 - 1s
# Epoch 82/8000
# critic: 0.002429 - generator: -0.022729 - 1s
# Epoch 83/8000
# critic: 0.002618 - generator: -0.022480 - 1s
# Epoch 84/8000
# critic: 0.004156 - generator: -0.020236 - 1s
# Epoch 85/8000
# critic: 0.005626 - generator: -0.018466 - 1s
# Epoch 86/8000
# critic: 0.002205 - generator: -0.014986 - 1s
# Epoch 87/8000
# critic: 0.005603 - generator: -0.013079 - 1s
# Epoch 88/8000
# critic: 0.004560 - generator: -0.014035 - 1s
# Epoch 89/8000
# critic: 0.005364 - generator: -0.015051 - 1s
# Epoch 90/8000
# critic: 0.006457 - generator: -0.014316 - 1s
# Epoch 91/8000
# critic: 0.002705 - generator: -0.014854 - 1s
# Epoch 92/8000
# critic: 0.003409 - generator: -0.014377 - 1s
# Epoch 93/8000
# critic: 0.004890 - generator: -0.016296 - 1s
# Epoch 94/8000
# critic: 0.005189 - generator: -0.015655 - 1s
# Epoch 95/8000
# critic: 0.004987 - generator: -0.016564 - 1s
# Epoch 96/8000
# critic: 0.005145 - generator: -0.012730 - 1s
# Epoch 97/8000
# critic: 0.004141 - generator: -0.014250 - 1s
# Epoch 98/8000
# critic: 0.003925 - generator: -0.013123 - 1s
# Epoch 99/8000
# critic: 0.001613 - generator: -0.013183 - 1s
# Epoch 100/8000
# critic: 0.002689 - generator: -0.013709 - 1s
# Epoch 101/8000
# critic: 0.004540 - generator: -0.019072 - 1s
# Epoch 102/8000
# critic: 0.003894 - generator: -0.021012 - 1s
# Epoch 103/8000
# critic: 0.003615 - generator: -0.019752 - 1s
# Epoch 104/8000
# critic: 0.004485 - generator: -0.018276 - 1s
# Epoch 105/8000
# critic: 0.005439 - generator: -0.017050 - 1s
# Epoch 106/8000
# critic: 0.003383 - generator: -0.019275 - 1s
# Epoch 107/8000
# critic: 0.001963 - generator: -0.019450 - 1s
# Epoch 108/8000
# critic: 0.001045 - generator: -0.024004 - 1s
# Epoch 109/8000
# critic: 0.003492 - generator: -0.024173 - 1s
# Epoch 110/8000
# critic: 0.002287 - generator: -0.026287 - 1s
# Epoch 111/8000
# critic: 0.000683 - generator: -0.023058 - 1s
# Epoch 112/8000
# critic: 0.002846 - generator: -0.028631 - 1s
# Epoch 113/8000
# critic: 0.003381 - generator: -0.030205 - 1s
# Epoch 114/8000
# critic: 0.002706 - generator: -0.024603 - 1s
# Epoch 115/8000
# critic: 0.002978 - generator: -0.031046 - 1s
# Epoch 116/8000
# critic: 0.002149 - generator: -0.030277 - 1s
# Epoch 117/8000
# critic: 0.002912 - generator: -0.031147 - 1s
# Epoch 118/8000
# critic: 0.003083 - generator: -0.029429 - 1s
# Epoch 119/8000
# critic: 0.006013 - generator: -0.027049 - 1s
# Epoch 120/8000
# critic: 0.004563 - generator: -0.030333 - 1s
# Epoch 121/8000
# critic: 0.003357 - generator: -0.023950 - 1s
# Epoch 122/8000
# critic: 0.004770 - generator: -0.027043 - 1s
# Epoch 123/8000
# critic: -0.000540 - generator: -0.027172 - 1s
# Epoch 124/8000
# critic: 0.002682 - generator: -0.023669 - 1s
# Epoch 125/8000
# critic: 0.004396 - generator: -0.020819 - 1s
# Epoch 126/8000
# critic: 0.005410 - generator: -0.019981 - 1s
# Epoch 127/8000
# critic: 0.001560 - generator: -0.022909 - 1s
# Epoch 128/8000
# critic: 0.002596 - generator: -0.016835 - 1s
# Epoch 129/8000
# critic: 0.003543 - generator: -0.022856 - 1s
# Epoch 130/8000
# critic: 0.002877 - generator: -0.024058 - 1s
# Epoch 131/8000
# critic: 0.000829 - generator: -0.021861 - 1s
# Epoch 132/8000
# critic: 0.003436 - generator: -0.020102 - 1s
# Epoch 133/8000
# critic: 0.004735 - generator: -0.019126 - 1s
# Epoch 134/8000
# critic: 0.002815 - generator: -0.018201 - 1s
# Epoch 135/8000
# critic: 0.005138 - generator: -0.021192 - 1s
# Epoch 136/8000
# critic: 0.001732 - generator: -0.022521 - 1s
# Epoch 137/8000
# critic: 0.003032 - generator: -0.017946 - 1s
# Epoch 138/8000
# critic: 0.001535 - generator: -0.023343 - 1s
# Epoch 139/8000
# critic: 0.001374 - generator: -0.024104 - 1s
# Epoch 140/8000
# critic: 0.002948 - generator: -0.021099 - 1s
# Epoch 141/8000
# critic: 0.002579 - generator: -0.022119 - 1s
# Epoch 142/8000
# critic: 0.001502 - generator: -0.020848 - 1s
# Epoch 143/8000
# critic: 0.001986 - generator: -0.024074 - 1s
# Epoch 144/8000
# critic: 0.005625 - generator: -0.023969 - 1s
# Epoch 145/8000
# critic: 0.001495 - generator: -0.025129 - 1s
# Epoch 146/8000
# critic: 0.002149 - generator: -0.026491 - 1s
# Epoch 147/8000
# critic: 0.002543 - generator: -0.020517 - 1s
# Epoch 148/8000
# critic: 0.001464 - generator: -0.019274 - 1s
# Epoch 149/8000
# critic: 0.002567 - generator: -0.015893 - 1s
# Epoch 150/8000
# critic: 0.008113 - generator: -0.017027 - 1s
# Epoch 151/8000
# critic: 0.004151 - generator: -0.018449 - 1s
# Epoch 152/8000
# critic: 0.002756 - generator: -0.016101 - 1s
# Epoch 153/8000
# critic: 0.001273 - generator: -0.020773 - 1s
# Epoch 154/8000
# critic: 0.004853 - generator: -0.020768 - 1s
# Epoch 155/8000
# critic: 0.002050 - generator: -0.017018 - 1s
# Epoch 156/8000
# critic: 0.002741 - generator: -0.018486 - 1s
# Epoch 157/8000
# critic: 0.003019 - generator: -0.017526 - 1s
# Epoch 158/8000
# critic: 0.002010 - generator: -0.017559 - 1s
# Epoch 159/8000
# critic: 0.003077 - generator: -0.018973 - 1s
# Epoch 160/8000
# critic: 0.002211 - generator: -0.018090 - 1s
# Epoch 161/8000
# critic: 0.005453 - generator: -0.019324 - 1s
# Epoch 162/8000
# critic: 0.001434 - generator: -0.016440 - 1s
# Epoch 163/8000
# critic: 0.001895 - generator: -0.019677 - 1s
# Epoch 164/8000
# critic: 0.004493 - generator: -0.016553 - 1s
# Epoch 165/8000
# critic: 0.000538 - generator: -0.018242 - 1s
# Epoch 166/8000
# critic: 0.002280 - generator: -0.023397 - 1s
# Epoch 167/8000
# critic: 0.001949 - generator: -0.019466 - 1s
# Epoch 168/8000
# critic: 0.005637 - generator: -0.020074 - 1s
# Epoch 169/8000
# critic: -0.000321 - generator: -0.021034 - 1s
# Epoch 170/8000
# critic: 0.003073 - generator: -0.019639 - 1s
# Epoch 171/8000
# critic: 0.002090 - generator: -0.021089 - 1s
# Epoch 172/8000
# critic: 0.001914 - generator: -0.018358 - 1s
# Epoch 173/8000
# critic: 0.003016 - generator: -0.017074 - 1s
# Epoch 174/8000
# critic: 0.001814 - generator: -0.016065 - 1s
# Epoch 175/8000
# critic: 0.000814 - generator: -0.019335 - 1s
# Epoch 176/8000
# critic: 0.001440 - generator: -0.020113 - 1s
# Epoch 177/8000
# critic: 0.003138 - generator: -0.021546 - 1s
# Epoch 178/8000
# critic: 0.000774 - generator: -0.021138 - 1s
# Epoch 179/8000
# critic: 0.005818 - generator: -0.018999 - 1s
# Epoch 180/8000
# critic: 0.002271 - generator: -0.019745 - 1s
# Epoch 181/8000
# critic: 0.003458 - generator: -0.016493 - 1s
# Epoch 182/8000
# critic: 0.003915 - generator: -0.016506 - 1s
# Epoch 183/8000
# critic: 0.001314 - generator: -0.016736 - 1s
# Epoch 184/8000
# critic: 0.002497 - generator: -0.014983 - 1s
# Epoch 185/8000
# critic: 0.000508 - generator: -0.019492 - 1s
# Epoch 186/8000
# critic: 0.002151 - generator: -0.017135 - 1s
# Epoch 187/8000
# critic: 0.002829 - generator: -0.015932 - 1s
# Epoch 188/8000
# critic: 0.002811 - generator: -0.017725 - 1s
# Epoch 189/8000
# critic: 0.001934 - generator: -0.017903 - 1s
# Epoch 190/8000
# critic: 0.000688 - generator: -0.015596 - 1s
# Epoch 191/8000
# critic: 0.001086 - generator: -0.016374 - 1s
# Epoch 192/8000
# critic: 0.001039 - generator: -0.013370 - 1s
# Epoch 193/8000
# critic: 0.000758 - generator: -0.013216 - 1s
# Epoch 194/8000
# critic: -0.000616 - generator: -0.012467 - 1s
# Epoch 195/8000
# critic: -0.001292 - generator: -0.011577 - 1s
# Epoch 196/8000
# critic: 0.002182 - generator: -0.009787 - 1s
# Epoch 197/8000
# critic: 0.000481 - generator: -0.013767 - 1s
# Epoch 198/8000
# critic: 0.001117 - generator: -0.014665 - 1s
# Epoch 199/8000
# critic: 0.000624 - generator: -0.012310 - 1s
# Epoch 200/8000
# critic: 0.001543 - generator: -0.011053 - 1s
# Epoch 201/8000
# critic: 0.002711 - generator: -0.006567 - 1s
# Epoch 202/8000
# critic: 0.001466 - generator: -0.012614 - 1s
# Epoch 203/8000
# critic: 0.003140 - generator: -0.011870 - 1s
# Epoch 204/8000
# critic: 0.000095 - generator: -0.009085 - 1s
# Epoch 205/8000
# critic: 0.000824 - generator: -0.010231 - 1s
# Epoch 206/8000
# critic: 0.000565 - generator: -0.006427 - 1s
# Epoch 207/8000
# critic: 0.002629 - generator: -0.004748 - 1s
# Epoch 208/8000
# critic: 0.004100 - generator: -0.004970 - 1s
# Epoch 209/8000
# critic: 0.001409 - generator: -0.006347 - 1s
# Epoch 210/8000
# critic: -0.000436 - generator: -0.011622 - 1s
# Epoch 211/8000
# critic: 0.000370 - generator: -0.009854 - 1s
# Epoch 212/8000
# critic: 0.000958 - generator: -0.007950 - 1s
# Epoch 213/8000
# critic: 0.001299 - generator: -0.007131 - 1s
# Epoch 214/8000
# critic: 0.000851 - generator: -0.009256 - 1s
# Epoch 215/8000
# critic: 0.003873 - generator: -0.008035 - 1s
# Epoch 216/8000
# critic: 0.002172 - generator: -0.009926 - 1s
# Epoch 217/8000
# critic: 0.000912 - generator: -0.005021 - 1s
# Epoch 218/8000
# critic: 0.001665 - generator: -0.002031 - 1s
# Epoch 219/8000
# critic: 0.003609 - generator: -0.005958 - 1s
# Epoch 220/8000
# critic: 0.001034 - generator: -0.003719 - 1s
# Epoch 221/8000
# critic: 0.001185 - generator: -0.002531 - 1s
# Epoch 222/8000
# critic: 0.000720 - generator: -0.002202 - 1s
# Epoch 223/8000
# critic: 0.000429 - generator: -0.005786 - 1s
# Epoch 224/8000
# critic: 0.004042 - generator: -0.007709 - 1s
# Epoch 225/8000
# critic: 0.001060 - generator: -0.002256 - 1s
# Epoch 226/8000
# critic: 0.000642 - generator: -0.002825 - 1s
# Epoch 227/8000
# critic: 0.002158 - generator: -0.003804 - 1s
# Epoch 228/8000
# critic: 0.001131 - generator: -0.005767 - 1s
# Epoch 229/8000
# critic: 0.002071 - generator: -0.005488 - 1s
# Epoch 230/8000
# critic: 0.004572 - generator: -0.006834 - 1s
# Epoch 231/8000
# critic: 0.001002 - generator: -0.003582 - 1s
# Epoch 232/8000
# critic: 0.001170 - generator: -0.005750 - 1s
# Epoch 233/8000
# critic: 0.001190 - generator: -0.002629 - 1s
# Epoch 234/8000
# critic: 0.001621 - generator: -0.001469 - 1s
# Epoch 235/8000
# critic: 0.001577 - generator: -0.005302 - 1s
# Epoch 236/8000
# critic: 0.000489 - generator: -0.003979 - 1s
# Epoch 237/8000
# critic: 0.001845 - generator: -0.001748 - 1s
# Epoch 238/8000
# critic: 0.001192 - generator: -0.003932 - 1s
# Epoch 239/8000
# critic: 0.003380 - generator: -0.003330 - 1s
# Epoch 240/8000
# critic: -0.000942 - generator: -0.003505 - 1s
# Epoch 241/8000
# critic: 0.000977 - generator: -0.002142 - 1s
# Epoch 242/8000
# critic: 0.003775 - generator: -0.003383 - 1s
# Epoch 243/8000
# critic: -0.000486 - generator: -0.000822 - 1s
# Epoch 244/8000
# critic: 0.001104 - generator: -0.001263 - 1s
# Epoch 245/8000
# critic: 0.001041 - generator: 0.001115 - 1s
# Epoch 246/8000
# critic: 0.000354 - generator: 0.000688 - 1s
# Epoch 247/8000
# critic: 0.004046 - generator: 0.001974 - 1s
# Epoch 248/8000
# critic: 0.001316 - generator: -0.001243 - 1s
# Epoch 249/8000
# critic: 0.001306 - generator: -0.000240 - 1s
# Epoch 250/8000
# critic: 0.002881 - generator: -0.002489 - 1s
# Epoch 251/8000
# critic: 0.001985 - generator: -0.002674 - 1s
# Epoch 252/8000
# critic: 0.002630 - generator: -0.001680 - 1s
# Epoch 253/8000
# critic: 0.001604 - generator: -0.003343 - 1s
# Epoch 254/8000
# critic: 0.001361 - generator: -0.000624 - 1s
# Epoch 255/8000
# critic: 0.001199 - generator: 0.001574 - 1s
# Epoch 256/8000
# critic: 0.001235 - generator: 0.003278 - 1s
# Epoch 257/8000
# critic: 0.001608 - generator: 0.002069 - 1s
# Epoch 258/8000
# critic: 0.000164 - generator: 0.002708 - 1s
# Epoch 259/8000
# critic: 0.000286 - generator: 0.001711 - 1s
# Epoch 260/8000
# critic: 0.001994 - generator: 0.000590 - 1s
# Epoch 261/8000
# critic: 0.000155 - generator: 0.002060 - 1s
# Epoch 262/8000
# critic: 0.001045 - generator: -0.000305 - 1s
# Epoch 263/8000
# critic: 0.001704 - generator: 0.002204 - 1s
# Epoch 264/8000
# critic: 0.000922 - generator: 0.004133 - 1s
# Epoch 265/8000
# critic: 0.002313 - generator: 0.006421 - 1s
# Epoch 266/8000
# critic: 0.000079 - generator: 0.001030 - 1s
# Epoch 267/8000
# critic: 0.001094 - generator: 0.000553 - 1s
# Epoch 268/8000
# critic: 0.002090 - generator: 0.003558 - 1s
# Epoch 269/8000
# critic: 0.002804 - generator: 0.002804 - 1s
# Epoch 270/8000
# critic: 0.002023 - generator: 0.003209 - 1s
# Epoch 271/8000
# critic: 0.004128 - generator: 0.004456 - 1s
# Epoch 272/8000
# critic: 0.001297 - generator: 0.004551 - 1s
# Epoch 273/8000
# critic: 0.003401 - generator: 0.003830 - 1s
# Epoch 274/8000
# critic: 0.001101 - generator: 0.005555 - 1s
# Epoch 275/8000
# critic: 0.002646 - generator: 0.006323 - 1s
# Epoch 276/8000
# critic: 0.001091 - generator: 0.006749 - 1s
# Epoch 277/8000
# critic: 0.002224 - generator: 0.006776 - 1s
# Epoch 278/8000
# critic: 0.001366 - generator: 0.006516 - 1s
# Epoch 279/8000
# critic: 0.001299 - generator: 0.001751 - 1s
# Epoch 280/8000
# critic: 0.000481 - generator: 0.007609 - 1s
# Epoch 281/8000
# critic: 0.003064 - generator: 0.008032 - 1s
# Epoch 282/8000
# critic: -0.000198 - generator: 0.008019 - 1s
# Epoch 283/8000
# critic: 0.003370 - generator: 0.005921 - 1s
# Epoch 284/8000
# critic: 0.000204 - generator: 0.005977 - 1s
# Epoch 285/8000
# critic: 0.000446 - generator: 0.007988 - 1s
# Epoch 286/8000
# critic: 0.001039 - generator: 0.008706 - 1s
# Epoch 287/8000
# critic: 0.001664 - generator: 0.009227 - 1s
# Epoch 288/8000
# critic: 0.002487 - generator: 0.009436 - 1s
# Epoch 289/8000
# critic: 0.001104 - generator: 0.008363 - 1s
# Epoch 290/8000
# critic: 0.001347 - generator: 0.008887 - 1s
# Epoch 291/8000
# critic: 0.001918 - generator: 0.009454 - 1s
# Epoch 292/8000
# critic: 0.003353 - generator: 0.010157 - 1s
# Epoch 293/8000
# critic: 0.001644 - generator: 0.009108 - 1s
# Epoch 294/8000
# critic: 0.000143 - generator: 0.010803 - 1s
# Epoch 295/8000
# critic: 0.000504 - generator: 0.009065 - 1s
# Epoch 296/8000
# critic: 0.000987 - generator: 0.008871 - 1s
# Epoch 297/8000
# critic: 0.001945 - generator: 0.009086 - 1s
# Epoch 298/8000
# critic: 0.001812 - generator: 0.009279 - 1s
# Epoch 299/8000
# critic: 0.001428 - generator: 0.009959 - 1s
# Epoch 300/8000
# critic: 0.002030 - generator: 0.011583 - 1s
# Epoch 301/8000
# critic: 0.000807 - generator: 0.009011 - 1s
# Epoch 302/8000
# critic: 0.002983 - generator: 0.012183 - 1s
# Epoch 303/8000
# critic: 0.000502 - generator: 0.007157 - 1s
# Epoch 304/8000
# critic: 0.002789 - generator: 0.009485 - 1s
# Epoch 305/8000
# critic: 0.001870 - generator: 0.011515 - 1s
# Epoch 306/8000
# critic: 0.001754 - generator: 0.008450 - 1s
# Epoch 307/8000
# critic: 0.001888 - generator: 0.008952 - 1s
# Epoch 308/8000
# critic: 0.002699 - generator: 0.011180 - 1s
# Epoch 309/8000
# critic: 0.000473 - generator: 0.011158 - 1s
# Epoch 310/8000
# critic: 0.001113 - generator: 0.011131 - 1s
# Epoch 311/8000
# critic: 0.000262 - generator: 0.012595 - 1s
# Epoch 312/8000
# critic: 0.002950 - generator: 0.012507 - 1s
# Epoch 313/8000
# critic: 0.001333 - generator: 0.009751 - 1s
# Epoch 314/8000
# critic: 0.001802 - generator: 0.008115 - 1s
# Epoch 315/8000
# critic: 0.000335 - generator: 0.010164 - 1s
# Epoch 316/8000
# critic: 0.002025 - generator: 0.009587 - 1s
# Epoch 317/8000
# critic: 0.003279 - generator: 0.008472 - 1s
# Epoch 318/8000
# critic: 0.001681 - generator: 0.006964 - 1s
# Epoch 319/8000
# critic: 0.003497 - generator: 0.007436 - 1s
# Epoch 320/8000
# critic: 0.002346 - generator: 0.008779 - 1s
# Epoch 321/8000
# critic: 0.002052 - generator: 0.009734 - 1s
# Epoch 322/8000
# critic: 0.000190 - generator: 0.008753 - 1s
# Epoch 323/8000
# critic: -0.000077 - generator: 0.008853 - 1s
# Epoch 324/8000
# critic: 0.001832 - generator: 0.011629 - 1s
# Epoch 325/8000
# critic: 0.001902 - generator: 0.012782 - 1s
# Epoch 326/8000
# critic: 0.002023 - generator: 0.006891 - 1s
# Epoch 327/8000
# critic: 0.002364 - generator: 0.008188 - 1s
# Epoch 328/8000
# critic: 0.001132 - generator: 0.009130 - 1s
# Epoch 329/8000
# critic: 0.000953 - generator: 0.010534 - 1s
# Epoch 330/8000
# critic: 0.001308 - generator: 0.010352 - 1s
# Epoch 331/8000
# critic: 0.000758 - generator: 0.012933 - 1s
# Epoch 332/8000
# critic: 0.002199 - generator: 0.011693 - 1s
# Epoch 333/8000
# critic: 0.001610 - generator: 0.013210 - 1s
# Epoch 334/8000
# critic: 0.001147 - generator: 0.012556 - 1s
# Epoch 335/8000
# critic: 0.001681 - generator: 0.011173 - 1s
# Epoch 336/8000
# critic: 0.001528 - generator: 0.011630 - 1s
# Epoch 337/8000
# critic: 0.001089 - generator: 0.009946 - 1s
# Epoch 338/8000
# critic: 0.000606 - generator: 0.009181 - 1s
# Epoch 339/8000
# critic: 0.000656 - generator: 0.010606 - 1s
# Epoch 340/8000
# critic: 0.001009 - generator: 0.011141 - 1s
# Epoch 341/8000
# critic: 0.001756 - generator: 0.012967 - 1s
# Epoch 342/8000
# critic: 0.001216 - generator: 0.012211 - 1s
# Epoch 343/8000
# critic: 0.001208 - generator: 0.013048 - 1s
# Epoch 344/8000
# critic: 0.000232 - generator: 0.011695 - 1s
# Epoch 345/8000
# critic: 0.002128 - generator: 0.011873 - 1s
# Epoch 346/8000
# critic: 0.003135 - generator: 0.012240 - 1s
# Epoch 347/8000
# critic: 0.000161 - generator: 0.014945 - 1s
# Epoch 348/8000
# critic: 0.000852 - generator: 0.010678 - 1s
# Epoch 349/8000
# critic: 0.001670 - generator: 0.012695 - 1s
# Epoch 350/8000
# critic: 0.000785 - generator: 0.014409 - 1s
# Epoch 351/8000
# critic: 0.000817 - generator: 0.015499 - 1s
# Epoch 352/8000
# critic: 0.000395 - generator: 0.014823 - 1s
# Epoch 353/8000
# critic: -0.000434 - generator: 0.012593 - 1s
# Epoch 354/8000
# critic: 0.000410 - generator: 0.010802 - 1s
# Epoch 355/8000
# critic: 0.000941 - generator: 0.010141 - 1s
# Epoch 356/8000
# critic: 0.002505 - generator: 0.010696 - 1s
# Epoch 357/8000
# critic: 0.001841 - generator: 0.011840 - 1s
# Epoch 358/8000
# critic: 0.000272 - generator: 0.013387 - 1s
# Epoch 359/8000
# critic: 0.001818 - generator: 0.012356 - 1s
# Epoch 360/8000
# critic: 0.001337 - generator: 0.011893 - 1s
# Epoch 361/8000
# critic: -0.000393 - generator: 0.013507 - 1s
# Epoch 362/8000
# critic: 0.000814 - generator: 0.015475 - 1s
# Epoch 363/8000
# critic: 0.000612 - generator: 0.013332 - 1s
# Epoch 364/8000
# critic: 0.001023 - generator: 0.015103 - 1s
# Epoch 365/8000
# critic: 0.001965 - generator: 0.013650 - 1s
# Epoch 366/8000
# critic: 0.002508 - generator: 0.016240 - 1s
# Epoch 367/8000
# critic: 0.000667 - generator: 0.014145 - 1s
# Epoch 368/8000
# critic: 0.001999 - generator: 0.017056 - 1s
# Epoch 369/8000
# critic: 0.001548 - generator: 0.013800 - 1s
# Epoch 370/8000
# critic: 0.001317 - generator: 0.017849 - 1s
# Epoch 371/8000
# critic: 0.001626 - generator: 0.015097 - 1s
# Epoch 372/8000
# critic: 0.001443 - generator: 0.015008 - 1s
# Epoch 373/8000
# critic: 0.001471 - generator: 0.014093 - 1s
# Epoch 374/8000
# critic: 0.003976 - generator: 0.015096 - 1s
# Epoch 375/8000
# critic: 0.000300 - generator: 0.013569 - 1s
# Epoch 376/8000
# critic: 0.001749 - generator: 0.013592 - 1s
# Epoch 377/8000
# critic: 0.001105 - generator: 0.014531 - 1s
# Epoch 378/8000
# critic: 0.001893 - generator: 0.014863 - 1s
# Epoch 379/8000
# critic: 0.001692 - generator: 0.012501 - 1s
# Epoch 380/8000
# critic: 0.000039 - generator: 0.014150 - 1s
# Epoch 381/8000
# critic: 0.001352 - generator: 0.014040 - 1s
# Epoch 382/8000
# critic: -0.000634 - generator: 0.016228 - 1s
# Epoch 383/8000
# critic: 0.001319 - generator: 0.014768 - 1s
# Epoch 384/8000
# critic: 0.001590 - generator: 0.013032 - 1s
# Epoch 385/8000
# critic: 0.003261 - generator: 0.015742 - 1s
# Epoch 386/8000
# critic: 0.000599 - generator: 0.016377 - 1s
# Epoch 387/8000
# critic: 0.000710 - generator: 0.016021 - 1s
# Epoch 388/8000
# critic: 0.001213 - generator: 0.016196 - 1s
# Epoch 389/8000
# critic: -0.000084 - generator: 0.018431 - 1s
# Epoch 390/8000
# critic: 0.000886 - generator: 0.016940 - 1s
# Epoch 391/8000
# critic: 0.001999 - generator: 0.016005 - 1s
# Epoch 392/8000
# critic: 0.000713 - generator: 0.017226 - 1s
# Epoch 393/8000
# critic: 0.001903 - generator: 0.018825 - 1s
# Epoch 394/8000
# critic: 0.003120 - generator: 0.016319 - 1s
# Epoch 395/8000
# critic: 0.000886 - generator: 0.018167 - 1s
# Epoch 396/8000
# critic: 0.000454 - generator: 0.016842 - 1s
# Epoch 397/8000
# critic: 0.000856 - generator: 0.017762 - 1s
# Epoch 398/8000
# critic: 0.001145 - generator: 0.018525 - 1s
# Epoch 399/8000
# critic: 0.001159 - generator: 0.017335 - 1s
# Epoch 400/8000
# critic: 0.000971 - generator: 0.018330 - 1s
# Epoch 401/8000
# critic: 0.002251 - generator: 0.021157 - 1s
# Epoch 402/8000
# critic: 0.001681 - generator: 0.019212 - 1s
# Epoch 403/8000
# critic: -0.000105 - generator: 0.019218 - 1s
# Epoch 404/8000
# critic: 0.000900 - generator: 0.018764 - 1s
# Epoch 405/8000
# critic: 0.001567 - generator: 0.017403 - 1s
# Epoch 406/8000
# critic: 0.001596 - generator: 0.019061 - 1s
# Epoch 407/8000
# critic: 0.000614 - generator: 0.016086 - 1s
# Epoch 408/8000
# critic: 0.000760 - generator: 0.017242 - 1s
# Epoch 409/8000
# critic: 0.001517 - generator: 0.017306 - 1s
# Epoch 410/8000
# critic: 0.002539 - generator: 0.017253 - 1s
# Epoch 411/8000
# critic: 0.000379 - generator: 0.018221 - 1s
# Epoch 412/8000
# critic: 0.002624 - generator: 0.017079 - 1s
# Epoch 413/8000
# critic: 0.000245 - generator: 0.018199 - 1s
# Epoch 414/8000
# critic: 0.002212 - generator: 0.018007 - 1s
# Epoch 415/8000
# critic: 0.000070 - generator: 0.015715 - 1s
# Epoch 416/8000
# critic: 0.000142 - generator: 0.021598 - 1s
# Epoch 417/8000
# critic: 0.003337 - generator: 0.021710 - 1s
# Epoch 418/8000
# critic: 0.001859 - generator: 0.017588 - 1s
# Epoch 419/8000
# critic: 0.002203 - generator: 0.019516 - 1s
# Epoch 420/8000
# critic: 0.000932 - generator: 0.018086 - 1s
# Epoch 421/8000
# critic: 0.000462 - generator: 0.019958 - 1s
# Epoch 422/8000
# critic: 0.001662 - generator: 0.016988 - 1s
# Epoch 423/8000
# critic: -0.000125 - generator: 0.018778 - 1s
# Epoch 424/8000
# critic: 0.000881 - generator: 0.023630 - 1s
# Epoch 425/8000
# critic: 0.002431 - generator: 0.020000 - 1s
# Epoch 426/8000
# critic: 0.001998 - generator: 0.021869 - 1s
# Epoch 427/8000
# critic: 0.001160 - generator: 0.022024 - 1s
# Epoch 428/8000
# critic: 0.001309 - generator: 0.022979 - 1s
# Epoch 429/8000
# critic: 0.002271 - generator: 0.021235 - 1s
# Epoch 430/8000
# critic: 0.000488 - generator: 0.020469 - 1s
# Epoch 431/8000
# critic: 0.001792 - generator: 0.024712 - 1s
# Epoch 432/8000
# critic: 0.000448 - generator: 0.023201 - 1s
# Epoch 433/8000
# critic: 0.001012 - generator: 0.023059 - 1s
# Epoch 434/8000
# critic: 0.001831 - generator: 0.023432 - 1s
# Epoch 435/8000
# critic: 0.001011 - generator: 0.023760 - 1s
# Epoch 436/8000
# critic: 0.000494 - generator: 0.019886 - 1s
# Epoch 437/8000
# critic: 0.002091 - generator: 0.022060 - 1s
# Epoch 438/8000
# critic: 0.000541 - generator: 0.019035 - 1s
# Epoch 439/8000
# critic: -0.000748 - generator: 0.021548 - 1s
# Epoch 440/8000
# critic: 0.001059 - generator: 0.021875 - 1s
# Epoch 441/8000
# critic: 0.000171 - generator: 0.022166 - 1s
# Epoch 442/8000
# critic: 0.000929 - generator: 0.021888 - 1s
# Epoch 443/8000
# critic: 0.001536 - generator: 0.023563 - 1s
# Epoch 444/8000
# critic: 0.000738 - generator: 0.022563 - 1s
# Epoch 445/8000
# critic: 0.000204 - generator: 0.023113 - 1s
# Epoch 446/8000
# critic: 0.000488 - generator: 0.021409 - 1s
# Epoch 447/8000
# critic: 0.002305 - generator: 0.020577 - 1s
# Epoch 448/8000
# critic: 0.000009 - generator: 0.019041 - 1s
# Epoch 449/8000
# critic: 0.001468 - generator: 0.019861 - 1s
# Epoch 450/8000
# critic: 0.001630 - generator: 0.022164 - 1s
# Epoch 451/8000
# critic: 0.001589 - generator: 0.021224 - 1s
# Epoch 452/8000
# critic: -0.000379 - generator: 0.021619 - 1s
# Epoch 453/8000
# critic: 0.000460 - generator: 0.019941 - 1s
# Epoch 454/8000
# critic: 0.001694 - generator: 0.017889 - 1s
# Epoch 455/8000
# critic: 0.002237 - generator: 0.020659 - 1s
# Epoch 456/8000
# critic: 0.001791 - generator: 0.022796 - 1s
# Epoch 457/8000
# critic: -0.000352 - generator: 0.020027 - 1s
# Epoch 458/8000
# critic: 0.000049 - generator: 0.021004 - 1s
# Epoch 459/8000
# critic: 0.003066 - generator: 0.017104 - 1s
# Epoch 460/8000
# critic: 0.002026 - generator: 0.020182 - 1s
# Epoch 461/8000
# critic: 0.001557 - generator: 0.022145 - 1s
# Epoch 462/8000
# critic: 0.002081 - generator: 0.022834 - 1s
# Epoch 463/8000
# critic: 0.002203 - generator: 0.022283 - 1s
# Epoch 464/8000
# critic: 0.001129 - generator: 0.024556 - 1s
# Epoch 465/8000
# critic: 0.000361 - generator: 0.024312 - 1s
# Epoch 466/8000
# critic: 0.000773 - generator: 0.024260 - 1s
# Epoch 467/8000
# critic: 0.001681 - generator: 0.025611 - 1s
# Epoch 468/8000
# critic: 0.001180 - generator: 0.025145 - 1s
# Epoch 469/8000
# critic: 0.001260 - generator: 0.026438 - 1s
# Epoch 470/8000
# critic: 0.000872 - generator: 0.028839 - 1s
# Epoch 471/8000
# critic: 0.001380 - generator: 0.027674 - 1s
# Epoch 472/8000
# critic: 0.001090 - generator: 0.025459 - 1s
# Epoch 473/8000
# critic: 0.001723 - generator: 0.027492 - 1s
# Epoch 474/8000
# critic: 0.001196 - generator: 0.027872 - 1s
# Epoch 475/8000
# critic: 0.001558 - generator: 0.026511 - 1s
# Epoch 476/8000
# critic: 0.000844 - generator: 0.029335 - 1s
# Epoch 477/8000
# critic: 0.003226 - generator: 0.026757 - 1s
# Epoch 478/8000
# critic: 0.001152 - generator: 0.027971 - 1s
# Epoch 479/8000
# critic: 0.001797 - generator: 0.028447 - 1s
# Epoch 480/8000
# critic: 0.000924 - generator: 0.028531 - 1s
# Epoch 481/8000
# critic: 0.002402 - generator: 0.029122 - 1s
# Epoch 482/8000
# critic: 0.000068 - generator: 0.028348 - 1s
# Epoch 483/8000
# critic: 0.001659 - generator: 0.028296 - 1s
# Epoch 484/8000
# critic: 0.001269 - generator: 0.028924 - 1s
# Epoch 485/8000
# critic: 0.002188 - generator: 0.025581 - 1s
# Epoch 486/8000
# critic: 0.001729 - generator: 0.025200 - 1s
# Epoch 487/8000
# critic: 0.002472 - generator: 0.023784 - 1s
# Epoch 488/8000
# critic: 0.001182 - generator: 0.028688 - 1s
# Epoch 489/8000
# critic: 0.001272 - generator: 0.027005 - 1s
# Epoch 490/8000
# critic: 0.002057 - generator: 0.028264 - 1s
# Epoch 491/8000
# critic: 0.001760 - generator: 0.026975 - 1s
# Epoch 492/8000
# critic: 0.001914 - generator: 0.027791 - 1s
# Epoch 493/8000
# critic: 0.002165 - generator: 0.029369 - 1s
# Epoch 494/8000
# critic: 0.001879 - generator: 0.029978 - 1s
# Epoch 495/8000
# critic: 0.002685 - generator: 0.030177 - 1s
# Epoch 496/8000
# critic: 0.001032 - generator: 0.028802 - 1s
# Epoch 497/8000
# critic: 0.001452 - generator: 0.030483 - 1s
# Epoch 498/8000
# critic: 0.001139 - generator: 0.032563 - 1s
# Epoch 499/8000
# critic: 0.004000 - generator: 0.031939 - 1s
# Epoch 500/8000
# critic: 0.002531 - generator: 0.031949 - 1s
# Epoch 501/8000
# critic: 0.001025 - generator: 0.029423 - 1s
# Epoch 502/8000
# critic: 0.001502 - generator: 0.029099 - 1s
# Epoch 503/8000
# critic: 0.001681 - generator: 0.027131 - 1s
# Epoch 504/8000
# critic: 0.001557 - generator: 0.030328 - 1s
# Epoch 505/8000
# critic: 0.001117 - generator: 0.029722 - 1s
# Epoch 506/8000
# critic: 0.002402 - generator: 0.030013 - 1s
# Epoch 507/8000
# critic: 0.002795 - generator: 0.030666 - 1s
# Epoch 508/8000
# critic: 0.001106 - generator: 0.030668 - 1s
# Epoch 509/8000
# critic: 0.001007 - generator: 0.030913 - 1s
# Epoch 510/8000
# critic: 0.002651 - generator: 0.029563 - 1s
# Epoch 511/8000
# critic: 0.001310 - generator: 0.030107 - 1s
# Epoch 512/8000
# critic: 0.001786 - generator: 0.030777 - 1s
# Epoch 513/8000
# critic: 0.001118 - generator: 0.033517 - 1s
# Epoch 514/8000
# critic: 0.002849 - generator: 0.031496 - 1s
# Epoch 515/8000
# critic: 0.001672 - generator: 0.033342 - 1s
# Epoch 516/8000
# critic: 0.001284 - generator: 0.033298 - 1s
# Epoch 517/8000
# critic: 0.002164 - generator: 0.032237 - 1s
# Epoch 518/8000
# critic: 0.002395 - generator: 0.030966 - 1s
# Epoch 519/8000
# critic: 0.002229 - generator: 0.033145 - 1s
# Epoch 520/8000
# critic: 0.001005 - generator: 0.033858 - 1s
# Epoch 521/8000
# critic: 0.002147 - generator: 0.034259 - 1s
# Epoch 522/8000
# critic: 0.002756 - generator: 0.031650 - 1s
# Epoch 523/8000
# critic: 0.001669 - generator: 0.033635 - 1s
# Epoch 524/8000
# critic: 0.001849 - generator: 0.031822 - 1s
# Epoch 525/8000
# critic: 0.000924 - generator: 0.029412 - 1s
# Epoch 526/8000
# critic: 0.002386 - generator: 0.032042 - 1s
# Epoch 527/8000
# critic: 0.002267 - generator: 0.030466 - 1s
# Epoch 528/8000
# critic: 0.002559 - generator: 0.032195 - 1s
# Epoch 529/8000
# critic: 0.001870 - generator: 0.031395 - 1s
# Epoch 530/8000
# critic: 0.002881 - generator: 0.033936 - 1s
# Epoch 531/8000
# critic: 0.003127 - generator: 0.033111 - 1s
# Epoch 532/8000
# critic: 0.001738 - generator: 0.031140 - 1s
# Epoch 533/8000
# critic: 0.001263 - generator: 0.031945 - 1s
# Epoch 534/8000
# critic: 0.001535 - generator: 0.033827 - 1s
# Epoch 535/8000
# critic: 0.000676 - generator: 0.031286 - 1s
# Epoch 536/8000
# critic: 0.001931 - generator: 0.033065 - 1s
# Epoch 537/8000
# critic: 0.002494 - generator: 0.030226 - 1s
# Epoch 538/8000
# critic: 0.000805 - generator: 0.030794 - 1s
# Epoch 539/8000
# critic: 0.001772 - generator: 0.029701 - 1s
# Epoch 540/8000
# critic: 0.001139 - generator: 0.029800 - 1s
# Epoch 541/8000
# critic: 0.001815 - generator: 0.027641 - 0s
# Epoch 542/8000
# critic: 0.002150 - generator: 0.028996 - 1s
# Epoch 543/8000
# critic: 0.001346 - generator: 0.026309 - 1s
# Epoch 544/8000
# critic: 0.000813 - generator: 0.026919 - 1s
# Epoch 545/8000
# critic: 0.002824 - generator: 0.028550 - 1s
# Epoch 546/8000
# critic: 0.000907 - generator: 0.028346 - 1s
# Epoch 547/8000
# critic: 0.001292 - generator: 0.025995 - 1s
# Epoch 548/8000
# critic: 0.002874 - generator: 0.025805 - 1s
# Epoch 549/8000
# critic: 0.002246 - generator: 0.026657 - 1s
# Epoch 550/8000
# critic: 0.002362 - generator: 0.027519 - 1s
# Epoch 551/8000
# critic: 0.002671 - generator: 0.024098 - 1s
# Epoch 552/8000
# critic: 0.001957 - generator: 0.024946 - 1s
# Epoch 553/8000
# critic: 0.002318 - generator: 0.025361 - 1s
# Epoch 554/8000
# critic: 0.001365 - generator: 0.023631 - 1s
# Epoch 555/8000
# critic: 0.001513 - generator: 0.023669 - 1s
# Epoch 556/8000
# critic: 0.002482 - generator: 0.023009 - 1s
# Epoch 557/8000
# critic: 0.002256 - generator: 0.025406 - 1s
# Epoch 558/8000
# critic: 0.002536 - generator: 0.020806 - 1s
# Epoch 559/8000
# critic: 0.001181 - generator: 0.017441 - 1s
# Epoch 560/8000
# critic: 0.001774 - generator: 0.017083 - 1s
# Epoch 561/8000
# critic: 0.002503 - generator: 0.017604 - 1s
# Epoch 562/8000
# critic: 0.002794 - generator: 0.018762 - 1s
# Epoch 563/8000
# critic: 0.000427 - generator: 0.018982 - 1s
# Epoch 564/8000
# critic: 0.001748 - generator: 0.017797 - 1s
# Epoch 565/8000
# critic: 0.001832 - generator: 0.018190 - 1s
# Epoch 566/8000
# critic: 0.001567 - generator: 0.018099 - 1s
# Epoch 567/8000
# critic: 0.002217 - generator: 0.017866 - 1s
# Epoch 568/8000
# critic: 0.002548 - generator: 0.017229 - 1s
# Epoch 569/8000
# critic: 0.001545 - generator: 0.016765 - 1s
# Epoch 570/8000
# critic: 0.002799 - generator: 0.016460 - 1s
# Epoch 571/8000
# critic: 0.002827 - generator: 0.014374 - 1s
# Epoch 572/8000
# critic: 0.002389 - generator: 0.015257 - 1s
# Epoch 573/8000
# critic: 0.001209 - generator: 0.016402 - 1s
# Epoch 574/8000
# critic: 0.002297 - generator: 0.015630 - 1s
# Epoch 575/8000
# critic: 0.002039 - generator: 0.013442 - 1s
# Epoch 576/8000
# critic: 0.002152 - generator: 0.015082 - 1s
# Epoch 577/8000
# critic: 0.003819 - generator: 0.014696 - 1s
# Epoch 578/8000
# critic: 0.002425 - generator: 0.014684 - 1s
# Epoch 579/8000
# critic: 0.002048 - generator: 0.014088 - 1s
# Epoch 580/8000
# critic: 0.003030 - generator: 0.015920 - 1s
# Epoch 581/8000
# critic: 0.003114 - generator: 0.015325 - 1s
# Epoch 582/8000
# critic: 0.002206 - generator: 0.015058 - 1s
# Epoch 583/8000
# critic: 0.002865 - generator: 0.015005 - 1s
# Epoch 584/8000
# critic: 0.001118 - generator: 0.015103 - 1s
# Epoch 585/8000
# critic: 0.001384 - generator: 0.016946 - 1s
# Epoch 586/8000
# critic: 0.002158 - generator: 0.014154 - 1s
# Epoch 587/8000
# critic: 0.002472 - generator: 0.013820 - 1s
# Epoch 588/8000
# critic: 0.002582 - generator: 0.012515 - 1s
# Epoch 589/8000
# critic: 0.001770 - generator: 0.014239 - 1s
# Epoch 590/8000
# critic: 0.002121 - generator: 0.014261 - 1s
# Epoch 591/8000
# critic: 0.002418 - generator: 0.012901 - 1s
# Epoch 592/8000
# critic: 0.002158 - generator: 0.014653 - 1s
# Epoch 593/8000
# critic: 0.003774 - generator: 0.014294 - 1s
# Epoch 594/8000
# critic: 0.002100 - generator: 0.014907 - 1s
# Epoch 595/8000
# critic: 0.002341 - generator: 0.014945 - 1s
# Epoch 596/8000
# critic: 0.002044 - generator: 0.011747 - 1s
# Epoch 597/8000
# critic: 0.001180 - generator: 0.012539 - 1s
# Epoch 598/8000
# critic: 0.001855 - generator: 0.012367 - 1s
# Epoch 599/8000
# critic: 0.001277 - generator: 0.011854 - 1s
# Epoch 600/8000
# critic: 0.000693 - generator: 0.011333 - 1s
# Epoch 601/8000
# critic: 0.003207 - generator: 0.011078 - 1s
# Epoch 602/8000
# critic: 0.002328 - generator: 0.012010 - 1s
# Epoch 603/8000
# critic: 0.001729 - generator: 0.012427 - 1s
# Epoch 604/8000
# critic: 0.003963 - generator: 0.011299 - 1s
# Epoch 605/8000
# critic: 0.001920 - generator: 0.011552 - 1s
# Epoch 606/8000
# critic: 0.001898 - generator: 0.011205 - 1s
# Epoch 607/8000
# critic: 0.002418 - generator: 0.009980 - 1s
# Epoch 608/8000
# critic: 0.000633 - generator: 0.011429 - 1s
# Epoch 609/8000
# critic: 0.002733 - generator: 0.011025 - 1s
# Epoch 610/8000
# critic: 0.002232 - generator: 0.012334 - 1s
# Epoch 611/8000
# critic: 0.002736 - generator: 0.013199 - 1s
# Epoch 612/8000
# critic: 0.002303 - generator: 0.014568 - 1s
# Epoch 613/8000
# critic: 0.002869 - generator: 0.010889 - 1s
# Epoch 614/8000
# critic: 0.003423 - generator: 0.008580 - 1s
# Epoch 615/8000
# critic: 0.003437 - generator: 0.008767 - 1s
# Epoch 616/8000
# critic: 0.001615 - generator: 0.009858 - 1s
# Epoch 617/8000
# critic: 0.002418 - generator: 0.009246 - 1s
# Epoch 618/8000
# critic: 0.002679 - generator: 0.009484 - 1s
# Epoch 619/8000
# critic: 0.001483 - generator: 0.009666 - 1s
# Epoch 620/8000
# critic: 0.002962 - generator: 0.008695 - 1s
# Epoch 621/8000
# critic: 0.002857 - generator: 0.010054 - 1s
# Epoch 622/8000
# critic: 0.002745 - generator: 0.008234 - 1s
# Epoch 623/8000
# critic: 0.002784 - generator: 0.007092 - 1s
# Epoch 624/8000
# critic: 0.002486 - generator: 0.008567 - 1s
# Epoch 625/8000
# critic: 0.002529 - generator: 0.007895 - 1s
# Epoch 626/8000
# critic: 0.001309 - generator: 0.008768 - 1s
# Epoch 627/8000
# critic: 0.002514 - generator: 0.008808 - 1s
# Epoch 628/8000
# critic: 0.001646 - generator: 0.006959 - 1s
# Epoch 629/8000
# critic: 0.001608 - generator: 0.007331 - 1s
# Epoch 630/8000
# critic: 0.002313 - generator: 0.005581 - 1s
# Epoch 631/8000
# critic: 0.001971 - generator: 0.005304 - 1s
# Epoch 632/8000
# critic: 0.002595 - generator: 0.003231 - 1s
# Epoch 633/8000
# critic: 0.002372 - generator: 0.003463 - 1s
# Epoch 634/8000
# critic: 0.004310 - generator: 0.003326 - 1s
# Epoch 635/8000
# critic: 0.002604 - generator: 0.001933 - 1s
# Epoch 636/8000
# critic: 0.002049 - generator: 0.004769 - 1s
# Epoch 637/8000
# critic: 0.001827 - generator: 0.006197 - 1s
# Epoch 638/8000
# critic: 0.003513 - generator: 0.006110 - 1s
# Epoch 639/8000
# critic: 0.001637 - generator: 0.003694 - 1s
# Epoch 640/8000
# critic: 0.003701 - generator: 0.001427 - 1s
# Epoch 641/8000
# critic: 0.003658 - generator: 0.003098 - 1s
# Epoch 642/8000
# critic: 0.003755 - generator: 0.003016 - 1s
# Epoch 643/8000
# critic: 0.002748 - generator: 0.001740 - 1s
# Epoch 644/8000
# critic: 0.002273 - generator: 0.004126 - 1s
# Epoch 645/8000
# critic: 0.001950 - generator: 0.003179 - 1s
# Epoch 646/8000
# critic: 0.003804 - generator: 0.005260 - 1s
# Epoch 647/8000
# critic: 0.003245 - generator: 0.006466 - 1s
# Epoch 648/8000
# critic: 0.002763 - generator: 0.006767 - 1s
# Epoch 649/8000
# critic: 0.002683 - generator: 0.006833 - 1s
# Epoch 650/8000
# critic: 0.004650 - generator: 0.006893 - 1s
# Epoch 651/8000
# critic: 0.004063 - generator: 0.006190 - 1s
# Epoch 652/8000
# critic: 0.001673 - generator: 0.006760 - 1s
# Epoch 653/8000
# critic: 0.003147 - generator: 0.006634 - 1s
# Epoch 654/8000
# critic: 0.003043 - generator: 0.005490 - 1s
# Epoch 655/8000
# critic: 0.002565 - generator: 0.006640 - 1s
# Epoch 656/8000
# critic: 0.004166 - generator: 0.006184 - 1s
# Epoch 657/8000
# critic: 0.003563 - generator: 0.007522 - 1s
# Epoch 658/8000
# critic: 0.001999 - generator: 0.007569 - 1s
# Epoch 659/8000
# critic: 0.002861 - generator: 0.007989 - 1s
# Epoch 660/8000
# critic: 0.003477 - generator: 0.009147 - 1s
# Epoch 661/8000
# critic: 0.003475 - generator: 0.007557 - 1s
# Epoch 662/8000
# critic: 0.003028 - generator: 0.009344 - 1s
# Epoch 663/8000
# critic: 0.001824 - generator: 0.009201 - 1s
# Epoch 664/8000
# critic: 0.003592 - generator: 0.008899 - 1s
# Epoch 665/8000
# critic: 0.002147 - generator: 0.007748 - 1s
# Epoch 666/8000
# critic: 0.001787 - generator: 0.007962 - 1s
# Epoch 667/8000
# critic: 0.003813 - generator: 0.006325 - 1s
# Epoch 668/8000
# critic: 0.002914 - generator: 0.007588 - 1s
# Epoch 669/8000
# critic: 0.001464 - generator: 0.008377 - 1s
# Epoch 670/8000
# critic: 0.003497 - generator: 0.009835 - 1s
# Epoch 671/8000
# critic: 0.002025 - generator: 0.007693 - 1s
# Epoch 672/8000
# critic: 0.001289 - generator: 0.008422 - 1s
# Epoch 673/8000
# critic: 0.003435 - generator: 0.005439 - 1s
# Epoch 674/8000
# critic: 0.002230 - generator: 0.008563 - 1s
# Epoch 675/8000
# critic: 0.001867 - generator: 0.008533 - 1s
# Epoch 676/8000
# critic: 0.001515 - generator: 0.008802 - 1s
# Epoch 677/8000
# critic: 0.002867 - generator: 0.010070 - 1s
# Epoch 678/8000
# critic: 0.001770 - generator: 0.009938 - 1s
# Epoch 679/8000
# critic: 0.002282 - generator: 0.010151 - 1s
# Epoch 680/8000
# critic: 0.001563 - generator: 0.009654 - 1s
# Epoch 681/8000
# critic: 0.003107 - generator: 0.011143 - 1s
# Epoch 682/8000
# critic: 0.001862 - generator: 0.012384 - 1s
# Epoch 683/8000
# critic: 0.003068 - generator: 0.013219 - 1s
# Epoch 684/8000
# critic: 0.002674 - generator: 0.011970 - 1s
# Epoch 685/8000
# critic: 0.004586 - generator: 0.010735 - 1s
# Epoch 686/8000
# critic: 0.003523 - generator: 0.011964 - 1s
# Epoch 687/8000
# critic: 0.003552 - generator: 0.007503 - 1s
# Epoch 688/8000
# critic: 0.001252 - generator: 0.008367 - 1s
# Epoch 689/8000
# critic: 0.002739 - generator: 0.006522 - 1s
# Epoch 690/8000
# critic: 0.002190 - generator: 0.008467 - 1s
# Epoch 691/8000
# critic: 0.001923 - generator: 0.009436 - 1s
# Epoch 692/8000
# critic: 0.000907 - generator: 0.009732 - 1s
# Epoch 693/8000
# critic: 0.001560 - generator: 0.010749 - 1s
# Epoch 694/8000
# critic: 0.002616 - generator: 0.011377 - 1s
# Epoch 695/8000
# critic: 0.003871 - generator: 0.010086 - 1s
# Epoch 696/8000
# critic: 0.002812 - generator: 0.009847 - 1s
# Epoch 697/8000
# critic: 0.003533 - generator: 0.007513 - 1s
# Epoch 698/8000
# critic: 0.004499 - generator: 0.008722 - 1s
# Epoch 699/8000
# critic: 0.002287 - generator: 0.006135 - 1s
# Epoch 700/8000
# critic: 0.002919 - generator: 0.005062 - 1s
# Epoch 701/8000
# critic: 0.002554 - generator: 0.007618 - 1s
# Epoch 702/8000
# critic: 0.003690 - generator: 0.008813 - 1s
# Epoch 703/8000
# critic: 0.002452 - generator: 0.009164 - 1s
# Epoch 704/8000
# critic: 0.001683 - generator: 0.010687 - 1s
# Epoch 705/8000
# critic: 0.002221 - generator: 0.010977 - 1s
# Epoch 706/8000
# critic: 0.004149 - generator: 0.010738 - 1s
# Epoch 707/8000
# critic: 0.001484 - generator: 0.011040 - 1s
# Epoch 708/8000
# critic: 0.002102 - generator: 0.011437 - 1s
# Epoch 709/8000
# critic: 0.002718 - generator: 0.011982 - 1s
# Epoch 710/8000
# critic: 0.003291 - generator: 0.011035 - 1s
# Epoch 711/8000
# critic: 0.002620 - generator: 0.013211 - 1s
# Epoch 712/8000
# critic: 0.002440 - generator: 0.012639 - 1s
# Epoch 713/8000
# critic: 0.002297 - generator: 0.012283 - 1s
# Epoch 714/8000
# critic: 0.003387 - generator: 0.011840 - 1s
# Epoch 715/8000
# critic: 0.003918 - generator: 0.011423 - 1s
# Epoch 716/8000
# critic: 0.003346 - generator: 0.011629 - 1s
# Epoch 717/8000
# critic: 0.001535 - generator: 0.010461 - 1s
# Epoch 718/8000
# critic: 0.003272 - generator: 0.009449 - 1s
# Epoch 719/8000
# critic: 0.002626 - generator: 0.010099 - 1s
# Epoch 720/8000
# critic: 0.002749 - generator: 0.010291 - 1s
# Epoch 721/8000
# critic: 0.003965 - generator: 0.009369 - 1s
# Epoch 722/8000
# critic: 0.002835 - generator: 0.009364 - 1s
# Epoch 723/8000
# critic: 0.003437 - generator: 0.009446 - 1s
# Epoch 724/8000
# critic: 0.001854 - generator: 0.010941 - 1s
# Epoch 725/8000
# critic: 0.003811 - generator: 0.011038 - 1s
# Epoch 726/8000
# critic: 0.002326 - generator: 0.012154 - 1s
# Epoch 727/8000
# critic: 0.002702 - generator: 0.011223 - 1s
# Epoch 728/8000
# critic: 0.002864 - generator: 0.010864 - 1s
# Epoch 729/8000
# critic: 0.003151 - generator: 0.012092 - 1s
# Epoch 730/8000
# critic: 0.003600 - generator: 0.011722 - 1s
# Epoch 731/8000
# critic: 0.002954 - generator: 0.012034 - 1s
# Epoch 732/8000
# critic: 0.001436 - generator: 0.010514 - 1s
# Epoch 733/8000
# critic: 0.002978 - generator: 0.011711 - 1s
# Epoch 734/8000
# critic: 0.001856 - generator: 0.011006 - 1s
# Epoch 735/8000
# critic: 0.001834 - generator: 0.013478 - 1s
# Epoch 736/8000
# critic: 0.002487 - generator: 0.016508 - 1s
# Epoch 737/8000
# critic: 0.003500 - generator: 0.016435 - 1s
# Epoch 738/8000
# critic: 0.003939 - generator: 0.013859 - 1s
# Epoch 739/8000
# critic: 0.003330 - generator: 0.012640 - 1s
# Epoch 740/8000
# critic: 0.003849 - generator: 0.012559 - 1s
# Epoch 741/8000
# critic: 0.001754 - generator: 0.013750 - 1s
# Epoch 742/8000
# critic: 0.001907 - generator: 0.012563 - 1s
# Epoch 743/8000
# critic: 0.001361 - generator: 0.013077 - 1s
# Epoch 744/8000
# critic: 0.002044 - generator: 0.017166 - 1s
# Epoch 745/8000
# critic: 0.002425 - generator: 0.017141 - 1s
# Epoch 746/8000
# critic: 0.002699 - generator: 0.017050 - 1s
# Epoch 747/8000
# critic: 0.003748 - generator: 0.015660 - 1s
# Epoch 748/8000
# critic: 0.002900 - generator: 0.015301 - 1s
# Epoch 749/8000
# critic: 0.003718 - generator: 0.013745 - 1s
# Epoch 750/8000
# critic: 0.002975 - generator: 0.014087 - 1s
# Epoch 751/8000
# critic: 0.002962 - generator: 0.015818 - 1s
# Epoch 752/8000
# critic: 0.003575 - generator: 0.016503 - 1s
# Epoch 753/8000
# critic: 0.002717 - generator: 0.015677 - 1s
# Epoch 754/8000
# critic: 0.002560 - generator: 0.017910 - 1s
# Epoch 755/8000
# critic: 0.002636 - generator: 0.017060 - 1s
# Epoch 756/8000
# critic: 0.002385 - generator: 0.018373 - 1s
# Epoch 757/8000
# critic: 0.002373 - generator: 0.017757 - 1s
# Epoch 758/8000
# critic: 0.002124 - generator: 0.016680 - 1s
# Epoch 759/8000
# critic: 0.001673 - generator: 0.017969 - 1s
# Epoch 760/8000
# critic: 0.001507 - generator: 0.018419 - 1s
# Epoch 761/8000
# critic: 0.002701 - generator: 0.017256 - 1s
# Epoch 762/8000
# critic: 0.002266 - generator: 0.018048 - 1s
# Epoch 763/8000
# critic: 0.002461 - generator: 0.020088 - 1s
# Epoch 764/8000
# critic: 0.001356 - generator: 0.019429 - 1s
# Epoch 765/8000
# critic: 0.002420 - generator: 0.017556 - 1s
# Epoch 766/8000
# critic: 0.003607 - generator: 0.019218 - 1s
# Epoch 767/8000
# critic: 0.002899 - generator: 0.019229 - 1s
# Epoch 768/8000
# critic: 0.002284 - generator: 0.017403 - 1s
# Epoch 769/8000
# critic: 0.003673 - generator: 0.019480 - 1s
# Epoch 770/8000
# critic: 0.002118 - generator: 0.019622 - 1s
# Epoch 771/8000
# critic: 0.002695 - generator: 0.019763 - 1s
# Epoch 772/8000
# critic: 0.001862 - generator: 0.020240 - 1s
# Epoch 773/8000
# critic: 0.001775 - generator: 0.018255 - 1s
# Epoch 774/8000
# critic: 0.001631 - generator: 0.015541 - 1s
# Epoch 775/8000
# critic: 0.000877 - generator: 0.017147 - 1s
# Epoch 776/8000
# critic: 0.002222 - generator: 0.013802 - 1s
# Epoch 777/8000
# critic: 0.003848 - generator: 0.015609 - 1s
# Epoch 778/8000
# critic: 0.002285 - generator: 0.016198 - 1s
# Epoch 779/8000
# critic: 0.003110 - generator: 0.015791 - 1s
# Epoch 780/8000
# critic: 0.002561 - generator: 0.016301 - 1s
# Epoch 781/8000
# critic: 0.002529 - generator: 0.017368 - 1s
# Epoch 782/8000
# critic: 0.001409 - generator: 0.018143 - 1s
# Epoch 783/8000
# critic: 0.003027 - generator: 0.017923 - 1s
# Epoch 784/8000
# critic: 0.002918 - generator: 0.014300 - 1s
# Epoch 785/8000
# critic: 0.001840 - generator: 0.016012 - 1s
# Epoch 786/8000
# critic: 0.002827 - generator: 0.015814 - 1s
# Epoch 787/8000
# critic: 0.002797 - generator: 0.014177 - 1s
# Epoch 788/8000
# critic: 0.003186 - generator: 0.016280 - 1s
# Epoch 789/8000
# critic: 0.002363 - generator: 0.013476 - 1s
# Epoch 790/8000
# critic: 0.002075 - generator: 0.013286 - 1s
# Epoch 791/8000
# critic: 0.001757 - generator: 0.013813 - 1s
# Epoch 792/8000
# critic: 0.001248 - generator: 0.013658 - 1s
# Epoch 793/8000
# critic: 0.002372 - generator: 0.013652 - 1s
# Epoch 794/8000
# critic: 0.003901 - generator: 0.013056 - 1s
# Epoch 795/8000
# critic: 0.002823 - generator: 0.012920 - 1s
# Epoch 796/8000
# critic: 0.003058 - generator: 0.013081 - 1s
# Epoch 797/8000
# critic: 0.002472 - generator: 0.011092 - 1s
# Epoch 798/8000
# critic: 0.002571 - generator: 0.011647 - 1s
# Epoch 799/8000
# critic: 0.002568 - generator: 0.015904 - 1s
# Epoch 800/8000
# critic: 0.002411 - generator: 0.015682 - 1s
# Epoch 801/8000
# critic: 0.004216 - generator: 0.013921 - 1s
# Epoch 802/8000
# critic: 0.003927 - generator: 0.015618 - 1s
# Epoch 803/8000
# critic: 0.003239 - generator: 0.014456 - 1s
# Epoch 804/8000
# critic: 0.002398 - generator: 0.016198 - 1s
# Epoch 805/8000
# critic: 0.002538 - generator: 0.016275 - 1s
# Epoch 806/8000
# critic: 0.003349 - generator: 0.016062 - 1s
# Epoch 807/8000
# critic: 0.002608 - generator: 0.017065 - 1s
# Epoch 808/8000
# critic: 0.002646 - generator: 0.017180 - 1s
# Epoch 809/8000
# critic: 0.001992 - generator: 0.018183 - 1s
# Epoch 810/8000
# critic: 0.003407 - generator: 0.015462 - 1s
# Epoch 811/8000
# critic: 0.002587 - generator: 0.013981 - 1s
# ...
# critic: 0.001373 - generator: -0.062321 - 0s
# Epoch 4253/8000
# critic: 0.002529 - generator: -0.060221 - 0s
# Epoch 4254/8000
# critic: 0.001727 - generator: -0.058341 - 0s
# Epoch 4255/8000
# critic: 0.002190 - generator: -0.062223 - 0s
# Epoch 4256/8000
# critic: 0.003871 - generator: -0.061617 - 0s
# Epoch 4257/8000
# critic: 0.001608 - generator: -0.065913 - 0s
# Epoch 4258/8000
# critic: 0.001655 - generator: -0.065832 - 0s
# Epoch 4259/8000
# critic: 0.002638 - generator: -0.062453 - 0s
# Epoch 4260/8000
# critic: 0.004325 - generator: -0.058982 - 0s
# Epoch 4261/8000
# critic: 0.003574 - generator: -0.054530 - 0s
# Epoch 4262/8000
# critic: 0.001768 - generator: -0.054572 - 0s
# Epoch 4263/8000
# critic: 0.002108 - generator: -0.056303 - 0s
# Epoch 4264/8000
# critic: 0.003080 - generator: -0.057523 - 0s
# Epoch 4265/8000
# critic: 0.002199 - generator: -0.061814 - 0s
# Epoch 4266/8000
# critic: 0.003250 - generator: -0.062502 - 0s
# Epoch 4267/8000
# critic: 0.001850 - generator: -0.063597 - 0s
# Epoch 4268/8000
# critic: 0.001543 - generator: -0.061580 - 0s
# Epoch 4269/8000
# critic: 0.002326 - generator: -0.063708 - 0s
# Epoch 4270/8000
# critic: 0.002624 - generator: -0.064930 - 0s
# Epoch 4271/8000
# critic: 0.002239 - generator: -0.069316 - 0s
# Epoch 4272/8000
# critic: 0.002778 - generator: -0.070253 - 0s
# Epoch 4273/8000
# critic: 0.003469 - generator: -0.072062 - 0s
# Epoch 4274/8000
# critic: 0.003865 - generator: -0.071625 - 0s
# Epoch 4275/8000
# critic: 0.003368 - generator: -0.069499 - 0s
# Epoch 4276/8000
# critic: 0.002382 - generator: -0.068850 - 0s
# Epoch 4277/8000
# critic: 0.001883 - generator: -0.066582 - 0s
# Epoch 4278/8000
# critic: 0.001317 - generator: -0.064726 - 0s
# Epoch 4279/8000
# critic: 0.001458 - generator: -0.065532 - 0s
# Epoch 4280/8000
# critic: 0.000899 - generator: -0.068818 - 0s
# Epoch 4281/8000
# critic: 0.001542 - generator: -0.073274 - 0s
# Epoch 4282/8000
# critic: 0.002017 - generator: -0.072240 - 0s
# Epoch 4283/8000
# critic: 0.003000 - generator: -0.070752 - 0s
# Epoch 4284/8000
# critic: 0.002395 - generator: -0.070758 - 0s
# Epoch 4285/8000
# critic: 0.002026 - generator: -0.072271 - 0s
# Epoch 4286/8000
# critic: 0.002204 - generator: -0.075931 - 0s
# Epoch 4287/8000
# critic: 0.001890 - generator: -0.074968 - 0s
# Epoch 4288/8000
# critic: 0.001979 - generator: -0.071795 - 0s
# Epoch 4289/8000
# critic: 0.001670 - generator: -0.074040 - 0s
# Epoch 4290/8000
# critic: 0.002296 - generator: -0.072953 - 0s
# Epoch 4291/8000
# critic: 0.001272 - generator: -0.073716 - 0s
# Epoch 4292/8000
# critic: 0.001991 - generator: -0.071552 - 0s
# Epoch 4293/8000
# critic: 0.002299 - generator: -0.072277 - 0s
# Epoch 4294/8000
# critic: 0.001828 - generator: -0.071436 - 0s
# Epoch 4295/8000
# critic: 0.002893 - generator: -0.073302 - 0s
# Epoch 4296/8000
# critic: 0.002589 - generator: -0.071878 - 0s
# Epoch 4297/8000
# critic: 0.002885 - generator: -0.070801 - 0s
# Epoch 4298/8000
# critic: 0.002076 - generator: -0.070244 - 0s
# Epoch 4299/8000
# critic: 0.002500 - generator: -0.071350 - 0s
# Epoch 4300/8000
# critic: 0.001792 - generator: -0.074092 - 0s
# Epoch 4301/8000
# critic: 0.002479 - generator: -0.073749 - 0s
# Epoch 4302/8000
# critic: 0.002014 - generator: -0.072467 - 0s
# Epoch 4303/8000
# critic: 0.001686 - generator: -0.070501 - 0s
# Epoch 4304/8000
# critic: 0.002744 - generator: -0.068574 - 0s
# Epoch 4305/8000
# critic: 0.001815 - generator: -0.064529 - 0s
# Epoch 4306/8000
# critic: 0.001479 - generator: -0.059806 - 0s
# Epoch 4307/8000
# critic: 0.001714 - generator: -0.058299 - 0s
# Epoch 4308/8000
# critic: 0.002860 - generator: -0.060829 - 0s
# Epoch 4309/8000
# critic: 0.002709 - generator: -0.063010 - 0s
# Epoch 4310/8000
# critic: 0.003728 - generator: -0.065211 - 0s
# Epoch 4311/8000
# critic: 0.003638 - generator: -0.066979 - 0s
# Epoch 4312/8000
# critic: 0.002027 - generator: -0.067978 - 0s
# Epoch 4313/8000
# critic: 0.001520 - generator: -0.065055 - 0s
# Epoch 4314/8000
# critic: 0.002333 - generator: -0.062393 - 0s
# Epoch 4315/8000
# critic: 0.002665 - generator: -0.064489 - 0s
# Epoch 4316/8000
# critic: 0.002759 - generator: -0.062931 - 0s
# Epoch 4317/8000
# critic: 0.001657 - generator: -0.059808 - 0s
# Epoch 4318/8000
# critic: 0.001231 - generator: -0.060181 - 0s
# Epoch 4319/8000
# critic: 0.001512 - generator: -0.058642 - 0s
# Epoch 4320/8000
# critic: 0.004714 - generator: -0.058262 - 0s
# Epoch 4321/8000
# critic: 0.004750 - generator: -0.061184 - 0s
# Epoch 4322/8000
# critic: 0.004872 - generator: -0.061462 - 0s
# Epoch 4323/8000
# critic: 0.003595 - generator: -0.061784 - 0s
# Epoch 4324/8000
# critic: 0.002395 - generator: -0.062030 - 0s
# Epoch 4325/8000
# critic: 0.001937 - generator: -0.064787 - 0s
# Epoch 4326/8000
# critic: 0.001632 - generator: -0.066120 - 0s
# Epoch 4327/8000
# critic: 0.001301 - generator: -0.066311 - 0s
# Epoch 4328/8000
# critic: 0.002462 - generator: -0.065081 - 0s
# Epoch 4329/8000
# critic: 0.002170 - generator: -0.063378 - 0s
# Epoch 4330/8000
# critic: 0.001564 - generator: -0.061074 - 0s
# Epoch 4331/8000
# critic: 0.002566 - generator: -0.063532 - 0s
# Epoch 4332/8000
# critic: 0.002939 - generator: -0.061772 - 0s
# Epoch 4333/8000
# critic: 0.004151 - generator: -0.062296 - 0s
# Epoch 4334/8000
# critic: 0.003087 - generator: -0.064439 - 0s
# Epoch 4335/8000
# critic: 0.003201 - generator: -0.066850 - 0s
# Epoch 4336/8000
# critic: 0.002808 - generator: -0.070702 - 0s
# Epoch 4337/8000
# critic: 0.001871 - generator: -0.069471 - 0s
# Epoch 4338/8000
# critic: 0.001293 - generator: -0.069869 - 0s
# Epoch 4339/8000
# critic: 0.003320 - generator: -0.069644 - 0s
# Epoch 4340/8000
# critic: 0.002323 - generator: -0.069789 - 0s
# Epoch 4341/8000
# critic: 0.002527 - generator: -0.069306 - 0s
# Epoch 4342/8000
# critic: 0.002961 - generator: -0.067322 - 0s
# Epoch 4343/8000
# critic: 0.003075 - generator: -0.066542 - 0s
# Epoch 4344/8000
# critic: 0.002456 - generator: -0.064586 - 0s
# Epoch 4345/8000
# critic: 0.003822 - generator: -0.065116 - 0s
# Epoch 4346/8000
# critic: 0.003931 - generator: -0.066667 - 0s
# Epoch 4347/8000
# critic: 0.003884 - generator: -0.069995 - 0s
# Epoch 4348/8000
# critic: 0.001904 - generator: -0.073136 - 0s
# Epoch 4349/8000
# critic: 0.001363 - generator: -0.075995 - 0s
# Epoch 4350/8000
# critic: 0.001956 - generator: -0.077100 - 0s
# Epoch 4351/8000
# critic: 0.001367 - generator: -0.072013 - 0s
# Epoch 4352/8000
# critic: 0.001902 - generator: -0.073955 - 0s
# Epoch 4353/8000
# critic: 0.002659 - generator: -0.068543 - 0s
# Epoch 4354/8000
# critic: 0.003171 - generator: -0.065703 - 0s
# Epoch 4355/8000
# critic: 0.002502 - generator: -0.063110 - 0s
# Epoch 4356/8000
# critic: 0.001046 - generator: -0.065810 - 0s
# Epoch 4357/8000
# critic: 0.002256 - generator: -0.067381 - 0s
# Epoch 4358/8000
# critic: 0.002928 - generator: -0.063640 - 0s
# Epoch 4359/8000
# critic: 0.002633 - generator: -0.064926 - 0s
# Epoch 4360/8000
# critic: 0.002461 - generator: -0.065033 - 0s
# Epoch 4361/8000
# critic: 0.003063 - generator: -0.069795 - 0s
# Epoch 4362/8000
# critic: 0.003042 - generator: -0.073117 - 0s
# Epoch 4363/8000
# critic: 0.002162 - generator: -0.077494 - 0s
# Epoch 4364/8000
# critic: 0.002663 - generator: -0.082245 - 0s
# Epoch 4365/8000
# critic: 0.001345 - generator: -0.080140 - 1s
# Epoch 4366/8000
# critic: 0.002125 - generator: -0.078128 - 0s
# Epoch 4367/8000
# critic: 0.001868 - generator: -0.076812 - 0s
# Epoch 4368/8000
# critic: 0.002845 - generator: -0.075696 - 0s
# Epoch 4369/8000
# critic: 0.002187 - generator: -0.073060 - 0s
# Epoch 4370/8000
# critic: 0.001585 - generator: -0.069434 - 0s
# Epoch 4371/8000
# critic: 0.001796 - generator: -0.069756 - 0s
# Epoch 4372/8000
# critic: 0.001471 - generator: -0.069556 - 0s
# Epoch 4373/8000
# critic: 0.002265 - generator: -0.067294 - 0s
# Epoch 4374/8000
# critic: 0.002230 - generator: -0.071570 - 0s
# Epoch 4375/8000
# critic: 0.002197 - generator: -0.074121 - 0s
# Epoch 4376/8000
# critic: 0.001512 - generator: -0.074545 - 0s
# Epoch 4377/8000
# critic: 0.001937 - generator: -0.076535 - 0s
# Epoch 4378/8000
# critic: 0.002882 - generator: -0.074397 - 0s
# Epoch 4379/8000
# critic: 0.001709 - generator: -0.072208 - 0s
# Epoch 4380/8000
# critic: 0.001698 - generator: -0.066429 - 0s
# Epoch 4381/8000
# critic: 0.001792 - generator: -0.065308 - 0s
# Epoch 4382/8000
# critic: 0.001822 - generator: -0.068586 - 0s
# Epoch 4383/8000
# critic: 0.002559 - generator: -0.069478 - 0s
# Epoch 4384/8000
# critic: 0.002319 - generator: -0.071550 - 0s
# Epoch 4385/8000
# critic: 0.002515 - generator: -0.071219 - 0s
# Epoch 4386/8000
# critic: 0.002205 - generator: -0.067876 - 0s
# Epoch 4387/8000
# critic: 0.003066 - generator: -0.069026 - 0s
# Epoch 4388/8000
# critic: 0.002565 - generator: -0.070801 - 0s
# Epoch 4389/8000
# critic: 0.001715 - generator: -0.071772 - 0s
# Epoch 4390/8000
# critic: 0.001310 - generator: -0.068486 - 0s
# Epoch 4391/8000
# critic: 0.001360 - generator: -0.064350 - 0s
# Epoch 4392/8000
# critic: 0.002044 - generator: -0.066711 - 0s
# Epoch 4393/8000
# critic: 0.001348 - generator: -0.067207 - 0s
# Epoch 4394/8000
# critic: 0.002009 - generator: -0.071832 - 0s
# Epoch 4395/8000
# critic: 0.001752 - generator: -0.072873 - 0s
# Epoch 4396/8000
# critic: 0.002144 - generator: -0.072536 - 0s
# Epoch 4397/8000
# critic: 0.001543 - generator: -0.073602 - 0s
# Epoch 4398/8000
# critic: 0.001699 - generator: -0.074952 - 0s
# Epoch 4399/8000
# critic: 0.001862 - generator: -0.074750 - 0s
# Epoch 4400/8000
# critic: 0.001686 - generator: -0.076213 - 0s
# Epoch 4401/8000
# critic: 0.002160 - generator: -0.074943 - 0s
# Epoch 4402/8000
# critic: 0.001988 - generator: -0.077425 - 0s
# Epoch 4403/8000
# critic: 0.002669 - generator: -0.079457 - 0s
# Epoch 4404/8000
# critic: 0.002527 - generator: -0.078529 - 0s
# Epoch 4405/8000
# critic: 0.001593 - generator: -0.078620 - 0s
# Epoch 4406/8000
# critic: 0.002451 - generator: -0.077406 - 0s
# Epoch 4407/8000
# critic: 0.004014 - generator: -0.075224 - 0s
# Epoch 4408/8000
# critic: 0.003586 - generator: -0.076698 - 0s
# Epoch 4409/8000
# critic: 0.001926 - generator: -0.080137 - 0s
# Epoch 4410/8000
# critic: 0.001943 - generator: -0.078243 - 0s
# Epoch 4411/8000
# critic: 0.001859 - generator: -0.080426 - 0s
# Epoch 4412/8000
# critic: 0.002043 - generator: -0.080002 - 0s
# Epoch 4413/8000
# critic: 0.000986 - generator: -0.079842 - 0s
# Epoch 4414/8000
# critic: 0.003013 - generator: -0.081007 - 0s
# Epoch 4415/8000
# critic: 0.002302 - generator: -0.079572 - 0s
# Epoch 4416/8000
# critic: 0.002845 - generator: -0.073805 - 0s
# Epoch 4417/8000
# critic: 0.002792 - generator: -0.071503 - 0s
# Epoch 4418/8000
# critic: 0.002524 - generator: -0.073679 - 0s
# Epoch 4419/8000
# critic: 0.002819 - generator: -0.074866 - 0s
# Epoch 4420/8000
# critic: 0.002957 - generator: -0.078668 - 0s
# Epoch 4421/8000
# critic: 0.002152 - generator: -0.080153 - 0s
# Epoch 4422/8000
# critic: 0.002274 - generator: -0.078302 - 0s
# Epoch 4423/8000
# critic: 0.002613 - generator: -0.078838 - 0s
# Epoch 4424/8000
# critic: 0.004044 - generator: -0.080113 - 0s
# Epoch 4425/8000
# critic: 0.002987 - generator: -0.076498 - 0s
# Epoch 4426/8000
# critic: 0.002943 - generator: -0.070769 - 0s
# Epoch 4427/8000
# critic: 0.003345 - generator: -0.066770 - 0s
# Epoch 4428/8000
# critic: 0.003976 - generator: -0.061980 - 0s
# Epoch 4429/8000
# critic: 0.005710 - generator: -0.063712 - 0s
# Epoch 4430/8000
# critic: 0.003694 - generator: -0.063950 - 0s
# Epoch 4431/8000
# critic: 0.003001 - generator: -0.064720 - 0s
# Epoch 4432/8000
# critic: 0.003775 - generator: -0.064769 - 0s
# Epoch 4433/8000
# critic: 0.003312 - generator: -0.064866 - 0s
# Epoch 4434/8000
# critic: 0.004929 - generator: -0.063394 - 0s
# Epoch 4435/8000
# critic: 0.004901 - generator: -0.063582 - 0s
# Epoch 4436/8000
# critic: 0.004439 - generator: -0.067903 - 0s
# Epoch 4437/8000
# critic: 0.003936 - generator: -0.069484 - 0s
# Epoch 4438/8000
# critic: 0.003378 - generator: -0.075330 - 0s
# Epoch 4439/8000
# critic: 0.003222 - generator: -0.075992 - 0s
# Epoch 4440/8000
# critic: 0.004128 - generator: -0.076897 - 0s
# Epoch 4441/8000
# critic: 0.003327 - generator: -0.076845 - 0s
# Epoch 4442/8000
# critic: 0.003989 - generator: -0.078884 - 0s
# Epoch 4443/8000
# critic: 0.004534 - generator: -0.079977 - 0s
# Epoch 4444/8000
# critic: 0.003187 - generator: -0.081703 - 0s
# Epoch 4445/8000
# critic: 0.002562 - generator: -0.088352 - 0s
# Epoch 4446/8000
# critic: 0.003201 - generator: -0.092758 - 0s
# Epoch 4447/8000
# critic: 0.002808 - generator: -0.095547 - 0s
# Epoch 4448/8000
# critic: 0.002686 - generator: -0.099547 - 0s
# Epoch 4449/8000
# critic: 0.001023 - generator: -0.102508 - 0s
# Epoch 4450/8000
# critic: 0.002464 - generator: -0.106881 - 0s
# Epoch 4451/8000
# critic: 0.001325 - generator: -0.111372 - 0s
# Epoch 4452/8000
# critic: 0.002241 - generator: -0.116800 - 0s
# Epoch 4453/8000
# critic: 0.001567 - generator: -0.117569 - 0s
# Epoch 4454/8000
# critic: 0.003633 - generator: -0.118878 - 0s
# Epoch 4455/8000
# critic: 0.003789 - generator: -0.118601 - 0s
# Epoch 4456/8000
# critic: 0.004192 - generator: -0.120619 - 0s
# Epoch 4457/8000
# critic: 0.004135 - generator: -0.117029 - 0s
# Epoch 4458/8000
# critic: 0.004309 - generator: -0.121362 - 0s
# Epoch 4459/8000
# critic: 0.005223 - generator: -0.125090 - 0s
# Epoch 4460/8000
# critic: 0.004560 - generator: -0.123338 - 0s
# Epoch 4461/8000
# critic: 0.005148 - generator: -0.116551 - 0s
# Epoch 4462/8000
# critic: 0.005964 - generator: -0.106601 - 0s
# Epoch 4463/8000
# critic: 0.005353 - generator: -0.097735 - 0s
# Epoch 4464/8000
# critic: 0.004590 - generator: -0.097177 - 0s
# Epoch 4465/8000
# critic: 0.004967 - generator: -0.100575 - 0s
# Epoch 4466/8000
# critic: 0.005838 - generator: -0.103839 - 0s
# Epoch 4467/8000
# critic: 0.006853 - generator: -0.103966 - 0s
# Epoch 4468/8000
# critic: 0.005178 - generator: -0.107306 - 0s
# Epoch 4469/8000
# critic: 0.006297 - generator: -0.114046 - 0s
# Epoch 4470/8000
# critic: 0.004770 - generator: -0.122009 - 0s
# Epoch 4471/8000
# critic: 0.002937 - generator: -0.130032 - 0s
# Epoch 4472/8000
# critic: 0.004296 - generator: -0.131698 - 0s
# Epoch 4473/8000
# critic: 0.006329 - generator: -0.129566 - 0s
# Epoch 4474/8000
# critic: 0.009448 - generator: -0.121101 - 0s
# Epoch 4475/8000
# critic: 0.011570 - generator: -0.111259 - 0s
# Epoch 4476/8000
# critic: 0.008364 - generator: -0.100672 - 0s
# Epoch 4477/8000
# critic: 0.001881 - generator: -0.082650 - 0s
# Epoch 4478/8000
# critic: 0.001043 - generator: -0.066182 - 0s
# Epoch 4479/8000
# critic: 0.001877 - generator: -0.055853 - 0s
# Epoch 4480/8000
# critic: 0.007691 - generator: -0.043997 - 0s
# Epoch 4481/8000
# critic: 0.008275 - generator: -0.047642 - 0s
# Epoch 4482/8000
# critic: 0.010159 - generator: -0.055285 - 0s
# Epoch 4483/8000
# critic: 0.008121 - generator: -0.071778 - 0s
# Epoch 4484/8000
# critic: 0.007501 - generator: -0.081695 - 0s
# Epoch 4485/8000
# critic: 0.007119 - generator: -0.087241 - 0s
# Epoch 4486/8000
# critic: 0.004342 - generator: -0.095581 - 0s
# Epoch 4487/8000
# critic: 0.000595 - generator: -0.106844 - 0s
# Epoch 4488/8000
# critic: 0.000739 - generator: -0.113660 - 0s
# Epoch 4489/8000
# critic: 0.003084 - generator: -0.113963 - 0s
# Epoch 4490/8000
# critic: 0.004364 - generator: -0.112625 - 0s
# Epoch 4491/8000
# critic: 0.008077 - generator: -0.103920 - 0s
# Epoch 4492/8000
# critic: 0.008674 - generator: -0.093068 - 0s
# Epoch 4493/8000
# critic: 0.005023 - generator: -0.078165 - 0s
# Epoch 4494/8000
# critic: 0.002421 - generator: -0.059947 - 0s
# Epoch 4495/8000
# critic: 0.002734 - generator: -0.041883 - 0s
# Epoch 4496/8000
# critic: 0.003886 - generator: -0.031019 - 0s
# Epoch 4497/8000
# critic: 0.005410 - generator: -0.028301 - 0s
# Epoch 4498/8000
# critic: 0.005039 - generator: -0.033878 - 0s
# Epoch 4499/8000
# critic: 0.007254 - generator: -0.043260 - 0s
# Epoch 4500/8000
# critic: 0.007710 - generator: -0.048740 - 0s
# Epoch 4501/8000
# critic: 0.008213 - generator: -0.057356 - 0s
# Epoch 4502/8000
# critic: 0.009053 - generator: -0.064840 - 0s
# Epoch 4503/8000
# critic: 0.008713 - generator: -0.076445 - 0s
# Epoch 4504/8000
# critic: 0.002543 - generator: -0.087572 - 0s
# Epoch 4505/8000
# critic: -0.000761 - generator: -0.101958 - 0s
# Epoch 4506/8000
# critic: -0.003136 - generator: -0.113261 - 0s
# Epoch 4507/8000
# critic: -0.000900 - generator: -0.115471 - 0s
# Epoch 4508/8000
# critic: 0.004045 - generator: -0.116833 - 0s
# Epoch 4509/8000
# critic: 0.004590 - generator: -0.116022 - 0s
# Epoch 4510/8000
# critic: 0.006084 - generator: -0.116923 - 0s
# Epoch 4511/8000
# critic: 0.008284 - generator: -0.114388 - 0s
# Epoch 4512/8000
# critic: 0.005847 - generator: -0.107333 - 0s
# Epoch 4513/8000
# critic: 0.001608 - generator: -0.091040 - 0s
# Epoch 4514/8000

# %% [markdown]
# #### plot loss

# %%
k=k
epoch = 8000

# %%
from PIL import Image

#Discriminator Loss
loss = Image.open('GANS/Losses/GANS_loss_v'+str(k)+'_epochs'+str(epoch)+'.png')
plt.figure("Loss",figsize=[15,10])
plt.imshow(loss)

# %% [markdown]
# ### Sampleing from the latent space

# %%
generator = keras.models.load_model('GANS/Models/generator_v'+str(k)+'_epochs_'+str(epoch))

# %%
#Discriminator Loss
result = Image.open('GANS/Result/Latent/v_'+str(k)+'_epochs_'+str(epoch)+'.png')
plt.figure("Latent Space",figsize=[10,6])
plt.imshow(result)

# %%
countour_line = Image.open('GANS/Result/'+'countour_points_v'+str(k)+'_epochs'+str(epoch)+'.png')
plt.figure("Countour Line",figsize=[20,6])
plt.imshow(countour_line)

countour_mesh = Image.open('GANS/Result/'+'countour_mesh_v'+str(k)+'_epochs'+str(epoch)+'.png')
plt.figure("Countour Mesh",figsize=[18,7])
plt.imshow(countour_mesh)

heatmap = Image.open('GANS/Result/'+'heatmap_v'+str(k)+'_epochs'+str(epoch)+'.png')
plt.figure("Heatmap",figsize=[18,7])
plt.imshow(heatmap)

# %% [markdown]
# ### Applying the prediction function

# %% [markdown]
# ## Fixed Input

# %%
# define these for desired prediction
x_input = [-1,-0.5,0,0.5,1.0,1.5,2.0]
n_points = 700
y_min = -1
y_max = 1

# produces an input of fixed x coordinates with random y values
predict1 = np.full((n_points//7, n_features), x_input[0])
predict2 = np.full((n_points//7, n_features), x_input[1])
predict3 = np.full((n_points//7, n_features), x_input[2])
predict4 = np.full((n_points//7, n_features), x_input[3])
predict5 = np.full((n_points//7, n_features), x_input[4])
predict6 = np.full((n_points//7, n_features), x_input[5])
predict7 = np.full((n_points//7, n_features), x_input[6])

predictthis = np.concatenate((predict1, predict2, predict3, predict4, predict5, predict6, predict7))
predictthis = scaler.transform(predictthis)
input_test = predictthis.reshape(n_points, n_features).astype('float32')


print("input_test :",input_test.shape)
plt.scatter(input_test[:,0],input_test[:,1] ,c='grey')
plt.ylabel('Y')
plt.xlabel('X')
plt.tight_layout()

# %%
X_generated = wgan.predict(input_test, scaler)

# %%
if scenario in ("3d", "helix"):
    print("latent_space=",latent_space)
    print("Epochs=",epochs)
    print("BATCH_SIZE=",BATCH_SIZE)
    print("use_bias=",use_bias)
    
    ax = plt.subplot(projection='3d')
    ax.scatter(X_generated[:,0], X_generated[:,1], X_generated[:,2], label='Generated Data')
    #ax.scatter(X_train[:,0], X_train[:,1], y_train, c='r', label='Sample Data')

    ax.set_zlabel('Z')
    ax.set_ylabel('Y')
    ax.set_xlabel('X')

    plt.legend(loc='best')
    plt.tight_layout()
    
    print("X-Y 2D slices:")
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    plt.ylim(-1.5,1.5)
    plt.xlim(-1.5,1.5)
    axes[0].scatter(X_train[:,0],X_train[:,1])
    axes[0].scatter(X_generated[:,0],X_generated[:,1])
    axes[0].set_xlabel("X")
    axes[0].set_ylabel("Y")
    
    plt.ylim(-1.5,1.5)
    plt.xlim(-2,22)
    axes[1].scatter(X_train[:,1],y_train)
    axes[1].scatter(X_generated[:,1],X_generated[:,2])
    axes[1].set_xlabel("Y")
    axes[1].set_ylabel("Z")
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-2,22)
    axes[2].scatter(X_train[:,0],y_train)
    axes[2].scatter(X_generated[:,0],X_generated[:,2])
    axes[2].set_xlabel("X")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    
    ac=np.where(np.logical_and(X_train[:,0]>=-0.8-0.05,X_train[:,0]<=-0.8+0.05),X_train[:,1],None)
    ad=np.where(np.logical_and(X_generated[:,0]>=-0.8-0.05,X_generated[:,0]<=-0.8+0.05),X_generated[:,1],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("Y(X=-0.8)")
    axes[0].set_ylabel("Y")
    
    ae=np.where(np.logical_and(X_train[:,0]>=0.0-0.05,X_train[:,0]<=0.0+0.05),X_train[:,1],None)
    af=np.where(np.logical_and(X_generated[:,0]>=0.0-0.05,X_generated[:,0]<=0.0+0.05),X_generated[:,1],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("Y(X=0.0)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,0]>=0.8-0.05,X_train[:,0]<=0.8+0.05),X_train[:,1],None)
    ah=np.where(np.logical_and(X_generated[:,0]>=0.8-0.05,X_generated[:,0]<=0.8+0.05),X_generated[:,1],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("Y(X=0.8)")
    axes[2].set_ylabel("Z")
    
    plt.tight_layout()
    
    
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=False, sharex=False)
    ac=np.where(np.logical_and(X_train[:,1]>=0.2-0.05,X_train[:,1]<=0.2+0.05),X_train[:,0],None)
    ad=np.where(np.logical_and(X_generated[:,1]>=0.2-0.05,X_generated[:,1]<=0.2+0.05),X_generated[:,0],None)
    axes[0].scatter(ac,y_train)
    axes[0].scatter(ad,X_generated[:,2])
    axes[0].set_xlabel("X(Y=0.2)")
    axes[0].set_ylabel("Z")
    
    ae=np.where(np.logical_and(X_train[:,1]>=0.5-0.05,X_train[:,1]<=0.5+0.05),X_train[:,0],None)
    af=np.where(np.logical_and(X_generated[:,1]>=0.5-0.05,X_generated[:,1]<=0.5+0.05),X_generated[:,0],None)
    axes[1].scatter(ae,y_train)
    axes[1].scatter(af,X_generated[:,2])
    axes[1].set_xlabel("X(Y=0.5)")
    axes[1].set_ylabel("Z")
    
    ag=np.where(np.logical_and(X_train[:,1]>=0.8-0.05,X_train[:,1]<=0.8+0.05),X_train[:,0],None)
    ah=np.where(np.logical_and(X_generated[:,1]>=0.8-0.05,X_generated[:,1]<=0.8+0.05),X_generated[:,0],None)
    axes[2].scatter(ag,y_train)
    axes[2].scatter(ah,X_generated[:,2])
    axes[2].set_xlabel("X(Y=0.8)")
    axes[2].set_ylabel("Z")
    
    
    plt.tight_layout()
    
    
else:
    print("Generated Data:",X_generated.shape)
    plt.scatter(X_train, y_train,label="Sample Data")
    plt.scatter(X_generated[:,0],X_generated[:,1])
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
